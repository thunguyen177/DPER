# %% [markdown]
# ## libraries and function

# %%
# !pip install impyute
# !pip install fancyimpute
from sklearn import datasets
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from scipy import stats
import numpy as np
# import impyute as impy
from fancyimpute import IterativeSVD, SoftImpute, NuclearNormMinimization
import pandas as pd
import time
# !pip install missingpy
# from missingpy import MissForest
# note that MissForest uses sklearn.__version__ 0.22.2.post1
# Out:
# Requirement already satisfied: fancyimpute in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.0)
# Requirement already satisfied: tensorflow>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (2.6.0)
# Requirement already satisfied: cvxpy==1.1.13 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.1.13)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.2.6)
# Requirement already satisfied: keras>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (2.6.0)
# Requirement already satisfied: knnimpute>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (0.1.0)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy==1.1.13->fancyimpute) (2.0.7.post1)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from cvxpy==1.1.13->fancyimpute) (2.1.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from cvxpy==1.1.13->fancyimpute) (1.4.1)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy==1.1.13->fancyimpute) (0.6.2.post0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from knnimpute>=0.1.0->fancyimpute) (1.15.0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy==1.1.13->fancyimpute) (0.1.5.post0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (1.0.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (3.17.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (0.37.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (0.12.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (3.3.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (1.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (1.12.1)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (2.6.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (3.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (1.12)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (1.1.2)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (5.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (0.4.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (1.6.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (3.7.4.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (1.40.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->fancyimpute) (2.6.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow>=2.5.1->fancyimpute) (1.5.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.1->fancyimpute) (3.5.0)

# %% [markdown]
# ## MLE estimation function

# %%
def diag_term(i,X,y):
  arr0 = X[:,i]
  nar2 = 0
  arr = arr0[~np.isnan(arr0)]
  y_arr = y[~np.isnan(arr0)]

  _, counts = np.unique(y_arr, return_counts=True)
  ind = np.insert(np.cumsum(counts), 0, 0)
  
  return sum([(ind[g]-ind[g-1])*np.var(arr[ind[g-1]:ind[g]]) for 
                       g in range(1,G+1)])/len(y_arr)

# %%
def mle(X,y,G):
    '''
    X: input, should be a numpy array
    y: label
    G: number of classes
    output:
    - mus: each row is a class mean
    - S: common covariance matrix of class 1,2,..., G 
    '''
    epsilon = 1e-5 # define epsilon to put r down to 0 if r < epsilon
    n,p = X.shape[0], X.shape[1]

    # Estimating class means
    mus = np.array([np.nanmean(X[y==g,:],axis=0) for g in range (G)]).T # so that each column is the mean of a class
 
    S = np.diag([diag_term(i,X,y) for i in range(p)]) 

    for i in range(p):      
      for j in range(i):
        mat = X[:,[i,j]]

        # drop rows with NA
        idx = ~np.isnan(mat).any(axis=1)
        mat, y_arr = mat[idx], y[idx]

        _, counts = np.unique(y_arr, return_counts=True)
        ind = np.insert(np.cumsum(counts), 0, 0)

        m_g = counts
 
        A = len(y_arr) 
        scaled_mat = [mat[ind[g-1]:ind[g],:]-mus[[i,j],g-1] for g in range(1,G+1)]   

        q = lambda g: np.dot(scaled_mat[g][:,0],scaled_mat[g][:,0])
        s11 = sum(map(q,range(G))) 
        q = lambda g: np.dot(scaled_mat[g][:,1],scaled_mat[g][:,1])
        s22 = sum(map(q,range(G))) 
        d = lambda g: np.dot(scaled_mat[g][:,0],scaled_mat[g][:,1])
        s12 = sum(map(d,range(G)))  

        start_solve = time.time()
        B = S[i,i]*S[j,j]*A - s22 * S[i,i] - s11 * S[j,j]
        coefficient = [-A, s12, B, s12*S[i,i]*S[j,j]]
        r = np.roots(coefficient)

        r = r[abs(np.imag(r)) < epsilon]
        r = np.real(r)
        r[abs(r) < epsilon] = 0

        if len(r)>1:
          condi_var = S[j,j] - r**2/S[i,i]
          eta = -A*np.log(condi_var)-(S[j,j]-2*r/S[i,i]*s12 +
                                      r**2/S[i,i]**2*s11)/condi_var
          # if condi_var <0 then eta = NA. in practice, it's impossible for cov to be negative
          #  therefore, we drop NA elements of eta  
          r = r[eta == max(eta[~np.isnan(eta)])]

        if len(r) > 1:        
            w = [m_g[g-1]*np.cov(mat[ind[g-1]:ind[g],], rowvar=False) for
                 g in range(1,G+1)]
            w = np.sum(w, axis = 0)    
            r = r[np.abs(r-w[0,1]).argmin()] # select r that is closet to w[0,1] 
              
        S[i,j] = S[j,i] = r
    return [mus, S]

# %% [markdown]
# ### compute_err function

# %%
def err(mus, S, mus_est, S_est):
  er = [np.linalg.norm(mus_est-mus)/mus.size,
         np.linalg.norm(S_est.flatten()-S.flatten())/S.size]
  return np.mean(er)  

def generate_nan(Xtrain, missing_rate):
  Xshape = Xtrain.shape
  na_id = np.random.randint(0,Xtrain.size,round(missing_rate*Xtrain.size))
  Xtr_nan = Xtrain.flatten()
  Xtr_nan[na_id] = np.nan 
  return Xtr_nan.reshape(Xshape)

# %%
def compute_err_mle(Xtrain, ytrain, G, missing_rate, runs = 10):
  e_rate = []
  running_time = []
  for i in  range(runs):
    Xtr_nan = generate_nan(Xtrain, missing_rate)
    Xtr_nan = generate_nan(Xtrain, missing_rate)
    
    scaler = StandardScaler()
    scaler.fit(Xtr_nan)
    Xtr_nan = scaler.transform(Xtr_nan)
    Xtrain = scaler.transform(Xtrain)
    
    # estimate parameters from full data
    mus = [np.mean(Xtrain[ytrain==g,:], axis=0) for g in np.arange(G)]
    mus = np.asarray(mus) # each row is a mean of a class
    S = [sum(ytrain==g)*np.cov(Xtrain[ytrain==g,:],rowvar =False) 
             for g in np.arange(G)]
    S = np.sum(S, axis = 0)/len(ytrain)

    # MLEs approach
    start = time.time()
    mus_mle, S_mle = mle(Xtr_nan,ytrain, G)
    mle_err = err(mus, S, mus_mle.T, S_mle)
    mle_time = time.time()-start    
    e_rate.append(mle_err)
    running_time.append(mle_time)
  e_rate = np.asarray(e_rate)
  running_time = np.asarray(running_time)
  return np.mean(e_rate), np.std(e_rate), np.mean(running_time)

# %%
def compute_err_soft(Xtrain, ytrain, G, missing_rate, runs = 10):
  e_rate = []
  for i in  range(runs):
    Xtr_nan = generate_nan(Xtrain, missing_rate)
    Xtr_nan = generate_nan(Xtrain, missing_rate)
    
    scaler = StandardScaler()
    scaler.fit(Xtr_nan)
    Xtr_nan = scaler.transform(Xtr_nan)
    Xtrain = scaler.transform(Xtrain)
    
    # estimate parameters from full data
    mus = [np.mean(Xtrain[ytrain==g,:], axis=0) for g in np.arange(G)]
    mus = np.asarray(mus) # each row is a mean of a class
    S = [sum(ytrain==g)*np.cov(Xtrain[ytrain==g,:],rowvar =False) 
             for g in np.arange(G)]
    S = np.sum(S, axis = 0)/len(ytrain)

    start = time.time()
    Xtr_softimpute = SoftImpute(max_iters = 100).fit_transform(Xtr_nan)
    mus_softimpute = np.asarray([np.mean(Xtr_softimpute[ytrain==g,:], axis=0
                                         ) for g in np.arange(G)])
    S_softimpute = np.asarray([(sum(ytrain==g))*np.cov(Xtr_softimpute[ytrain==g,:], rowvar =False) 
             for g in np.arange(G)])
    S_softimpute = np.sum(S_softimpute, axis = 0)/len(ytrain) 
    softimpute_err =  err(mus, S, mus_softimpute, S_softimpute)
    softimpute_time = time.time()-start

    e_rate.append(softimpute_err)
  e_rate = np.asarray(e_rate)
  return np.mean(e_rate), np.std(e_rate)

# %%
def compute_err_mice(Xtrain, ytrain, G, missing_rate, runs = 10):
  e_rate = []
  for i in  range(runs):
    Xtr_nan = generate_nan(Xtrain, missing_rate)
    Xtr_nan = generate_nan(Xtrain, missing_rate)
    
    scaler = StandardScaler()
    scaler.fit(Xtr_nan)
    Xtr_nan = scaler.transform(Xtr_nan)
    Xtrain = scaler.transform(Xtrain)
    
    # estimate parameters from full data
    mus = [np.mean(Xtrain[ytrain==g,:], axis=0) for g in np.arange(G)]
    mus = np.asarray(mus) # each row is a mean of a class
    S = [sum(ytrain==g)*np.cov(Xtrain[ytrain==g,:],rowvar =False) 
             for g in np.arange(G)]
    S = np.sum(S, axis = 0)/len(ytrain)


    start = time.time()
    Xtr_mice = IterativeImputer(max_iter=100).fit(Xtr_nan).transform(Xtr_nan)
    mus_mice = np.asarray([np.mean(Xtr_mice[ytrain==g,:], axis=0
                                   ) for g in np.arange(G)])
    S_mice = np.asarray([(sum(ytrain==g))*np.cov(Xtr_mice[ytrain==g,:], rowvar =False) 
             for g in np.arange(G)])
    S_mice = np.sum(S_mice, axis = 0)/len(ytrain) 
    mice_err = err(mus, S, mus_mice, S_mice)
    mice_time = time.time()-start

    e_rate.append(mice_err)
  e_rate = np.asarray(e_rate)
  return np.mean(e_rate), np.std(e_rate)

# %% [markdown]
# # Heart

# %%
data = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/spect/SPECTF.train', header = None,sep=',')
test = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/spect/SPECTF.test',
                     header=None, sep = ',')
data = pd.concat([data, test])
data = data.to_numpy()
X,y = data[:,1:], data[:,0]
X = X.astype(np.float32)
G = len(np.unique(y)) 
print(np.shape(X))
for g in range(G):
  print(sum(y==g))
# Out:
# (267, 44)
# 55
# 212

# %%
G = 2
mle_err = np.array([compute_err_mle(X, y, G, .2, runs = 10),
                    compute_err_mle(X, y, G, .35, runs = 10),
                    compute_err_mle(X, y, G, .5, runs = 10),
                    compute_err_mle(X, y, G, .65, runs = 10),
                    compute_err_mle(X, y, G, .8, runs = 10)])
mle_err.round(3)
# Out:
# array([[0.003, 0.   ],
#        [0.004, 0.   ],
#        [0.004, 0.   ],
#        [0.005, 0.   ],
#        [0.006, 0.   ]])

# %%
G = 2
mice_err = np.array([compute_err_mice(X, y, G, .2, runs = 10),
                    compute_err_mice(X, y, G, .35, runs = 10),
                    compute_err_mice(X, y, G, .5, runs = 10),
                    compute_err_mice(X, y, G, .65, runs = 10),
                    compute_err_mice(X, y, G, .8, runs = 10)])
mice_err.round(3)
# Out:
# array([[0.002, 0.   ],
#        [0.003, 0.   ],
#        [0.004, 0.   ],
#        [0.005, 0.   ],
#        [0.006, 0.   ]])

# %%
G = 2
soft_err = np.array([compute_err_soft(X, y, G, .2, runs = 10),
                    compute_err_soft(X, y, G, .35, runs = 10),
                    compute_err_soft(X, y, G, .5, runs = 10),
                    compute_err_soft(X, y, G, .65, runs = 10),
                    compute_err_soft(X, y, G, .8, runs = 10)])
soft_err.round(3)
# Out:
# [SoftImpute] Max Singular Value of X_init = 50.945023
# [SoftImpute] Iter 1: observed MAE=0.048939 rank=44
# [SoftImpute] Iter 2: observed MAE=0.049282 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049599 rank=44
# [SoftImpute] Iter 4: observed MAE=0.049890 rank=44
# [SoftImpute] Iter 5: observed MAE=0.050154 rank=44
# [SoftImpute] Iter 6: observed MAE=0.050387 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050595 rank=44
# [SoftImpute] Iter 8: observed MAE=0.050778 rank=44
# [SoftImpute] Iter 9: observed MAE=0.050936 rank=44
# [SoftImpute] Iter 10: observed MAE=0.051076 rank=44
# [SoftImpute] Iter 11: observed MAE=0.051198 rank=44
# [SoftImpute] Iter 12: observed MAE=0.051303 rank=44
# [SoftImpute] Iter 13: observed MAE=0.051390 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051465 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051529 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051583 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051631 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051672 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051707 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051738 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051765 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051788 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051809 rank=44
# [SoftImpute] Iter 24: observed MAE=0.051828 rank=44
# [SoftImpute] Iter 25: observed MAE=0.051844 rank=44
# [SoftImpute] Iter 26: observed MAE=0.051859 rank=44
# [SoftImpute] Iter 27: observed MAE=0.051872 rank=44
# [SoftImpute] Iter 28: observed MAE=0.051883 rank=44
# [SoftImpute] Iter 29: observed MAE=0.051893 rank=44
# [SoftImpute] Iter 30: observed MAE=0.051902 rank=44
# [SoftImpute] Iter 31: observed MAE=0.051910 rank=44
# [SoftImpute] Iter 32: observed MAE=0.051917 rank=44
# [SoftImpute] Iter 33: observed MAE=0.051923 rank=44
# [SoftImpute] Iter 34: observed MAE=0.051929 rank=44
# [SoftImpute] Iter 35: observed MAE=0.051934 rank=44
# [SoftImpute] Iter 36: observed MAE=0.051939 rank=44
# [SoftImpute] Iter 37: observed MAE=0.051943 rank=44
# [SoftImpute] Iter 38: observed MAE=0.051947 rank=44
# [SoftImpute] Iter 39: observed MAE=0.051950 rank=44
# [SoftImpute] Iter 40: observed MAE=0.051953 rank=44
# [SoftImpute] Iter 41: observed MAE=0.051956 rank=44
# [SoftImpute] Iter 42: observed MAE=0.051959 rank=44
# [SoftImpute] Iter 43: observed MAE=0.051961 rank=44
# [SoftImpute] Iter 44: observed MAE=0.051964 rank=44
# [SoftImpute] Iter 45: observed MAE=0.051966 rank=44
# [SoftImpute] Iter 46: observed MAE=0.051968 rank=44
# [SoftImpute] Iter 47: observed MAE=0.051969 rank=44
# [SoftImpute] Iter 48: observed MAE=0.051971 rank=44
# [SoftImpute] Iter 49: observed MAE=0.051972 rank=44
# [SoftImpute] Iter 50: observed MAE=0.051973 rank=44
# [SoftImpute] Iter 51: observed MAE=0.051975 rank=44
# [SoftImpute] Iter 52: observed MAE=0.051976 rank=44
# [SoftImpute] Iter 53: observed MAE=0.051977 rank=44
# [SoftImpute] Iter 54: observed MAE=0.051978 rank=44
# [SoftImpute] Iter 55: observed MAE=0.051978 rank=44
# [SoftImpute] Iter 56: observed MAE=0.051979 rank=44
# [SoftImpute] Iter 57: observed MAE=0.051980 rank=44
# [SoftImpute] Iter 58: observed MAE=0.051981 rank=44
# [SoftImpute] Iter 59: observed MAE=0.051981 rank=44
# [SoftImpute] Iter 60: observed MAE=0.051982 rank=44
# [SoftImpute] Iter 61: observed MAE=0.051982 rank=44
# [SoftImpute] Iter 62: observed MAE=0.051983 rank=44
# [SoftImpute] Iter 63: observed MAE=0.051983 rank=44
# [SoftImpute] Iter 64: observed MAE=0.051984 rank=44
# [SoftImpute] Stopped after iteration 64 for lambda=1.018900
# [SoftImpute] Max Singular Value of X_init = 51.526520
# [SoftImpute] Iter 1: observed MAE=0.049676 rank=44
# [SoftImpute] Iter 2: observed MAE=0.050019 rank=44
# [SoftImpute] Iter 3: observed MAE=0.050336 rank=44
# [SoftImpute] Iter 4: observed MAE=0.050631 rank=44
# [SoftImpute] Iter 5: observed MAE=0.050898 rank=44
# [SoftImpute] Iter 6: observed MAE=0.051137 rank=44
# [SoftImpute] Iter 7: observed MAE=0.051347 rank=44
# [SoftImpute] Iter 8: observed MAE=0.051529 rank=44
# [SoftImpute] Iter 9: observed MAE=0.051687 rank=44
# [SoftImpute] Iter 10: observed MAE=0.051823 rank=44
# [SoftImpute] Iter 11: observed MAE=0.051939 rank=44
# [SoftImpute] Iter 12: observed MAE=0.052039 rank=44
# [SoftImpute] Iter 13: observed MAE=0.052124 rank=44
# [SoftImpute] Iter 14: observed MAE=0.052197 rank=44
# [SoftImpute] Iter 15: observed MAE=0.052259 rank=44
# [SoftImpute] Iter 16: observed MAE=0.052311 rank=44
# [SoftImpute] Iter 17: observed MAE=0.052353 rank=44
# [SoftImpute] Iter 18: observed MAE=0.052389 rank=44
# [SoftImpute] Iter 19: observed MAE=0.052420 rank=44
# [SoftImpute] Iter 20: observed MAE=0.052446 rank=44
# [SoftImpute] Iter 21: observed MAE=0.052467 rank=44
# [SoftImpute] Iter 22: observed MAE=0.052485 rank=44
# [SoftImpute] Iter 23: observed MAE=0.052500 rank=44
# [SoftImpute] Iter 24: observed MAE=0.052513 rank=44
# [SoftImpute] Iter 25: observed MAE=0.052524 rank=44
# [SoftImpute] Iter 26: observed MAE=0.052534 rank=44
# [SoftImpute] Iter 27: observed MAE=0.052543 rank=44
# [SoftImpute] Iter 28: observed MAE=0.052550 rank=44
# [SoftImpute] Iter 29: observed MAE=0.052557 rank=44
# [SoftImpute] Iter 30: observed MAE=0.052563 rank=44
# [SoftImpute] Iter 31: observed MAE=0.052569 rank=44
# [SoftImpute] Iter 32: observed MAE=0.052574 rank=44
# [SoftImpute] Iter 33: observed MAE=0.052578 rank=44
# [SoftImpute] Iter 34: observed MAE=0.052582 rank=44
# [SoftImpute] Iter 35: observed MAE=0.052585 rank=44
# [SoftImpute] Iter 36: observed MAE=0.052588 rank=44
# [SoftImpute] Iter 37: observed MAE=0.052591 rank=44
# [SoftImpute] Iter 38: observed MAE=0.052593 rank=44
# [SoftImpute] Iter 39: observed MAE=0.052596 rank=44
# [SoftImpute] Iter 40: observed MAE=0.052598 rank=44
# [SoftImpute] Iter 41: observed MAE=0.052600 rank=44
# [SoftImpute] Iter 42: observed MAE=0.052602 rank=44
# [SoftImpute] Iter 43: observed MAE=0.052604 rank=44
# [SoftImpute] Iter 44: observed MAE=0.052606 rank=44
# [SoftImpute] Iter 45: observed MAE=0.052607 rank=44
# [SoftImpute] Iter 46: observed MAE=0.052609 rank=44
# [SoftImpute] Iter 47: observed MAE=0.052610 rank=44
# [SoftImpute] Iter 48: observed MAE=0.052611 rank=44
# [SoftImpute] Iter 49: observed MAE=0.052613 rank=44
# [SoftImpute] Iter 50: observed MAE=0.052614 rank=44
# [SoftImpute] Iter 51: observed MAE=0.052615 rank=44
# [SoftImpute] Iter 52: observed MAE=0.052616 rank=44
# [SoftImpute] Iter 53: observed MAE=0.052617 rank=44
# [SoftImpute] Iter 54: observed MAE=0.052618 rank=44
# [SoftImpute] Iter 55: observed MAE=0.052618 rank=44
# [SoftImpute] Iter 56: observed MAE=0.052619 rank=44
# [SoftImpute] Iter 57: observed MAE=0.052620 rank=44
# [SoftImpute] Iter 58: observed MAE=0.052621 rank=44
# [SoftImpute] Iter 59: observed MAE=0.052621 rank=44
# [SoftImpute] Iter 60: observed MAE=0.052622 rank=44
# [SoftImpute] Iter 61: observed MAE=0.052622 rank=44
# [SoftImpute] Iter 62: observed MAE=0.052623 rank=44
# [SoftImpute] Iter 63: observed MAE=0.052624 rank=44
# [SoftImpute] Stopped after iteration 63 for lambda=1.030530
# [SoftImpute] Max Singular Value of X_init = 51.040359
# [SoftImpute] Iter 1: observed MAE=0.049112 rank=44
# [SoftImpute] Iter 2: observed MAE=0.049449 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049758 rank=44
# [SoftImpute] Iter 4: observed MAE=0.050042 rank=44
# [SoftImpute] Iter 5: observed MAE=0.050297 rank=44
# [SoftImpute] Iter 6: observed MAE=0.050525 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050724 rank=44
# [SoftImpute] Iter 8: observed MAE=0.050898 rank=44
# [SoftImpute] Iter 9: observed MAE=0.051053 rank=44
# [SoftImpute] Iter 10: observed MAE=0.051188 rank=44
# [SoftImpute] Iter 11: observed MAE=0.051305 rank=44
# [SoftImpute] Iter 12: observed MAE=0.051406 rank=44
# [SoftImpute] Iter 13: observed MAE=0.051494 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051571 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051637 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051697 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051751 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051797 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051837 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051873 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051903 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051929 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051953 rank=44
# [SoftImpute] Iter 24: observed MAE=0.051973 rank=44
# [SoftImpute] Iter 25: observed MAE=0.051991 rank=44
# [SoftImpute] Iter 26: observed MAE=0.052006 rank=44
# [SoftImpute] Iter 27: observed MAE=0.052020 rank=44
# [SoftImpute] Iter 28: observed MAE=0.052033 rank=44
# [SoftImpute] Iter 29: observed MAE=0.052043 rank=44
# [SoftImpute] Iter 30: observed MAE=0.052053 rank=44
# [SoftImpute] Iter 31: observed MAE=0.052061 rank=44
# [SoftImpute] Iter 32: observed MAE=0.052069 rank=44
# [SoftImpute] Iter 33: observed MAE=0.052076 rank=44
# [SoftImpute] Iter 34: observed MAE=0.052081 rank=44
# [SoftImpute] Iter 35: observed MAE=0.052087 rank=44
# [SoftImpute] Iter 36: observed MAE=0.052092 rank=44
# [SoftImpute] Iter 37: observed MAE=0.052096 rank=44
# [SoftImpute] Iter 38: observed MAE=0.052100 rank=44
# [SoftImpute] Iter 39: observed MAE=0.052103 rank=44
# [SoftImpute] Iter 40: observed MAE=0.052106 rank=44
# [SoftImpute] Iter 41: observed MAE=0.052109 rank=44
# [SoftImpute] Iter 42: observed MAE=0.052112 rank=44
# [SoftImpute] Iter 43: observed MAE=0.052115 rank=44
# [SoftImpute] Iter 44: observed MAE=0.052117 rank=44
# [SoftImpute] Iter 45: observed MAE=0.052119 rank=44
# [SoftImpute] Iter 46: observed MAE=0.052121 rank=44
# [SoftImpute] Iter 47: observed MAE=0.052123 rank=44
# [SoftImpute] Iter 48: observed MAE=0.052125 rank=44
# [SoftImpute] Iter 49: observed MAE=0.052126 rank=44
# [SoftImpute] Iter 50: observed MAE=0.052127 rank=44
# [SoftImpute] Iter 51: observed MAE=0.052129 rank=44
# [SoftImpute] Iter 52: observed MAE=0.052130 rank=44
# [SoftImpute] Iter 53: observed MAE=0.052131 rank=44
# [SoftImpute] Iter 54: observed MAE=0.052132 rank=44
# [SoftImpute] Iter 55: observed MAE=0.052133 rank=44
# [SoftImpute] Iter 56: observed MAE=0.052134 rank=44
# [SoftImpute] Iter 57: observed MAE=0.052134 rank=44
# [SoftImpute] Iter 58: observed MAE=0.052135 rank=44
# [SoftImpute] Iter 59: observed MAE=0.052136 rank=44
# [SoftImpute] Iter 60: observed MAE=0.052136 rank=44
# [SoftImpute] Iter 61: observed MAE=0.052137 rank=44
# [SoftImpute] Iter 62: observed MAE=0.052138 rank=44
# [SoftImpute] Iter 63: observed MAE=0.052138 rank=44
# [SoftImpute] Iter 64: observed MAE=0.052139 rank=44
# [SoftImpute] Stopped after iteration 64 for lambda=1.020807
# [SoftImpute] Max Singular Value of X_init = 50.566849
# [SoftImpute] Iter 1: observed MAE=0.048569 rank=44
# [SoftImpute] Iter 2: observed MAE=0.048926 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049254 rank=44
# [SoftImpute] Iter 4: observed MAE=0.049556 rank=44
# [SoftImpute] Iter 5: observed MAE=0.049828 rank=44
# [SoftImpute] Iter 6: observed MAE=0.050072 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050293 rank=44
# [SoftImpute] Iter 8: observed MAE=0.050491 rank=44
# [SoftImpute] Iter 9: observed MAE=0.050666 rank=44
# [SoftImpute] Iter 10: observed MAE=0.050819 rank=44
# [SoftImpute] Iter 11: observed MAE=0.050949 rank=44
# [SoftImpute] Iter 12: observed MAE=0.051058 rank=44
# [SoftImpute] Iter 13: observed MAE=0.051151 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051233 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051302 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051362 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051414 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051459 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051498 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051533 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051563 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051589 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051612 rank=44
# [SoftImpute] Iter 24: observed MAE=0.051632 rank=44
# [SoftImpute] Iter 25: observed MAE=0.051650 rank=44
# [SoftImpute] Iter 26: observed MAE=0.051667 rank=44
# [SoftImpute] Iter 27: observed MAE=0.051682 rank=44
# [SoftImpute] Iter 28: observed MAE=0.051695 rank=44
# [SoftImpute] Iter 29: observed MAE=0.051706 rank=44
# [SoftImpute] Iter 30: observed MAE=0.051717 rank=44
# [SoftImpute] Iter 31: observed MAE=0.051726 rank=44
# [SoftImpute] Iter 32: observed MAE=0.051735 rank=44
# [SoftImpute] Iter 33: observed MAE=0.051742 rank=44
# [SoftImpute] Iter 34: observed MAE=0.051749 rank=44
# [SoftImpute] Iter 35: observed MAE=0.051756 rank=44
# [SoftImpute] Iter 36: observed MAE=0.051761 rank=44
# [SoftImpute] Iter 37: observed MAE=0.051767 rank=44
# [SoftImpute] Iter 38: observed MAE=0.051772 rank=44
# [SoftImpute] Iter 39: observed MAE=0.051776 rank=44
# [SoftImpute] Iter 40: observed MAE=0.051780 rank=44
# [SoftImpute] Iter 41: observed MAE=0.051784 rank=44
# [SoftImpute] Iter 42: observed MAE=0.051787 rank=44
# [SoftImpute] Iter 43: observed MAE=0.051790 rank=44
# [SoftImpute] Iter 44: observed MAE=0.051793 rank=44
# [SoftImpute] Iter 45: observed MAE=0.051796 rank=44
# [SoftImpute] Iter 46: observed MAE=0.051798 rank=44
# [SoftImpute] Iter 47: observed MAE=0.051800 rank=44
# [SoftImpute] Iter 48: observed MAE=0.051802 rank=44
# [SoftImpute] Iter 49: observed MAE=0.051804 rank=44
# [SoftImpute] Iter 50: observed MAE=0.051805 rank=44
# [SoftImpute] Iter 51: observed MAE=0.051807 rank=44
# [SoftImpute] Iter 52: observed MAE=0.051808 rank=44
# [SoftImpute] Iter 53: observed MAE=0.051810 rank=44
# [SoftImpute] Iter 54: observed MAE=0.051811 rank=44
# [SoftImpute] Iter 55: observed MAE=0.051812 rank=44
# [SoftImpute] Iter 56: observed MAE=0.051813 rank=44
# [SoftImpute] Iter 57: observed MAE=0.051814 rank=44
# [SoftImpute] Iter 58: observed MAE=0.051815 rank=44
# [SoftImpute] Iter 59: observed MAE=0.051816 rank=44
# [SoftImpute] Iter 60: observed MAE=0.051817 rank=44
# [SoftImpute] Iter 61: observed MAE=0.051818 rank=44
# [SoftImpute] Iter 62: observed MAE=0.051818 rank=44
# [SoftImpute] Iter 63: observed MAE=0.051819 rank=44
# [SoftImpute] Iter 64: observed MAE=0.051820 rank=44
# [SoftImpute] Iter 65: observed MAE=0.051820 rank=44
# [SoftImpute] Iter 66: observed MAE=0.051821 rank=44
# [SoftImpute] Iter 67: observed MAE=0.051821 rank=44
# [SoftImpute] Iter 68: observed MAE=0.051822 rank=44
# [SoftImpute] Stopped after iteration 68 for lambda=1.011337
# [SoftImpute] Max Singular Value of X_init = 51.286816
# [SoftImpute] Iter 1: observed MAE=0.049267 rank=44
# [SoftImpute] Iter 2: observed MAE=0.049609 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049922 rank=44
# [SoftImpute] Iter 4: observed MAE=0.050206 rank=44
# [SoftImpute] Iter 5: observed MAE=0.050463 rank=44
# [SoftImpute] Iter 6: observed MAE=0.050694 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050898 rank=44
# [SoftImpute] Iter 8: observed MAE=0.051072 rank=44
# [SoftImpute] Iter 9: observed MAE=0.051220 rank=44
# [SoftImpute] Iter 10: observed MAE=0.051346 rank=44
# [SoftImpute] Iter 11: observed MAE=0.051453 rank=44
# [SoftImpute] Iter 12: observed MAE=0.051544 rank=44
# [SoftImpute] Iter 13: observed MAE=0.051621 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051686 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051742 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051789 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051830 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051867 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051899 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051927 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051953 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051976 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051995 rank=44
# [SoftImpute] Iter 24: observed MAE=0.052013 rank=44
# [SoftImpute] Iter 25: observed MAE=0.052030 rank=44
# [SoftImpute] Iter 26: observed MAE=0.052045 rank=44
# [SoftImpute] Iter 27: observed MAE=0.052058 rank=44
# [SoftImpute] Iter 28: observed MAE=0.052070 rank=44
# [SoftImpute] Iter 29: observed MAE=0.052082 rank=44
# [SoftImpute] Iter 30: observed MAE=0.052092 rank=44
# [SoftImpute] Iter 31: observed MAE=0.052101 rank=44
# [SoftImpute] Iter 32: observed MAE=0.052109 rank=44
# [SoftImpute] Iter 33: observed MAE=0.052116 rank=44
# [SoftImpute] Iter 34: observed MAE=0.052123 rank=44
# [SoftImpute] Iter 35: observed MAE=0.052129 rank=44
# [SoftImpute] Iter 36: observed MAE=0.052135 rank=44
# [SoftImpute] Iter 37: observed MAE=0.052140 rank=44
# [SoftImpute] Iter 38: observed MAE=0.052144 rank=44
# [SoftImpute] Iter 39: observed MAE=0.052148 rank=44
# [SoftImpute] Iter 40: observed MAE=0.052152 rank=44
# [SoftImpute] Iter 41: observed MAE=0.052155 rank=44
# [SoftImpute] Iter 42: observed MAE=0.052158 rank=44
# [SoftImpute] Iter 43: observed MAE=0.052161 rank=44
# [SoftImpute] Iter 44: observed MAE=0.052164 rank=44
# [SoftImpute] Iter 45: observed MAE=0.052166 rank=44
# [SoftImpute] Iter 46: observed MAE=0.052168 rank=44
# [SoftImpute] Iter 47: observed MAE=0.052170 rank=44
# [SoftImpute] Iter 48: observed MAE=0.052172 rank=44
# [SoftImpute] Iter 49: observed MAE=0.052174 rank=44
# [SoftImpute] Iter 50: observed MAE=0.052176 rank=44
# [SoftImpute] Iter 51: observed MAE=0.052177 rank=44
# [SoftImpute] Iter 52: observed MAE=0.052179 rank=44
# [SoftImpute] Iter 53: observed MAE=0.052180 rank=44
# [SoftImpute] Iter 54: observed MAE=0.052181 rank=44
# [SoftImpute] Iter 55: observed MAE=0.052182 rank=44
# [SoftImpute] Iter 56: observed MAE=0.052184 rank=44
# [SoftImpute] Iter 57: observed MAE=0.052185 rank=44
# [SoftImpute] Iter 58: observed MAE=0.052185 rank=44
# [SoftImpute] Iter 59: observed MAE=0.052186 rank=44
# [SoftImpute] Iter 60: observed MAE=0.052187 rank=44
# [SoftImpute] Iter 61: observed MAE=0.052188 rank=44
# [SoftImpute] Iter 62: observed MAE=0.052189 rank=44
# [SoftImpute] Iter 63: observed MAE=0.052189 rank=44
# [SoftImpute] Iter 64: observed MAE=0.052190 rank=44
# [SoftImpute] Stopped after iteration 64 for lambda=1.025736
# [SoftImpute] Max Singular Value of X_init = 50.611877
# [SoftImpute] Iter 1: observed MAE=0.048621 rank=44
# [SoftImpute] Iter 2: observed MAE=0.048965 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049286 rank=44
# [SoftImpute] Iter 4: observed MAE=0.049579 rank=44
# [SoftImpute] Iter 5: observed MAE=0.049843 rank=44
# [SoftImpute] Iter 6: observed MAE=0.050083 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050298 rank=44
# [SoftImpute] Iter 8: observed MAE=0.050487 rank=44
# [SoftImpute] Iter 9: observed MAE=0.050652 rank=44
# [SoftImpute] Iter 10: observed MAE=0.050794 rank=44
# [SoftImpute] Iter 11: observed MAE=0.050916 rank=44
# [SoftImpute] Iter 12: observed MAE=0.051019 rank=44
# [SoftImpute] Iter 13: observed MAE=0.051106 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051178 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051238 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051291 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051336 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051375 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051407 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051435 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051459 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051479 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051495 rank=44
# [SoftImpute] Iter 24: observed MAE=0.051511 rank=44
# [SoftImpute] Iter 25: observed MAE=0.051525 rank=44
# [SoftImpute] Iter 26: observed MAE=0.051537 rank=44
# [SoftImpute] Iter 27: observed MAE=0.051548 rank=44
# [SoftImpute] Iter 28: observed MAE=0.051557 rank=44
# [SoftImpute] Iter 29: observed MAE=0.051566 rank=44
# [SoftImpute] Iter 30: observed MAE=0.051573 rank=44
# [SoftImpute] Iter 31: observed MAE=0.051580 rank=44
# [SoftImpute] Iter 32: observed MAE=0.051586 rank=44
# [SoftImpute] Iter 33: observed MAE=0.051592 rank=44
# [SoftImpute] Iter 34: observed MAE=0.051597 rank=44
# [SoftImpute] Iter 35: observed MAE=0.051601 rank=44
# [SoftImpute] Iter 36: observed MAE=0.051605 rank=44
# [SoftImpute] Iter 37: observed MAE=0.051609 rank=44
# [SoftImpute] Iter 38: observed MAE=0.051612 rank=44
# [SoftImpute] Iter 39: observed MAE=0.051616 rank=44
# [SoftImpute] Iter 40: observed MAE=0.051619 rank=44
# [SoftImpute] Iter 41: observed MAE=0.051622 rank=44
# [SoftImpute] Iter 42: observed MAE=0.051624 rank=44
# [SoftImpute] Iter 43: observed MAE=0.051626 rank=44
# [SoftImpute] Iter 44: observed MAE=0.051629 rank=44
# [SoftImpute] Iter 45: observed MAE=0.051631 rank=44
# [SoftImpute] Iter 46: observed MAE=0.051633 rank=44
# [SoftImpute] Iter 47: observed MAE=0.051635 rank=44
# [SoftImpute] Iter 48: observed MAE=0.051637 rank=44
# [SoftImpute] Iter 49: observed MAE=0.051638 rank=44
# [SoftImpute] Iter 50: observed MAE=0.051640 rank=44
# [SoftImpute] Iter 51: observed MAE=0.051641 rank=44
# [SoftImpute] Iter 52: observed MAE=0.051642 rank=44
# [SoftImpute] Iter 53: observed MAE=0.051644 rank=44
# [SoftImpute] Iter 54: observed MAE=0.051645 rank=44
# [SoftImpute] Iter 55: observed MAE=0.051646 rank=44
# [SoftImpute] Iter 56: observed MAE=0.051647 rank=44
# [SoftImpute] Iter 57: observed MAE=0.051648 rank=44
# [SoftImpute] Iter 58: observed MAE=0.051649 rank=44
# [SoftImpute] Iter 59: observed MAE=0.051650 rank=44
# [SoftImpute] Iter 60: observed MAE=0.051651 rank=44
# [SoftImpute] Iter 61: observed MAE=0.051652 rank=44
# [SoftImpute] Iter 62: observed MAE=0.051653 rank=44
# [SoftImpute] Iter 63: observed MAE=0.051654 rank=44
# [SoftImpute] Iter 64: observed MAE=0.051654 rank=44
# [SoftImpute] Iter 65: observed MAE=0.051655 rank=44
# [SoftImpute] Iter 66: observed MAE=0.051655 rank=44
# [SoftImpute] Iter 67: observed MAE=0.051656 rank=44
# [SoftImpute] Stopped after iteration 67 for lambda=1.012238
# [SoftImpute] Max Singular Value of X_init = 50.459919
# [SoftImpute] Iter 1: observed MAE=0.048501 rank=44
# [SoftImpute] Iter 2: observed MAE=0.048811 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049097 rank=44
# [SoftImpute] Iter 4: observed MAE=0.049364 rank=44
# [SoftImpute] Iter 5: observed MAE=0.049607 rank=44
# [SoftImpute] Iter 6: observed MAE=0.049829 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050027 rank=44
# [SoftImpute] Iter 8: observed MAE=0.050202 rank=44
# [SoftImpute] Iter 9: observed MAE=0.050357 rank=44
# [SoftImpute] Iter 10: observed MAE=0.050494 rank=44
# [SoftImpute] Iter 11: observed MAE=0.050613 rank=44
# [SoftImpute] Iter 12: observed MAE=0.050716 rank=44
# [SoftImpute] Iter 13: observed MAE=0.050807 rank=44
# [SoftImpute] Iter 14: observed MAE=0.050885 rank=44
# [SoftImpute] Iter 15: observed MAE=0.050952 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051009 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051060 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051104 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051142 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051174 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051201 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051225 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051245 rank=44
# [SoftImpute] Iter 24: observed MAE=0.051263 rank=44
# [SoftImpute] Iter 25: observed MAE=0.051279 rank=44
# [SoftImpute] Iter 26: observed MAE=0.051293 rank=44
# [SoftImpute] Iter 27: observed MAE=0.051306 rank=44
# [SoftImpute] Iter 28: observed MAE=0.051316 rank=44
# [SoftImpute] Iter 29: observed MAE=0.051326 rank=44
# [SoftImpute] Iter 30: observed MAE=0.051334 rank=44
# [SoftImpute] Iter 31: observed MAE=0.051342 rank=44
# [SoftImpute] Iter 32: observed MAE=0.051349 rank=44
# [SoftImpute] Iter 33: observed MAE=0.051355 rank=44
# [SoftImpute] Iter 34: observed MAE=0.051360 rank=44
# [SoftImpute] Iter 35: observed MAE=0.051365 rank=44
# [SoftImpute] Iter 36: observed MAE=0.051369 rank=44
# [SoftImpute] Iter 37: observed MAE=0.051373 rank=44
# [SoftImpute] Iter 38: observed MAE=0.051376 rank=44
# [SoftImpute] Iter 39: observed MAE=0.051379 rank=44
# [SoftImpute] Iter 40: observed MAE=0.051382 rank=44
# [SoftImpute] Iter 41: observed MAE=0.051385 rank=44
# [SoftImpute] Iter 42: observed MAE=0.051387 rank=44
# [SoftImpute] Iter 43: observed MAE=0.051389 rank=44
# [SoftImpute] Iter 44: observed MAE=0.051391 rank=44
# [SoftImpute] Iter 45: observed MAE=0.051393 rank=44
# [SoftImpute] Iter 46: observed MAE=0.051394 rank=44
# [SoftImpute] Iter 47: observed MAE=0.051396 rank=44
# [SoftImpute] Iter 48: observed MAE=0.051397 rank=44
# [SoftImpute] Iter 49: observed MAE=0.051398 rank=44
# [SoftImpute] Iter 50: observed MAE=0.051399 rank=44
# [SoftImpute] Iter 51: observed MAE=0.051400 rank=44
# [SoftImpute] Iter 52: observed MAE=0.051401 rank=44
# [SoftImpute] Iter 53: observed MAE=0.051402 rank=44
# [SoftImpute] Iter 54: observed MAE=0.051403 rank=44
# [SoftImpute] Iter 55: observed MAE=0.051404 rank=44
# [SoftImpute] Iter 56: observed MAE=0.051404 rank=44
# [SoftImpute] Iter 57: observed MAE=0.051405 rank=44
# [SoftImpute] Iter 58: observed MAE=0.051406 rank=44
# [SoftImpute] Iter 59: observed MAE=0.051406 rank=44
# [SoftImpute] Iter 60: observed MAE=0.051407 rank=44
# [SoftImpute] Iter 61: observed MAE=0.051407 rank=44
# [SoftImpute] Iter 62: observed MAE=0.051408 rank=44
# [SoftImpute] Iter 63: observed MAE=0.051408 rank=44
# [SoftImpute] Iter 64: observed MAE=0.051408 rank=44
# [SoftImpute] Iter 65: observed MAE=0.051409 rank=44
# [SoftImpute] Iter 66: observed MAE=0.051409 rank=44
# [SoftImpute] Stopped after iteration 66 for lambda=1.009198
# [SoftImpute] Max Singular Value of X_init = 51.325993
# [SoftImpute] Iter 1: observed MAE=0.049384 rank=44
# [SoftImpute] Iter 2: observed MAE=0.049723 rank=44
# [SoftImpute] Iter 3: observed MAE=0.050034 rank=44
# [SoftImpute] Iter 4: observed MAE=0.050310 rank=44
# [SoftImpute] Iter 5: observed MAE=0.050561 rank=44
# [SoftImpute] Iter 6: observed MAE=0.050788 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050986 rank=44
# [SoftImpute] Iter 8: observed MAE=0.051158 rank=44
# [SoftImpute] Iter 9: observed MAE=0.051309 rank=44
# [SoftImpute] Iter 10: observed MAE=0.051442 rank=44
# [SoftImpute] Iter 11: observed MAE=0.051556 rank=44
# [SoftImpute] Iter 12: observed MAE=0.051653 rank=44
# [SoftImpute] Iter 13: observed MAE=0.051736 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051808 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051868 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051919 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051961 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051997 rank=44
# [SoftImpute] Iter 19: observed MAE=0.052028 rank=44
# [SoftImpute] Iter 20: observed MAE=0.052054 rank=44
# [SoftImpute] Iter 21: observed MAE=0.052076 rank=44
# [SoftImpute] Iter 22: observed MAE=0.052096 rank=44
# [SoftImpute] Iter 23: observed MAE=0.052113 rank=44
# [SoftImpute] Iter 24: observed MAE=0.052128 rank=44
# [SoftImpute] Iter 25: observed MAE=0.052140 rank=44
# [SoftImpute] Iter 26: observed MAE=0.052151 rank=44
# [SoftImpute] Iter 27: observed MAE=0.052161 rank=44
# [SoftImpute] Iter 28: observed MAE=0.052169 rank=44
# [SoftImpute] Iter 29: observed MAE=0.052176 rank=44
# [SoftImpute] Iter 30: observed MAE=0.052183 rank=44
# [SoftImpute] Iter 31: observed MAE=0.052189 rank=44
# [SoftImpute] Iter 32: observed MAE=0.052195 rank=44
# [SoftImpute] Iter 33: observed MAE=0.052200 rank=44
# [SoftImpute] Iter 34: observed MAE=0.052204 rank=44
# [SoftImpute] Iter 35: observed MAE=0.052208 rank=44
# [SoftImpute] Iter 36: observed MAE=0.052211 rank=44
# [SoftImpute] Iter 37: observed MAE=0.052214 rank=44
# [SoftImpute] Iter 38: observed MAE=0.052217 rank=44
# [SoftImpute] Iter 39: observed MAE=0.052220 rank=44
# [SoftImpute] Iter 40: observed MAE=0.052222 rank=44
# [SoftImpute] Iter 41: observed MAE=0.052224 rank=44
# [SoftImpute] Iter 42: observed MAE=0.052225 rank=44
# [SoftImpute] Iter 43: observed MAE=0.052227 rank=44
# [SoftImpute] Iter 44: observed MAE=0.052229 rank=44
# [SoftImpute] Iter 45: observed MAE=0.052230 rank=44
# [SoftImpute] Iter 46: observed MAE=0.052231 rank=44
# [SoftImpute] Iter 47: observed MAE=0.052232 rank=44
# [SoftImpute] Iter 48: observed MAE=0.052233 rank=44
# [SoftImpute] Iter 49: observed MAE=0.052234 rank=44
# [SoftImpute] Iter 50: observed MAE=0.052235 rank=44
# [SoftImpute] Iter 51: observed MAE=0.052236 rank=44
# [SoftImpute] Iter 52: observed MAE=0.052237 rank=44
# [SoftImpute] Iter 53: observed MAE=0.052238 rank=44
# [SoftImpute] Iter 54: observed MAE=0.052238 rank=44
# [SoftImpute] Iter 55: observed MAE=0.052239 rank=44
# [SoftImpute] Iter 56: observed MAE=0.052240 rank=44
# [SoftImpute] Iter 57: observed MAE=0.052240 rank=44
# [SoftImpute] Iter 58: observed MAE=0.052241 rank=44
# [SoftImpute] Iter 59: observed MAE=0.052241 rank=44
# [SoftImpute] Iter 60: observed MAE=0.052241 rank=44
# [SoftImpute] Iter 61: observed MAE=0.052242 rank=44
# [SoftImpute] Iter 62: observed MAE=0.052242 rank=44
# [SoftImpute] Iter 63: observed MAE=0.052243 rank=44
# [SoftImpute] Iter 64: observed MAE=0.052243 rank=44
# [SoftImpute] Stopped after iteration 64 for lambda=1.026520
# [SoftImpute] Max Singular Value of X_init = 50.716530
# [SoftImpute] Iter 1: observed MAE=0.048718 rank=44
# [SoftImpute] Iter 2: observed MAE=0.049060 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049376 rank=44
# [SoftImpute] Iter 4: observed MAE=0.049665 rank=44
# [SoftImpute] Iter 5: observed MAE=0.049925 rank=44
# [SoftImpute] Iter 6: observed MAE=0.050158 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050367 rank=44
# [SoftImpute] Iter 8: observed MAE=0.050552 rank=44
# [SoftImpute] Iter 9: observed MAE=0.050711 rank=44
# [SoftImpute] Iter 10: observed MAE=0.050847 rank=44
# [SoftImpute] Iter 11: observed MAE=0.050965 rank=44
# [SoftImpute] Iter 12: observed MAE=0.051067 rank=44
# [SoftImpute] Iter 13: observed MAE=0.051153 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051226 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051288 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051339 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051383 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051420 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051451 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051479 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051503 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051524 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051543 rank=44
# [SoftImpute] Iter 24: observed MAE=0.051560 rank=44
# [SoftImpute] Iter 25: observed MAE=0.051575 rank=44
# [SoftImpute] Iter 26: observed MAE=0.051589 rank=44
# [SoftImpute] Iter 27: observed MAE=0.051601 rank=44
# [SoftImpute] Iter 28: observed MAE=0.051612 rank=44
# [SoftImpute] Iter 29: observed MAE=0.051622 rank=44
# [SoftImpute] Iter 30: observed MAE=0.051631 rank=44
# [SoftImpute] Iter 31: observed MAE=0.051639 rank=44
# [SoftImpute] Iter 32: observed MAE=0.051646 rank=44
# [SoftImpute] Iter 33: observed MAE=0.051653 rank=44
# [SoftImpute] Iter 34: observed MAE=0.051659 rank=44
# [SoftImpute] Iter 35: observed MAE=0.051665 rank=44
# [SoftImpute] Iter 36: observed MAE=0.051670 rank=44
# [SoftImpute] Iter 37: observed MAE=0.051675 rank=44
# [SoftImpute] Iter 38: observed MAE=0.051679 rank=44
# [SoftImpute] Iter 39: observed MAE=0.051683 rank=44
# [SoftImpute] Iter 40: observed MAE=0.051687 rank=44
# [SoftImpute] Iter 41: observed MAE=0.051690 rank=44
# [SoftImpute] Iter 42: observed MAE=0.051693 rank=44
# [SoftImpute] Iter 43: observed MAE=0.051696 rank=44
# [SoftImpute] Iter 44: observed MAE=0.051698 rank=44
# [SoftImpute] Iter 45: observed MAE=0.051700 rank=44
# [SoftImpute] Iter 46: observed MAE=0.051702 rank=44
# [SoftImpute] Iter 47: observed MAE=0.051704 rank=44
# [SoftImpute] Iter 48: observed MAE=0.051706 rank=44
# [SoftImpute] Iter 49: observed MAE=0.051707 rank=44
# [SoftImpute] Iter 50: observed MAE=0.051709 rank=44
# [SoftImpute] Iter 51: observed MAE=0.051710 rank=44
# [SoftImpute] Iter 52: observed MAE=0.051711 rank=44
# [SoftImpute] Iter 53: observed MAE=0.051712 rank=44
# [SoftImpute] Iter 54: observed MAE=0.051713 rank=44
# [SoftImpute] Iter 55: observed MAE=0.051714 rank=44
# [SoftImpute] Iter 56: observed MAE=0.051715 rank=44
# [SoftImpute] Iter 57: observed MAE=0.051716 rank=44
# [SoftImpute] Iter 58: observed MAE=0.051717 rank=44
# [SoftImpute] Iter 59: observed MAE=0.051717 rank=44
# [SoftImpute] Iter 60: observed MAE=0.051718 rank=44
# [SoftImpute] Iter 61: observed MAE=0.051719 rank=44
# [SoftImpute] Iter 62: observed MAE=0.051719 rank=44
# [SoftImpute] Iter 63: observed MAE=0.051720 rank=44
# [SoftImpute] Iter 64: observed MAE=0.051720 rank=44
# [SoftImpute] Iter 65: observed MAE=0.051720 rank=44
# [SoftImpute] Iter 66: observed MAE=0.051721 rank=44
# [SoftImpute] Iter 67: observed MAE=0.051721 rank=44
# [SoftImpute] Stopped after iteration 67 for lambda=1.014331
# [SoftImpute] Max Singular Value of X_init = 50.461681
# [SoftImpute] Iter 1: observed MAE=0.048521 rank=44
# [SoftImpute] Iter 2: observed MAE=0.048856 rank=44
# [SoftImpute] Iter 3: observed MAE=0.049169 rank=44
# [SoftImpute] Iter 4: observed MAE=0.049457 rank=44
# [SoftImpute] Iter 5: observed MAE=0.049721 rank=44
# [SoftImpute] Iter 6: observed MAE=0.049958 rank=44
# [SoftImpute] Iter 7: observed MAE=0.050170 rank=44
# [SoftImpute] Iter 8: observed MAE=0.050359 rank=44
# [SoftImpute] Iter 9: observed MAE=0.050525 rank=44
# [SoftImpute] Iter 10: observed MAE=0.050670 rank=44
# [SoftImpute] Iter 11: observed MAE=0.050795 rank=44
# [SoftImpute] Iter 12: observed MAE=0.050903 rank=44
# [SoftImpute] Iter 13: observed MAE=0.050994 rank=44
# [SoftImpute] Iter 14: observed MAE=0.051070 rank=44
# [SoftImpute] Iter 15: observed MAE=0.051134 rank=44
# [SoftImpute] Iter 16: observed MAE=0.051188 rank=44
# [SoftImpute] Iter 17: observed MAE=0.051236 rank=44
# [SoftImpute] Iter 18: observed MAE=0.051278 rank=44
# [SoftImpute] Iter 19: observed MAE=0.051313 rank=44
# [SoftImpute] Iter 20: observed MAE=0.051343 rank=44
# [SoftImpute] Iter 21: observed MAE=0.051369 rank=44
# [SoftImpute] Iter 22: observed MAE=0.051391 rank=44
# [SoftImpute] Iter 23: observed MAE=0.051410 rank=44
# [SoftImpute] Iter 24: observed MAE=0.051427 rank=44
# [SoftImpute] Iter 25: observed MAE=0.051442 rank=44
# [SoftImpute] Iter 26: observed MAE=0.051455 rank=44
# [SoftImpute] Iter 27: observed MAE=0.051466 rank=44
# [SoftImpute] Iter 28: observed MAE=0.051476 rank=44
# [SoftImpute] Iter 29: observed MAE=0.051484 rank=44
# [SoftImpute] Iter 30: observed MAE=0.051492 rank=44
# [SoftImpute] Iter 31: observed MAE=0.051499 rank=44
# [SoftImpute] Iter 32: observed MAE=0.051505 rank=44
# [SoftImpute] Iter 33: observed MAE=0.051510 rank=44
# [SoftImpute] Iter 34: observed MAE=0.051515 rank=44
# [SoftImpute] Iter 35: observed MAE=0.051519 rank=44
# [SoftImpute] Iter 36: observed MAE=0.051524 rank=44
# [SoftImpute] Iter 37: observed MAE=0.051527 rank=44
# [SoftImpute] Iter 38: observed MAE=0.051531 rank=44
# [SoftImpute] Iter 39: observed MAE=0.051534 rank=44
# [SoftImpute] Iter 40: observed MAE=0.051537 rank=44
# [SoftImpute] Iter 41: observed MAE=0.051539 rank=44
# [SoftImpute] Iter 42: observed MAE=0.051542 rank=44
# [SoftImpute] Iter 43: observed MAE=0.051544 rank=44
# [SoftImpute] Iter 44: observed MAE=0.051545 rank=44
# [SoftImpute] Iter 45: observed MAE=0.051547 rank=44
# [SoftImpute] Iter 46: observed MAE=0.051549 rank=44
# [SoftImpute] Iter 47: observed MAE=0.051550 rank=44
# [SoftImpute] Iter 48: observed MAE=0.051552 rank=44
# [SoftImpute] Iter 49: observed MAE=0.051553 rank=44
# [SoftImpute] Iter 50: observed MAE=0.051554 rank=44
# [SoftImpute] Iter 51: observed MAE=0.051555 rank=44
# [SoftImpute] Iter 52: observed MAE=0.051556 rank=44
# [SoftImpute] Iter 53: observed MAE=0.051557 rank=44
# [SoftImpute] Iter 54: observed MAE=0.051558 rank=44
# [SoftImpute] Iter 55: observed MAE=0.051559 rank=44
# [SoftImpute] Iter 56: observed MAE=0.051560 rank=44
# [SoftImpute] Iter 57: observed MAE=0.051561 rank=44
# [SoftImpute] Iter 58: observed MAE=0.051561 rank=44
# [SoftImpute] Iter 59: observed MAE=0.051562 rank=44
# [SoftImpute] Iter 60: observed MAE=0.051563 rank=44
# [SoftImpute] Iter 61: observed MAE=0.051563 rank=44
# [SoftImpute] Iter 62: observed MAE=0.051564 rank=44
# [SoftImpute] Iter 63: observed MAE=0.051564 rank=44
# [SoftImpute] Iter 64: observed MAE=0.051565 rank=44
# [SoftImpute] Iter 65: observed MAE=0.051565 rank=44
# [SoftImpute] Iter 66: observed MAE=0.051566 rank=44
# [SoftImpute] Stopped after iteration 66 for lambda=1.009234
# [SoftImpute] Max Singular Value of X_init = 44.144638
# [SoftImpute] Iter 1: observed MAE=0.045683 rank=44
# [SoftImpute] Iter 2: observed MAE=0.045933 rank=44
# [SoftImpute] Iter 3: observed MAE=0.046169 rank=44
# [SoftImpute] Iter 4: observed MAE=0.046391 rank=44
# [SoftImpute] Iter 5: observed MAE=0.046599 rank=44
# [SoftImpute] Iter 6: observed MAE=0.046795 rank=44
# [SoftImpute] Iter 7: observed MAE=0.046978 rank=44
# [SoftImpute] Iter 8: observed MAE=0.047148 rank=44
# [SoftImpute] Iter 9: observed MAE=0.047304 rank=44
# [SoftImpute] Iter 10: observed MAE=0.047449 rank=44
# [SoftImpute] Iter 11: observed MAE=0.047581 rank=44
# [SoftImpute] Iter 12: observed MAE=0.047703 rank=44
# [SoftImpute] Iter 13: observed MAE=0.047815 rank=44
# [SoftImpute] Iter 14: observed MAE=0.047921 rank=44
# [SoftImpute] Iter 15: observed MAE=0.048018 rank=44
# [SoftImpute] Iter 16: observed MAE=0.048106 rank=44
# [SoftImpute] Iter 17: observed MAE=0.048185 rank=44
# [SoftImpute] Iter 18: observed MAE=0.048257 rank=44
# [SoftImpute] Iter 19: observed MAE=0.048323 rank=44
# [SoftImpute] Iter 20: observed MAE=0.048381 rank=44
# [SoftImpute] Iter 21: observed MAE=0.048433 rank=44
# [SoftImpute] Iter 22: observed MAE=0.048482 rank=44
# [SoftImpute] Iter 23: observed MAE=0.048525 rank=44
# [SoftImpute] Iter 24: observed MAE=0.048562 rank=44
# [SoftImpute] Iter 25: observed MAE=0.048596 rank=44
# [SoftImpute] Iter 26: observed MAE=0.048626 rank=44
# [SoftImpute] Iter 27: observed MAE=0.048654 rank=44
# [SoftImpute] Iter 28: observed MAE=0.048679 rank=44
# [SoftImpute] Iter 29: observed MAE=0.048702 rank=44
# [SoftImpute] Iter 30: observed MAE=0.048724 rank=44
# [SoftImpute] Iter 31: observed MAE=0.048744 rank=44
# [SoftImpute] Iter 32: observed MAE=0.048763 rank=44
# [SoftImpute] Iter 33: observed MAE=0.048780 rank=44
# [SoftImpute] Iter 34: observed MAE=0.048795 rank=44
# [SoftImpute] Iter 35: observed MAE=0.048808 rank=44
# [SoftImpute] Iter 36: observed MAE=0.048821 rank=44
# [SoftImpute] Iter 37: observed MAE=0.048832 rank=44
# [SoftImpute] Iter 38: observed MAE=0.048843 rank=44
# [SoftImpute] Iter 39: observed MAE=0.048852 rank=44
# [SoftImpute] Iter 40: observed MAE=0.048861 rank=44
# [SoftImpute] Iter 41: observed MAE=0.048869 rank=44
# [SoftImpute] Iter 42: observed MAE=0.048877 rank=44
# [SoftImpute] Iter 43: observed MAE=0.048884 rank=44
# [SoftImpute] Iter 44: observed MAE=0.048891 rank=44
# [SoftImpute] Iter 45: observed MAE=0.048897 rank=44
# [SoftImpute] Iter 46: observed MAE=0.048903 rank=44
# [SoftImpute] Iter 47: observed MAE=0.048908 rank=44
# [SoftImpute] Iter 48: observed MAE=0.048914 rank=44
# [SoftImpute] Iter 49: observed MAE=0.048918 rank=44
# [SoftImpute] Iter 50: observed MAE=0.048923 rank=44
# [SoftImpute] Iter 51: observed MAE=0.048927 rank=44
# [SoftImpute] Iter 52: observed MAE=0.048931 rank=44
# [SoftImpute] Iter 53: observed MAE=0.048934 rank=44
# [SoftImpute] Iter 54: observed MAE=0.048938 rank=44
# [SoftImpute] Iter 55: observed MAE=0.048941 rank=44
# [SoftImpute] Iter 56: observed MAE=0.048944 rank=44
# [SoftImpute] Iter 57: observed MAE=0.048946 rank=44
# [SoftImpute] Iter 58: observed MAE=0.048949 rank=44
# [SoftImpute] Iter 59: observed MAE=0.048951 rank=44
# [SoftImpute] Iter 60: observed MAE=0.048953 rank=44
# [SoftImpute] Iter 61: observed MAE=0.048955 rank=44
# [SoftImpute] Iter 62: observed MAE=0.048957 rank=44
# [SoftImpute] Iter 63: observed MAE=0.048959 rank=44
# [SoftImpute] Iter 64: observed MAE=0.048960 rank=44
# [SoftImpute] Iter 65: observed MAE=0.048962 rank=44
# [SoftImpute] Iter 66: observed MAE=0.048963 rank=44
# [SoftImpute] Iter 67: observed MAE=0.048965 rank=44
# [SoftImpute] Iter 68: observed MAE=0.048966 rank=44
# [SoftImpute] Iter 69: observed MAE=0.048967 rank=44
# [SoftImpute] Iter 70: observed MAE=0.048968 rank=44
# [SoftImpute] Iter 71: observed MAE=0.048969 rank=44
# [SoftImpute] Iter 72: observed MAE=0.048970 rank=44
# [SoftImpute] Iter 73: observed MAE=0.048971 rank=44
# [SoftImpute] Iter 74: observed MAE=0.048972 rank=44
# [SoftImpute] Iter 75: observed MAE=0.048973 rank=44
# [SoftImpute] Iter 76: observed MAE=0.048973 rank=44
# [SoftImpute] Iter 77: observed MAE=0.048974 rank=44
# [SoftImpute] Iter 78: observed MAE=0.048975 rank=44
# [SoftImpute] Iter 79: observed MAE=0.048976 rank=44
# [SoftImpute] Iter 80: observed MAE=0.048976 rank=44
# [SoftImpute] Iter 81: observed MAE=0.048977 rank=44
# [SoftImpute] Iter 82: observed MAE=0.048978 rank=44
# [SoftImpute] Iter 83: observed MAE=0.048978 rank=44
# [SoftImpute] Stopped after iteration 83 for lambda=0.882893
# [SoftImpute] Max Singular Value of X_init = 44.029091
# [SoftImpute] Iter 1: observed MAE=0.045232 rank=44
# [SoftImpute] Iter 2: observed MAE=0.045480 rank=44
# [SoftImpute] Iter 3: observed MAE=0.045718 rank=44
# [SoftImpute] Iter 4: observed MAE=0.045944 rank=44
# [SoftImpute] Iter 5: observed MAE=0.046161 rank=44
# [SoftImpute] Iter 6: observed MAE=0.046367 rank=44
# [SoftImpute] Iter 7: observed MAE=0.046560 rank=44
# [SoftImpute] Iter 8: observed MAE=0.046741 rank=44
# [SoftImpute] Iter 9: observed MAE=0.046909 rank=44
# [SoftImpute] Iter 10: observed MAE=0.047067 rank=44
# [SoftImpute] Iter 11: observed MAE=0.047213 rank=44
# [SoftImpute] Iter 12: observed MAE=0.047344 rank=44
# [SoftImpute] Iter 13: observed MAE=0.047464 rank=44
# [SoftImpute] Iter 14: observed MAE=0.047571 rank=44
# [SoftImpute] Iter 15: observed MAE=0.047665 rank=44
# [SoftImpute] Iter 16: observed MAE=0.047751 rank=44
# [SoftImpute] Iter 17: observed MAE=0.047831 rank=44
# [SoftImpute] Iter 18: observed MAE=0.047904 rank=44
# [SoftImpute] Iter 19: observed MAE=0.047970 rank=44
# [SoftImpute] Iter 20: observed MAE=0.048029 rank=44
# [SoftImpute] Iter 21: observed MAE=0.048083 rank=44
# [SoftImpute] Iter 22: observed MAE=0.048132 rank=44
# [SoftImpute] Iter 23: observed MAE=0.048176 rank=44
# [SoftImpute] Iter 24: observed MAE=0.048216 rank=44
# [SoftImpute] Iter 25: observed MAE=0.048252 rank=44
# [SoftImpute] Iter 26: observed MAE=0.048284 rank=44
# [SoftImpute] Iter 27: observed MAE=0.048313 rank=44
# [SoftImpute] Iter 28: observed MAE=0.048340 rank=44
# [SoftImpute] Iter 29: observed MAE=0.048363 rank=44
# [SoftImpute] Iter 30: observed MAE=0.048385 rank=44
# [SoftImpute] Iter 31: observed MAE=0.048403 rank=44
# [SoftImpute] Iter 32: observed MAE=0.048420 rank=44
# [SoftImpute] Iter 33: observed MAE=0.048435 rank=44
# [SoftImpute] Iter 34: observed MAE=0.048449 rank=44
# [SoftImpute] Iter 35: observed MAE=0.048461 rank=44
# [SoftImpute] Iter 36: observed MAE=0.048472 rank=44
# [SoftImpute] Iter 37: observed MAE=0.048482 rank=44
# [SoftImpute] Iter 38: observed MAE=0.048491 rank=44
# [SoftImpute] Iter 39: observed MAE=0.048499 rank=44
# [SoftImpute] Iter 40: observed MAE=0.048507 rank=44
# [SoftImpute] Iter 41: observed MAE=0.048513 rank=44
# [SoftImpute] Iter 42: observed MAE=0.048520 rank=44
# [SoftImpute] Iter 43: observed MAE=0.048525 rank=44
# [SoftImpute] Iter 44: observed MAE=0.048530 rank=44
# [SoftImpute] Iter 45: observed MAE=0.048535 rank=44
# [SoftImpute] Iter 46: observed MAE=0.048539 rank=44
# [SoftImpute] Iter 47: observed MAE=0.048543 rank=44
# [SoftImpute] Iter 48: observed MAE=0.048546 rank=44
# [SoftImpute] Iter 49: observed MAE=0.048550 rank=44
# [SoftImpute] Iter 50: observed MAE=0.048553 rank=44
# [SoftImpute] Iter 51: observed MAE=0.048555 rank=44
# [SoftImpute] Iter 52: observed MAE=0.048558 rank=44
# [SoftImpute] Iter 53: observed MAE=0.048560 rank=44
# [SoftImpute] Iter 54: observed MAE=0.048563 rank=44
# [SoftImpute] Iter 55: observed MAE=0.048565 rank=44
# [SoftImpute] Iter 56: observed MAE=0.048567 rank=44
# [SoftImpute] Iter 57: observed MAE=0.048568 rank=44
# [SoftImpute] Iter 58: observed MAE=0.048570 rank=44
# [SoftImpute] Iter 59: observed MAE=0.048572 rank=44
# [SoftImpute] Iter 60: observed MAE=0.048573 rank=44
# [SoftImpute] Iter 61: observed MAE=0.048574 rank=44
# [SoftImpute] Iter 62: observed MAE=0.048576 rank=44
# [SoftImpute] Iter 63: observed MAE=0.048577 rank=44
# [SoftImpute] Iter 64: observed MAE=0.048578 rank=44
# [SoftImpute] Iter 65: observed MAE=0.048579 rank=44
# [SoftImpute] Iter 66: observed MAE=0.048580 rank=44
# [SoftImpute] Iter 67: observed MAE=0.048581 rank=44
# [SoftImpute] Iter 68: observed MAE=0.048581 rank=44
# [SoftImpute] Iter 69: observed MAE=0.048582 rank=44
# [SoftImpute] Iter 70: observed MAE=0.048583 rank=44
# [SoftImpute] Iter 71: observed MAE=0.048583 rank=44
# [SoftImpute] Iter 72: observed MAE=0.048584 rank=44
# [SoftImpute] Iter 73: observed MAE=0.048585 rank=44
# [SoftImpute] Iter 74: observed MAE=0.048585 rank=44
# [SoftImpute] Iter 75: observed MAE=0.048586 rank=44
# [SoftImpute] Iter 76: observed MAE=0.048586 rank=44
# [SoftImpute] Iter 77: observed MAE=0.048587 rank=44
# [SoftImpute] Iter 78: observed MAE=0.048587 rank=44
# [SoftImpute] Iter 79: observed MAE=0.048588 rank=44
# [SoftImpute] Iter 80: observed MAE=0.048588 rank=44
# [SoftImpute] Iter 81: observed MAE=0.048589 rank=44
# [SoftImpute] Iter 82: observed MAE=0.048589 rank=44
# [SoftImpute] Iter 83: observed MAE=0.048589 rank=44
# [SoftImpute] Iter 84: observed MAE=0.048590 rank=44
# [SoftImpute] Iter 85: observed MAE=0.048590 rank=44
# [SoftImpute] Iter 86: observed MAE=0.048590 rank=44
# [SoftImpute] Stopped after iteration 86 for lambda=0.880582
# [SoftImpute] Max Singular Value of X_init = 43.776466
# [SoftImpute] Iter 1: observed MAE=0.044847 rank=44
# [SoftImpute] Iter 2: observed MAE=0.045108 rank=44
# [SoftImpute] Iter 3: observed MAE=0.045359 rank=44
# [SoftImpute] Iter 4: observed MAE=0.045596 rank=44
# [SoftImpute] Iter 5: observed MAE=0.045817 rank=44
# [SoftImpute] Iter 6: observed MAE=0.046024 rank=44
# [SoftImpute] Iter 7: observed MAE=0.046218 rank=44
# [SoftImpute] Iter 8: observed MAE=0.046400 rank=44
# [SoftImpute] Iter 9: observed MAE=0.046570 rank=44
# [SoftImpute] Iter 10: observed MAE=0.046726 rank=44
# [SoftImpute] Iter 11: observed MAE=0.046869 rank=44
# [SoftImpute] Iter 12: observed MAE=0.046999 rank=44
# [SoftImpute] Iter 13: observed MAE=0.047117 rank=44
# [SoftImpute] Iter 14: observed MAE=0.047224 rank=44
# [SoftImpute] Iter 15: observed MAE=0.047321 rank=44
# [SoftImpute] Iter 16: observed MAE=0.047407 rank=44
# [SoftImpute] Iter 17: observed MAE=0.047484 rank=44
# [SoftImpute] Iter 18: observed MAE=0.047554 rank=44
# [SoftImpute] Iter 19: observed MAE=0.047616 rank=44
# [SoftImpute] Iter 20: observed MAE=0.047672 rank=44
# [SoftImpute] Iter 21: observed MAE=0.047721 rank=44
# [SoftImpute] Iter 22: observed MAE=0.047764 rank=44
# [SoftImpute] Iter 23: observed MAE=0.047802 rank=44
# [SoftImpute] Iter 24: observed MAE=0.047835 rank=44
# [SoftImpute] Iter 25: observed MAE=0.047865 rank=44
# [SoftImpute] Iter 26: observed MAE=0.047892 rank=44
# [SoftImpute] Iter 27: observed MAE=0.047916 rank=44
# [SoftImpute] Iter 28: observed MAE=0.047937 rank=44
# [SoftImpute] Iter 29: observed MAE=0.047955 rank=44
# [SoftImpute] Iter 30: observed MAE=0.047972 rank=44
# [SoftImpute] Iter 31: observed MAE=0.047988 rank=44
# [SoftImpute] Iter 32: observed MAE=0.048002 rank=44
# [SoftImpute] Iter 33: observed MAE=0.048014 rank=44
# [SoftImpute] Iter 34: observed MAE=0.048026 rank=44
# [SoftImpute] Iter 35: observed MAE=0.048037 rank=44
# [SoftImpute] Iter 36: observed MAE=0.048046 rank=44
# [SoftImpute] Iter 37: observed MAE=0.048055 rank=44
# [SoftImpute] Iter 38: observed MAE=0.048063 rank=44
# [SoftImpute] Iter 39: observed MAE=0.048070 rank=44
# [SoftImpute] Iter 40: observed MAE=0.048077 rank=44
# [SoftImpute] Iter 41: observed MAE=0.048083 rank=44
# [SoftImpute] Iter 42: observed MAE=0.048088 rank=44
# [SoftImpute] Iter 43: observed MAE=0.048093 rank=44
# [SoftImpute] Iter 44: observed MAE=0.048098 rank=44
# [SoftImpute] Iter 45: observed MAE=0.048102 rank=44
# [SoftImpute] Iter 46: observed MAE=0.048106 rank=44
# [SoftImpute] Iter 47: observed MAE=0.048110 rank=44
# [SoftImpute] Iter 48: observed MAE=0.048114 rank=44
# [SoftImpute] Iter 49: observed MAE=0.048117 rank=44
# [SoftImpute] Iter 50: observed MAE=0.048120 rank=44
# [SoftImpute] Iter 51: observed MAE=0.048123 rank=44
# [SoftImpute] Iter 52: observed MAE=0.048126 rank=44
# [SoftImpute] Iter 53: observed MAE=0.048128 rank=44
# [SoftImpute] Iter 54: observed MAE=0.048130 rank=44
# [SoftImpute] Iter 55: observed MAE=0.048133 rank=44
# [SoftImpute] Iter 56: observed MAE=0.048134 rank=44
# [SoftImpute] Iter 57: observed MAE=0.048136 rank=44
# [SoftImpute] Iter 58: observed MAE=0.048138 rank=44
# [SoftImpute] Iter 59: observed MAE=0.048140 rank=44
# [SoftImpute] Iter 60: observed MAE=0.048141 rank=44
# [SoftImpute] Iter 61: observed MAE=0.048143 rank=44
# [SoftImpute] Iter 62: observed MAE=0.048144 rank=44
# [SoftImpute] Iter 63: observed MAE=0.048145 rank=44
# [SoftImpute] Iter 64: observed MAE=0.048146 rank=44
# [SoftImpute] Iter 65: observed MAE=0.048147 rank=44
# [SoftImpute] Iter 66: observed MAE=0.048148 rank=44
# [SoftImpute] Iter 67: observed MAE=0.048149 rank=44
# [SoftImpute] Iter 68: observed MAE=0.048150 rank=44
# [SoftImpute] Iter 69: observed MAE=0.048151 rank=44
# [SoftImpute] Iter 70: observed MAE=0.048152 rank=44
# [SoftImpute] Iter 71: observed MAE=0.048153 rank=44
# [SoftImpute] Iter 72: observed MAE=0.048154 rank=44
# [SoftImpute] Iter 73: observed MAE=0.048154 rank=44
# [SoftImpute] Iter 74: observed MAE=0.048155 rank=44
# [SoftImpute] Iter 75: observed MAE=0.048156 rank=44
# ...
# [SoftImpute] Iter 1: observed MAE=0.037052 rank=44
# [SoftImpute] Iter 2: observed MAE=0.037151 rank=44
# [SoftImpute] Iter 3: observed MAE=0.037248 rank=44
# [SoftImpute] Iter 4: observed MAE=0.037343 rank=44
# [SoftImpute] Iter 5: observed MAE=0.037434 rank=44
# [SoftImpute] Iter 6: observed MAE=0.037520 rank=44
# [SoftImpute] Iter 7: observed MAE=0.037604 rank=44
# [SoftImpute] Iter 8: observed MAE=0.037685 rank=44
# [SoftImpute] Iter 9: observed MAE=0.037765 rank=44
# [SoftImpute] Iter 10: observed MAE=0.037842 rank=44
# [SoftImpute] Iter 11: observed MAE=0.037916 rank=44
# [SoftImpute] Iter 12: observed MAE=0.037988 rank=44
# [SoftImpute] Iter 13: observed MAE=0.038056 rank=44
# [SoftImpute] Iter 14: observed MAE=0.038121 rank=44
# [SoftImpute] Iter 15: observed MAE=0.038181 rank=44
# [SoftImpute] Iter 16: observed MAE=0.038239 rank=44
# [SoftImpute] Iter 17: observed MAE=0.038294 rank=44
# [SoftImpute] Iter 18: observed MAE=0.038347 rank=44
# [SoftImpute] Iter 19: observed MAE=0.038398 rank=44
# [SoftImpute] Iter 20: observed MAE=0.038446 rank=44
# [SoftImpute] Iter 21: observed MAE=0.038493 rank=44
# [SoftImpute] Iter 22: observed MAE=0.038538 rank=44
# [SoftImpute] Iter 23: observed MAE=0.038582 rank=44
# [SoftImpute] Iter 24: observed MAE=0.038625 rank=44
# [SoftImpute] Iter 25: observed MAE=0.038666 rank=44
# [SoftImpute] Iter 26: observed MAE=0.038706 rank=44
# [SoftImpute] Iter 27: observed MAE=0.038744 rank=44
# [SoftImpute] Iter 28: observed MAE=0.038781 rank=44
# [SoftImpute] Iter 29: observed MAE=0.038814 rank=44
# [SoftImpute] Iter 30: observed MAE=0.038847 rank=44
# [SoftImpute] Iter 31: observed MAE=0.038878 rank=44
# [SoftImpute] Iter 32: observed MAE=0.038907 rank=44
# [SoftImpute] Iter 33: observed MAE=0.038935 rank=44
# [SoftImpute] Iter 34: observed MAE=0.038960 rank=44
# [SoftImpute] Iter 35: observed MAE=0.038985 rank=44
# [SoftImpute] Iter 36: observed MAE=0.039010 rank=44
# [SoftImpute] Iter 37: observed MAE=0.039033 rank=44
# [SoftImpute] Iter 38: observed MAE=0.039056 rank=44
# [SoftImpute] Iter 39: observed MAE=0.039077 rank=44
# [SoftImpute] Iter 40: observed MAE=0.039097 rank=44
# [SoftImpute] Iter 41: observed MAE=0.039116 rank=44
# [SoftImpute] Iter 42: observed MAE=0.039133 rank=44
# [SoftImpute] Iter 43: observed MAE=0.039150 rank=44
# [SoftImpute] Iter 44: observed MAE=0.039167 rank=44
# [SoftImpute] Iter 45: observed MAE=0.039183 rank=44
# [SoftImpute] Iter 46: observed MAE=0.039198 rank=44
# [SoftImpute] Iter 47: observed MAE=0.039212 rank=44
# [SoftImpute] Iter 48: observed MAE=0.039226 rank=44
# [SoftImpute] Iter 49: observed MAE=0.039239 rank=44
# [SoftImpute] Iter 50: observed MAE=0.039252 rank=44
# [SoftImpute] Iter 51: observed MAE=0.039247 rank=43
# [SoftImpute] Iter 52: observed MAE=0.039224 rank=43
# [SoftImpute] Iter 53: observed MAE=0.039219 rank=43
# [SoftImpute] Iter 54: observed MAE=0.039221 rank=43
# [SoftImpute] Iter 55: observed MAE=0.039226 rank=43
# [SoftImpute] Iter 56: observed MAE=0.039231 rank=43
# [SoftImpute] Iter 57: observed MAE=0.039237 rank=43
# [SoftImpute] Iter 58: observed MAE=0.039243 rank=43
# [SoftImpute] Iter 59: observed MAE=0.039249 rank=43
# [SoftImpute] Iter 60: observed MAE=0.039251 rank=42
# [SoftImpute] Iter 61: observed MAE=0.039224 rank=42
# [SoftImpute] Iter 62: observed MAE=0.039216 rank=42
# [SoftImpute] Iter 63: observed MAE=0.039216 rank=42
# [SoftImpute] Iter 64: observed MAE=0.039219 rank=42
# [SoftImpute] Iter 65: observed MAE=0.039223 rank=42
# [SoftImpute] Iter 66: observed MAE=0.039228 rank=42
# [SoftImpute] Iter 67: observed MAE=0.039233 rank=42
# [SoftImpute] Iter 68: observed MAE=0.039238 rank=42
# [SoftImpute] Iter 69: observed MAE=0.039243 rank=42
# [SoftImpute] Iter 70: observed MAE=0.039248 rank=42
# [SoftImpute] Iter 71: observed MAE=0.039253 rank=42
# [SoftImpute] Iter 72: observed MAE=0.039258 rank=42
# [SoftImpute] Iter 73: observed MAE=0.039263 rank=42
# [SoftImpute] Iter 74: observed MAE=0.039268 rank=42
# [SoftImpute] Iter 75: observed MAE=0.039273 rank=42
# [SoftImpute] Iter 76: observed MAE=0.039278 rank=42
# [SoftImpute] Iter 77: observed MAE=0.039282 rank=42
# [SoftImpute] Iter 78: observed MAE=0.039286 rank=42
# [SoftImpute] Iter 79: observed MAE=0.039290 rank=42
# [SoftImpute] Iter 80: observed MAE=0.039294 rank=42
# [SoftImpute] Iter 81: observed MAE=0.039298 rank=42
# [SoftImpute] Iter 82: observed MAE=0.039302 rank=42
# [SoftImpute] Iter 83: observed MAE=0.039305 rank=42
# [SoftImpute] Iter 84: observed MAE=0.039309 rank=42
# [SoftImpute] Iter 85: observed MAE=0.039312 rank=42
# [SoftImpute] Iter 86: observed MAE=0.039315 rank=42
# [SoftImpute] Iter 87: observed MAE=0.039318 rank=42
# [SoftImpute] Iter 88: observed MAE=0.039321 rank=42
# [SoftImpute] Iter 89: observed MAE=0.039324 rank=42
# [SoftImpute] Iter 90: observed MAE=0.039327 rank=42
# [SoftImpute] Iter 91: observed MAE=0.039329 rank=42
# [SoftImpute] Iter 92: observed MAE=0.039332 rank=42
# [SoftImpute] Iter 93: observed MAE=0.039335 rank=42
# [SoftImpute] Iter 94: observed MAE=0.039337 rank=42
# [SoftImpute] Iter 95: observed MAE=0.039340 rank=42
# [SoftImpute] Iter 96: observed MAE=0.039342 rank=42
# [SoftImpute] Iter 97: observed MAE=0.039345 rank=42
# [SoftImpute] Iter 98: observed MAE=0.039347 rank=42
# [SoftImpute] Iter 99: observed MAE=0.039349 rank=42
# [SoftImpute] Iter 100: observed MAE=0.039351 rank=42
# [SoftImpute] Stopped after iteration 100 for lambda=0.567659
# [SoftImpute] Max Singular Value of X_init = 28.533730
# [SoftImpute] Iter 1: observed MAE=0.037114 rank=44
# [SoftImpute] Iter 2: observed MAE=0.037214 rank=44
# [SoftImpute] Iter 3: observed MAE=0.037312 rank=44
# [SoftImpute] Iter 4: observed MAE=0.037409 rank=44
# [SoftImpute] Iter 5: observed MAE=0.037503 rank=44
# [SoftImpute] Iter 6: observed MAE=0.037595 rank=44
# [SoftImpute] Iter 7: observed MAE=0.037684 rank=44
# [SoftImpute] Iter 8: observed MAE=0.037770 rank=44
# [SoftImpute] Iter 9: observed MAE=0.037851 rank=44
# [SoftImpute] Iter 10: observed MAE=0.037930 rank=44
# [SoftImpute] Iter 11: observed MAE=0.038005 rank=44
# [SoftImpute] Iter 12: observed MAE=0.038077 rank=44
# [SoftImpute] Iter 13: observed MAE=0.038149 rank=44
# [SoftImpute] Iter 14: observed MAE=0.038217 rank=44
# [SoftImpute] Iter 15: observed MAE=0.038284 rank=44
# [SoftImpute] Iter 16: observed MAE=0.038347 rank=44
# [SoftImpute] Iter 17: observed MAE=0.038407 rank=44
# [SoftImpute] Iter 18: observed MAE=0.038465 rank=44
# [SoftImpute] Iter 19: observed MAE=0.038520 rank=44
# [SoftImpute] Iter 20: observed MAE=0.038571 rank=44
# [SoftImpute] Iter 21: observed MAE=0.038619 rank=44
# [SoftImpute] Iter 22: observed MAE=0.038662 rank=44
# [SoftImpute] Iter 23: observed MAE=0.038703 rank=44
# [SoftImpute] Iter 24: observed MAE=0.038743 rank=44
# [SoftImpute] Iter 25: observed MAE=0.038780 rank=44
# [SoftImpute] Iter 26: observed MAE=0.038815 rank=44
# [SoftImpute] Iter 27: observed MAE=0.038849 rank=44
# [SoftImpute] Iter 28: observed MAE=0.038881 rank=44
# [SoftImpute] Iter 29: observed MAE=0.038912 rank=44
# [SoftImpute] Iter 30: observed MAE=0.038942 rank=44
# [SoftImpute] Iter 31: observed MAE=0.038969 rank=44
# [SoftImpute] Iter 32: observed MAE=0.038996 rank=44
# [SoftImpute] Iter 33: observed MAE=0.039022 rank=44
# [SoftImpute] Iter 34: observed MAE=0.039046 rank=44
# [SoftImpute] Iter 35: observed MAE=0.039069 rank=44
# [SoftImpute] Iter 36: observed MAE=0.039092 rank=44
# [SoftImpute] Iter 37: observed MAE=0.039113 rank=44
# [SoftImpute] Iter 38: observed MAE=0.039133 rank=44
# [SoftImpute] Iter 39: observed MAE=0.039152 rank=44
# [SoftImpute] Iter 40: observed MAE=0.039170 rank=44
# [SoftImpute] Iter 41: observed MAE=0.039187 rank=44
# [SoftImpute] Iter 42: observed MAE=0.039168 rank=43
# [SoftImpute] Iter 43: observed MAE=0.039150 rank=43
# [SoftImpute] Iter 44: observed MAE=0.039150 rank=43
# [SoftImpute] Iter 45: observed MAE=0.039155 rank=43
# [SoftImpute] Iter 46: observed MAE=0.039163 rank=43
# [SoftImpute] Iter 47: observed MAE=0.039173 rank=43
# [SoftImpute] Iter 48: observed MAE=0.039182 rank=43
# [SoftImpute] Iter 49: observed MAE=0.039192 rank=43
# [SoftImpute] Iter 50: observed MAE=0.039201 rank=43
# [SoftImpute] Iter 51: observed MAE=0.039210 rank=43
# [SoftImpute] Iter 52: observed MAE=0.039218 rank=43
# [SoftImpute] Iter 53: observed MAE=0.039226 rank=43
# [SoftImpute] Iter 54: observed MAE=0.039234 rank=43
# [SoftImpute] Iter 55: observed MAE=0.039242 rank=43
# [SoftImpute] Iter 56: observed MAE=0.039249 rank=43
# [SoftImpute] Iter 57: observed MAE=0.039256 rank=43
# [SoftImpute] Iter 58: observed MAE=0.039263 rank=43
# [SoftImpute] Iter 59: observed MAE=0.039269 rank=43
# [SoftImpute] Iter 60: observed MAE=0.039275 rank=43
# [SoftImpute] Iter 61: observed MAE=0.039280 rank=43
# [SoftImpute] Iter 62: observed MAE=0.039285 rank=43
# [SoftImpute] Iter 63: observed MAE=0.039290 rank=43
# [SoftImpute] Iter 64: observed MAE=0.039295 rank=43
# [SoftImpute] Iter 65: observed MAE=0.039299 rank=43
# [SoftImpute] Iter 66: observed MAE=0.039304 rank=43
# [SoftImpute] Iter 67: observed MAE=0.039308 rank=43
# [SoftImpute] Iter 68: observed MAE=0.039313 rank=43
# [SoftImpute] Iter 69: observed MAE=0.039317 rank=43
# [SoftImpute] Iter 70: observed MAE=0.039321 rank=43
# [SoftImpute] Iter 71: observed MAE=0.039308 rank=42
# [SoftImpute] Iter 72: observed MAE=0.039292 rank=42
# [SoftImpute] Iter 73: observed MAE=0.039286 rank=42
# [SoftImpute] Iter 74: observed MAE=0.039284 rank=42
# [SoftImpute] Iter 75: observed MAE=0.039285 rank=42
# [SoftImpute] Iter 76: observed MAE=0.039286 rank=42
# [SoftImpute] Iter 77: observed MAE=0.039288 rank=42
# [SoftImpute] Iter 78: observed MAE=0.039289 rank=42
# [SoftImpute] Iter 79: observed MAE=0.039291 rank=42
# [SoftImpute] Iter 80: observed MAE=0.039293 rank=42
# [SoftImpute] Iter 81: observed MAE=0.039296 rank=42
# [SoftImpute] Iter 82: observed MAE=0.039298 rank=42
# [SoftImpute] Iter 83: observed MAE=0.039300 rank=42
# [SoftImpute] Iter 84: observed MAE=0.039302 rank=42
# [SoftImpute] Iter 85: observed MAE=0.039304 rank=42
# [SoftImpute] Iter 86: observed MAE=0.039306 rank=42
# [SoftImpute] Iter 87: observed MAE=0.039308 rank=42
# [SoftImpute] Iter 88: observed MAE=0.039310 rank=42
# [SoftImpute] Iter 89: observed MAE=0.039312 rank=42
# [SoftImpute] Iter 90: observed MAE=0.039314 rank=42
# [SoftImpute] Iter 91: observed MAE=0.039316 rank=42
# [SoftImpute] Iter 92: observed MAE=0.039318 rank=42
# [SoftImpute] Iter 93: observed MAE=0.039320 rank=42
# [SoftImpute] Iter 94: observed MAE=0.039322 rank=42
# [SoftImpute] Iter 95: observed MAE=0.039324 rank=42
# [SoftImpute] Iter 96: observed MAE=0.039325 rank=42
# [SoftImpute] Iter 97: observed MAE=0.039327 rank=42
# [SoftImpute] Iter 98: observed MAE=0.039329 rank=42
# [SoftImpute] Iter 99: observed MAE=0.039331 rank=42
# [SoftImpute] Iter 100: observed MAE=0.039332 rank=42
# [SoftImpute] Stopped after iteration 100 for lambda=0.570675
# [SoftImpute] Max Singular Value of X_init = 28.672047
# [SoftImpute] Iter 1: observed MAE=0.037402 rank=44
# [SoftImpute] Iter 2: observed MAE=0.037499 rank=44
# [SoftImpute] Iter 3: observed MAE=0.037594 rank=44
# [SoftImpute] Iter 4: observed MAE=0.037687 rank=44
# [SoftImpute] Iter 5: observed MAE=0.037777 rank=44
# [SoftImpute] Iter 6: observed MAE=0.037866 rank=44
# [SoftImpute] Iter 7: observed MAE=0.037952 rank=44
# [SoftImpute] Iter 8: observed MAE=0.038035 rank=44
# [SoftImpute] Iter 9: observed MAE=0.038115 rank=44
# [SoftImpute] Iter 10: observed MAE=0.038193 rank=44
# [SoftImpute] Iter 11: observed MAE=0.038267 rank=44
# [SoftImpute] Iter 12: observed MAE=0.038338 rank=44
# [SoftImpute] Iter 13: observed MAE=0.038407 rank=44
# [SoftImpute] Iter 14: observed MAE=0.038473 rank=44
# [SoftImpute] Iter 15: observed MAE=0.038538 rank=44
# [SoftImpute] Iter 16: observed MAE=0.038601 rank=44
# [SoftImpute] Iter 17: observed MAE=0.038660 rank=44
# [SoftImpute] Iter 18: observed MAE=0.038717 rank=44
# [SoftImpute] Iter 19: observed MAE=0.038771 rank=44
# [SoftImpute] Iter 20: observed MAE=0.038823 rank=44
# [SoftImpute] Iter 21: observed MAE=0.038871 rank=44
# [SoftImpute] Iter 22: observed MAE=0.038918 rank=44
# [SoftImpute] Iter 23: observed MAE=0.038961 rank=44
# [SoftImpute] Iter 24: observed MAE=0.039003 rank=44
# [SoftImpute] Iter 25: observed MAE=0.039042 rank=44
# [SoftImpute] Iter 26: observed MAE=0.039079 rank=44
# [SoftImpute] Iter 27: observed MAE=0.039114 rank=44
# [SoftImpute] Iter 28: observed MAE=0.039147 rank=44
# [SoftImpute] Iter 29: observed MAE=0.039177 rank=44
# [SoftImpute] Iter 30: observed MAE=0.039206 rank=44
# [SoftImpute] Iter 31: observed MAE=0.039233 rank=44
# [SoftImpute] Iter 32: observed MAE=0.039260 rank=44
# [SoftImpute] Iter 33: observed MAE=0.039285 rank=44
# [SoftImpute] Iter 34: observed MAE=0.039310 rank=44
# [SoftImpute] Iter 35: observed MAE=0.039334 rank=44
# [SoftImpute] Iter 36: observed MAE=0.039358 rank=44
# [SoftImpute] Iter 37: observed MAE=0.039380 rank=44
# [SoftImpute] Iter 38: observed MAE=0.039402 rank=44
# [SoftImpute] Iter 39: observed MAE=0.039424 rank=44
# [SoftImpute] Iter 40: observed MAE=0.039443 rank=44
# [SoftImpute] Iter 41: observed MAE=0.039462 rank=44
# [SoftImpute] Iter 42: observed MAE=0.039480 rank=44
# [SoftImpute] Iter 43: observed MAE=0.039446 rank=43
# [SoftImpute] Iter 44: observed MAE=0.039430 rank=43
# [SoftImpute] Iter 45: observed MAE=0.039430 rank=43
# [SoftImpute] Iter 46: observed MAE=0.039436 rank=43
# [SoftImpute] Iter 47: observed MAE=0.039444 rank=43
# [SoftImpute] Iter 48: observed MAE=0.039454 rank=43
# [SoftImpute] Iter 49: observed MAE=0.039464 rank=43
# [SoftImpute] Iter 50: observed MAE=0.039475 rank=43
# [SoftImpute] Iter 51: observed MAE=0.039485 rank=43
# [SoftImpute] Iter 52: observed MAE=0.039495 rank=43
# [SoftImpute] Iter 53: observed MAE=0.039505 rank=43
# [SoftImpute] Iter 54: observed MAE=0.039516 rank=43
# [SoftImpute] Iter 55: observed MAE=0.039505 rank=42
# [SoftImpute] Iter 56: observed MAE=0.039485 rank=42
# [SoftImpute] Iter 57: observed MAE=0.039479 rank=42
# [SoftImpute] Iter 58: observed MAE=0.039479 rank=42
# [SoftImpute] Iter 59: observed MAE=0.039482 rank=42
# [SoftImpute] Iter 60: observed MAE=0.039486 rank=42
# [SoftImpute] Iter 61: observed MAE=0.039492 rank=42
# [SoftImpute] Iter 62: observed MAE=0.039497 rank=42
# [SoftImpute] Iter 63: observed MAE=0.039503 rank=42
# [SoftImpute] Iter 64: observed MAE=0.039508 rank=42
# [SoftImpute] Iter 65: observed MAE=0.039514 rank=42
# [SoftImpute] Iter 66: observed MAE=0.039519 rank=42
# [SoftImpute] Iter 67: observed MAE=0.039524 rank=42
# [SoftImpute] Iter 68: observed MAE=0.039529 rank=42
# [SoftImpute] Iter 69: observed MAE=0.039534 rank=42
# [SoftImpute] Iter 70: observed MAE=0.039539 rank=42
# [SoftImpute] Iter 71: observed MAE=0.039544 rank=42
# [SoftImpute] Iter 72: observed MAE=0.039549 rank=42
# [SoftImpute] Iter 73: observed MAE=0.039553 rank=42
# [SoftImpute] Iter 74: observed MAE=0.039558 rank=42
# [SoftImpute] Iter 75: observed MAE=0.039562 rank=42
# [SoftImpute] Iter 76: observed MAE=0.039566 rank=42
# [SoftImpute] Iter 77: observed MAE=0.039570 rank=42
# [SoftImpute] Iter 78: observed MAE=0.039574 rank=42
# [SoftImpute] Iter 79: observed MAE=0.039577 rank=41
# [SoftImpute] Iter 80: observed MAE=0.039567 rank=41
# [SoftImpute] Iter 81: observed MAE=0.039565 rank=41
# [SoftImpute] Iter 82: observed MAE=0.039565 rank=41
# [SoftImpute] Iter 83: observed MAE=0.039567 rank=41
# [SoftImpute] Iter 84: observed MAE=0.039569 rank=41
# [SoftImpute] Iter 85: observed MAE=0.039571 rank=41
# [SoftImpute] Iter 86: observed MAE=0.039573 rank=41
# [SoftImpute] Iter 87: observed MAE=0.039576 rank=41
# [SoftImpute] Iter 88: observed MAE=0.039578 rank=41
# [SoftImpute] Iter 89: observed MAE=0.039580 rank=41
# [SoftImpute] Iter 90: observed MAE=0.039583 rank=41
# [SoftImpute] Iter 91: observed MAE=0.039585 rank=41
# [SoftImpute] Iter 92: observed MAE=0.039587 rank=41
# [SoftImpute] Iter 93: observed MAE=0.039589 rank=41
# [SoftImpute] Iter 94: observed MAE=0.039592 rank=41
# [SoftImpute] Iter 95: observed MAE=0.039594 rank=41
# [SoftImpute] Iter 96: observed MAE=0.039596 rank=41
# [SoftImpute] Iter 97: observed MAE=0.039598 rank=41
# [SoftImpute] Iter 98: observed MAE=0.039601 rank=41
# [SoftImpute] Iter 99: observed MAE=0.039603 rank=41
# [SoftImpute] Iter 100: observed MAE=0.039605 rank=41
# [SoftImpute] Stopped after iteration 100 for lambda=0.573441
# array([[0.002, 0.   ],
#        [0.003, 0.   ],
#        [0.004, 0.   ],
#        [0.005, 0.001],
#        [0.007, 0.001]])

# %% [markdown]
# # Inosphere

# %%
data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/ionosphere/ionosphere.data',
                  sep = ",", header = None)
# print(data.head())
data = pd.DataFrame.to_numpy(data)
X, y = data[:,:34].astype(np.float64), data[:,34]
le2 = LabelEncoder()
y = le2.fit_transform(y)
print(len(y))
X = np.delete(X,[0,1], axis = 1)
X.shape
# Out:
# 351
# (351, 32)

# %%
G = 2
mle_err = np.array([compute_err_mle(X, y, G, .2, runs = 10),
                    compute_err_mle(X, y, G, .35, runs = 10),
                    compute_err_mle(X, y, G, .5, runs = 10),
                    compute_err_mle(X, y, G, .65, runs = 10),
                    compute_err_mle(X, y, G, .8, runs = 10)])
mle_err.round(3)
# Out:
# array([[0.004, 0.   ],
#        [0.005, 0.   ],
#        [0.006, 0.   ],
#        [0.007, 0.001],
#        [0.008, 0.001]])

# %%
G = 2
mice_err = np.array([compute_err_mice(X, y, G, .2, runs = 10),
                    compute_err_mice(X, y, G, .35, runs = 10),
                    compute_err_mice(X, y, G, .5, runs = 10),
                    compute_err_mice(X, y, G, .65, runs = 10),
                    compute_err_mice(X, y, G, .8, runs = 10)])
mice_err.round(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# array([[0.004, 0.   ],
#        [0.005, 0.   ],
#        [0.006, 0.   ],
#        [0.007, 0.001],
#        [0.01 , 0.001]])

# %%
G = 2
soft_err = np.array([compute_err_soft(X, y, G, .2, runs = 10),
                    compute_err_soft(X, y, G, .35, runs = 10),
                    compute_err_soft(X, y, G, .5, runs = 10),
                    compute_err_soft(X, y, G, .65, runs = 10),
                    compute_err_soft(X, y, G, .8, runs = 10)])
soft_err.round(3)
# Out:
# [SoftImpute] Max Singular Value of X_init = 46.126626
# [SoftImpute] Iter 1: observed MAE=0.037561 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037606 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037645 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037677 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037704 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037725 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037742 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037754 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037762 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037767 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037767 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037764 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037758 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037749 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037739 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037726 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037713 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037699 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037683 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037667 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037652 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037636 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037620 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037604 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037589 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037574 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037559 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037546 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037532 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037520 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037508 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037497 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037486 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037476 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037466 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037457 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037448 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037440 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037432 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037425 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037418 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037412 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037406 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037401 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037395 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037391 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037386 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037382 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037378 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037374 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037370 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037367 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037364 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037361 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037358 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037356 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037353 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037351 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037349 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037347 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037345 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037343 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037341 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037340 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037338 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037337 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037335 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037334 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037333 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037332 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037331 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037330 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037329 rank=32
# [SoftImpute] Stopped after iteration 73 for lambda=0.922533
# [SoftImpute] Max Singular Value of X_init = 46.464770
# [SoftImpute] Iter 1: observed MAE=0.037769 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037812 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037849 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037879 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037902 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037918 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037928 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037934 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037935 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037933 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037926 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037917 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037905 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037891 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037876 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037860 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037842 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037825 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037806 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037788 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037769 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037751 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037733 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037716 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037700 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037684 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037668 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037654 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037640 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037627 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037614 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037602 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037591 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037581 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037571 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037561 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037553 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037545 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037537 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037529 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037523 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037516 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037510 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037504 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037499 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037494 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037489 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037485 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037481 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037477 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037473 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037470 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037467 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037464 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037461 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037459 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037456 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037454 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037452 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037450 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037448 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037446 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037445 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037443 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037442 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037440 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037439 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037438 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037437 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037436 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037435 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037434 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037433 rank=32
# [SoftImpute] Stopped after iteration 73 for lambda=0.929295
# [SoftImpute] Max Singular Value of X_init = 46.422948
# [SoftImpute] Iter 1: observed MAE=0.037746 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037793 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037832 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037865 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037890 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037910 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037925 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037935 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037941 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037943 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037942 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037938 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037931 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037921 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037909 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037895 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037880 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037865 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037850 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037833 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037817 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037801 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037785 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037770 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037755 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037740 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037726 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037713 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037700 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037687 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037676 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037664 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037653 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037643 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037634 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037625 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037616 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037608 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037600 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037593 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037586 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037580 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037573 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037568 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037562 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037557 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037552 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037548 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037544 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037540 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037536 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037533 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037530 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037527 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037524 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037521 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037519 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037517 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037514 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037512 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037510 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037509 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037507 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037505 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037504 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037502 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037501 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037500 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037499 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037498 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037497 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037496 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037495 rank=32
# [SoftImpute] Iter 74: observed MAE=0.037494 rank=32
# [SoftImpute] Iter 75: observed MAE=0.037493 rank=32
# [SoftImpute] Stopped after iteration 75 for lambda=0.928459
# [SoftImpute] Max Singular Value of X_init = 46.816202
# [SoftImpute] Iter 1: observed MAE=0.038116 rank=32
# [SoftImpute] Iter 2: observed MAE=0.038162 rank=32
# [SoftImpute] Iter 3: observed MAE=0.038198 rank=32
# [SoftImpute] Iter 4: observed MAE=0.038228 rank=32
# [SoftImpute] Iter 5: observed MAE=0.038250 rank=32
# [SoftImpute] Iter 6: observed MAE=0.038266 rank=32
# [SoftImpute] Iter 7: observed MAE=0.038277 rank=32
# [SoftImpute] Iter 8: observed MAE=0.038281 rank=32
# [SoftImpute] Iter 9: observed MAE=0.038280 rank=32
# [SoftImpute] Iter 10: observed MAE=0.038276 rank=32
# [SoftImpute] Iter 11: observed MAE=0.038268 rank=32
# [SoftImpute] Iter 12: observed MAE=0.038257 rank=32
# [SoftImpute] Iter 13: observed MAE=0.038243 rank=32
# [SoftImpute] Iter 14: observed MAE=0.038228 rank=32
# [SoftImpute] Iter 15: observed MAE=0.038210 rank=32
# [SoftImpute] Iter 16: observed MAE=0.038192 rank=32
# [SoftImpute] Iter 17: observed MAE=0.038172 rank=32
# [SoftImpute] Iter 18: observed MAE=0.038152 rank=32
# [SoftImpute] Iter 19: observed MAE=0.038132 rank=32
# [SoftImpute] Iter 20: observed MAE=0.038112 rank=32
# [SoftImpute] Iter 21: observed MAE=0.038092 rank=32
# [SoftImpute] Iter 22: observed MAE=0.038072 rank=32
# [SoftImpute] Iter 23: observed MAE=0.038053 rank=32
# [SoftImpute] Iter 24: observed MAE=0.038034 rank=32
# [SoftImpute] Iter 25: observed MAE=0.038017 rank=32
# [SoftImpute] Iter 26: observed MAE=0.038000 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037984 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037969 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037954 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037941 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037928 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037915 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037903 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037892 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037881 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037871 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037862 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037853 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037845 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037837 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037830 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037823 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037816 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037810 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037805 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037799 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037794 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037789 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037785 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037781 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037777 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037773 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037770 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037766 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037763 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037760 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037758 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037755 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037753 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037751 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037749 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037747 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037745 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037743 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037742 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037740 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037739 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037737 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037736 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037735 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037734 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037733 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037732 rank=32
# [SoftImpute] Iter 74: observed MAE=0.037731 rank=32
# [SoftImpute] Stopped after iteration 74 for lambda=0.936324
# [SoftImpute] Max Singular Value of X_init = 45.571052
# [SoftImpute] Iter 1: observed MAE=0.037210 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037248 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037284 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037314 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037339 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037357 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037371 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037381 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037387 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037389 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037388 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037385 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037378 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037369 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037359 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037347 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037333 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037319 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037305 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037289 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037273 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037257 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037241 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037226 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037211 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037197 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037183 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037170 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037157 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037145 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037133 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037122 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037111 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037101 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037091 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037082 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037073 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037065 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037057 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037050 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037043 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037036 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037030 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037024 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037019 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037014 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037009 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037004 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037000 rank=32
# [SoftImpute] Iter 50: observed MAE=0.036996 rank=32
# [SoftImpute] Iter 51: observed MAE=0.036992 rank=32
# [SoftImpute] Iter 52: observed MAE=0.036989 rank=32
# [SoftImpute] Iter 53: observed MAE=0.036985 rank=32
# [SoftImpute] Iter 54: observed MAE=0.036982 rank=32
# [SoftImpute] Iter 55: observed MAE=0.036979 rank=32
# [SoftImpute] Iter 56: observed MAE=0.036977 rank=32
# [SoftImpute] Iter 57: observed MAE=0.036974 rank=32
# [SoftImpute] Iter 58: observed MAE=0.036972 rank=32
# [SoftImpute] Iter 59: observed MAE=0.036969 rank=32
# [SoftImpute] Iter 60: observed MAE=0.036967 rank=32
# [SoftImpute] Iter 61: observed MAE=0.036965 rank=32
# [SoftImpute] Iter 62: observed MAE=0.036963 rank=32
# [SoftImpute] Iter 63: observed MAE=0.036961 rank=32
# [SoftImpute] Iter 64: observed MAE=0.036960 rank=32
# [SoftImpute] Iter 65: observed MAE=0.036958 rank=32
# [SoftImpute] Iter 66: observed MAE=0.036956 rank=32
# [SoftImpute] Iter 67: observed MAE=0.036955 rank=32
# [SoftImpute] Iter 68: observed MAE=0.036954 rank=32
# [SoftImpute] Iter 69: observed MAE=0.036952 rank=32
# [SoftImpute] Iter 70: observed MAE=0.036951 rank=32
# [SoftImpute] Iter 71: observed MAE=0.036950 rank=32
# [SoftImpute] Iter 72: observed MAE=0.036949 rank=32
# [SoftImpute] Iter 73: observed MAE=0.036948 rank=32
# [SoftImpute] Iter 74: observed MAE=0.036947 rank=32
# [SoftImpute] Iter 75: observed MAE=0.036946 rank=32
# [SoftImpute] Stopped after iteration 75 for lambda=0.911421
# [SoftImpute] Max Singular Value of X_init = 46.108358
# [SoftImpute] Iter 1: observed MAE=0.037467 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037508 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037543 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037573 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037597 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037617 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037631 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037640 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037645 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037647 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037645 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037639 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037631 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037619 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037605 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037591 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037576 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037560 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037542 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037525 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037507 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037490 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037473 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037456 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037440 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037424 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037409 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037394 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037380 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037367 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037354 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037342 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037331 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037320 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037310 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037300 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037291 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037283 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037275 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037267 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037260 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037254 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037248 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037242 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037237 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037232 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037227 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037223 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037219 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037215 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037212 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037208 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037205 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037202 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037200 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037197 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037195 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037193 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037191 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037189 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037187 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037185 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037184 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037182 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037181 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037180 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037178 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037177 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037176 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037175 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037174 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037174 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037173 rank=32
# [SoftImpute] Iter 74: observed MAE=0.037172 rank=32
# [SoftImpute] Iter 75: observed MAE=0.037171 rank=32
# [SoftImpute] Stopped after iteration 75 for lambda=0.922167
# [SoftImpute] Max Singular Value of X_init = 46.480329
# [SoftImpute] Iter 1: observed MAE=0.037834 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037875 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037909 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037937 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037958 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037973 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037983 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037989 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037991 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037989 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037984 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037978 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037969 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037957 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037944 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037929 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037915 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037899 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037884 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037868 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037851 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037835 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037819 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037804 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037789 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037774 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037760 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037747 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037734 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037721 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037710 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037698 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037688 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037678 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037668 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037659 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037650 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037642 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037635 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037627 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037621 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037614 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037608 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037603 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037597 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037593 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037588 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037584 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037580 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037576 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037572 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037569 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037566 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037563 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037560 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037558 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037556 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037553 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037551 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037549 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037547 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037546 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037544 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037542 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037541 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037540 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037538 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037537 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037536 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037535 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037534 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037533 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037532 rank=32
# [SoftImpute] Iter 74: observed MAE=0.037531 rank=32
# [SoftImpute] Iter 75: observed MAE=0.037531 rank=32
# [SoftImpute] Iter 76: observed MAE=0.037530 rank=32
# [SoftImpute] Iter 77: observed MAE=0.037529 rank=32
# [SoftImpute] Stopped after iteration 77 for lambda=0.929607
# [SoftImpute] Max Singular Value of X_init = 46.227936
# [SoftImpute] Iter 1: observed MAE=0.037770 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037811 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037844 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037871 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037891 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037906 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037915 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037919 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037920 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037916 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037908 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037897 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037885 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037870 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037855 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037838 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037821 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037803 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037784 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037766 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037748 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037730 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037712 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037695 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037679 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037662 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037647 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037632 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037618 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037604 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037592 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037579 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037568 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037557 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037546 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037537 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037528 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037519 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037511 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037503 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037496 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037489 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037483 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037477 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037471 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037466 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037461 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037456 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037452 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037448 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037444 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037440 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037437 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037433 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037430 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037428 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037425 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037422 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037420 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037418 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037416 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037414 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037412 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037410 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037409 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037407 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037406 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037405 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037404 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037402 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037401 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037400 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037399 rank=32
# [SoftImpute] Iter 74: observed MAE=0.037398 rank=32
# [SoftImpute] Stopped after iteration 74 for lambda=0.924559
# [SoftImpute] Max Singular Value of X_init = 45.842834
# [SoftImpute] Iter 1: observed MAE=0.037555 rank=32
# [SoftImpute] Iter 2: observed MAE=0.037591 rank=32
# [SoftImpute] Iter 3: observed MAE=0.037622 rank=32
# [SoftImpute] Iter 4: observed MAE=0.037646 rank=32
# [SoftImpute] Iter 5: observed MAE=0.037663 rank=32
# [SoftImpute] Iter 6: observed MAE=0.037676 rank=32
# [SoftImpute] Iter 7: observed MAE=0.037683 rank=32
# [SoftImpute] Iter 8: observed MAE=0.037686 rank=32
# [SoftImpute] Iter 9: observed MAE=0.037685 rank=32
# [SoftImpute] Iter 10: observed MAE=0.037680 rank=32
# [SoftImpute] Iter 11: observed MAE=0.037671 rank=32
# [SoftImpute] Iter 12: observed MAE=0.037659 rank=32
# [SoftImpute] Iter 13: observed MAE=0.037645 rank=32
# [SoftImpute] Iter 14: observed MAE=0.037629 rank=32
# [SoftImpute] Iter 15: observed MAE=0.037610 rank=32
# [SoftImpute] Iter 16: observed MAE=0.037592 rank=32
# [SoftImpute] Iter 17: observed MAE=0.037573 rank=32
# [SoftImpute] Iter 18: observed MAE=0.037553 rank=32
# [SoftImpute] Iter 19: observed MAE=0.037533 rank=32
# [SoftImpute] Iter 20: observed MAE=0.037513 rank=32
# [SoftImpute] Iter 21: observed MAE=0.037493 rank=32
# [SoftImpute] Iter 22: observed MAE=0.037473 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037454 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037436 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037419 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037402 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037386 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037371 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037357 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037343 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037330 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037317 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037305 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037294 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037283 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037273 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037264 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037255 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037246 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037238 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037231 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037224 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037217 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037211 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037205 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037200 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037194 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037190 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037185 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037181 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037177 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037173 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037169 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037166 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037163 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037160 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037157 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037155 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037152 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037150 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037148 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037146 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037144 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037142 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037141 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037139 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037138 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037136 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037135 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037134 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037133 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037132 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037131 rank=32
# [SoftImpute] Iter 74: observed MAE=0.037130 rank=32
# [SoftImpute] Iter 75: observed MAE=0.037129 rank=32
# [SoftImpute] Stopped after iteration 75 for lambda=0.916857
# [SoftImpute] Max Singular Value of X_init = 46.491337
# [SoftImpute] Iter 1: observed MAE=0.037971 rank=32
# [SoftImpute] Iter 2: observed MAE=0.038018 rank=32
# [SoftImpute] Iter 3: observed MAE=0.038058 rank=32
# [SoftImpute] Iter 4: observed MAE=0.038092 rank=32
# [SoftImpute] Iter 5: observed MAE=0.038118 rank=32
# [SoftImpute] Iter 6: observed MAE=0.038138 rank=32
# [SoftImpute] Iter 7: observed MAE=0.038152 rank=32
# [SoftImpute] Iter 8: observed MAE=0.038160 rank=32
# [SoftImpute] Iter 9: observed MAE=0.038164 rank=32
# [SoftImpute] Iter 10: observed MAE=0.038162 rank=32
# [SoftImpute] Iter 11: observed MAE=0.038157 rank=32
# [SoftImpute] Iter 12: observed MAE=0.038150 rank=32
# [SoftImpute] Iter 13: observed MAE=0.038140 rank=32
# [SoftImpute] Iter 14: observed MAE=0.038128 rank=32
# [SoftImpute] Iter 15: observed MAE=0.038114 rank=32
# [SoftImpute] Iter 16: observed MAE=0.038099 rank=32
# [SoftImpute] Iter 17: observed MAE=0.038084 rank=32
# [SoftImpute] Iter 18: observed MAE=0.038067 rank=32
# [SoftImpute] Iter 19: observed MAE=0.038050 rank=32
# [SoftImpute] Iter 20: observed MAE=0.038034 rank=32
# [SoftImpute] Iter 21: observed MAE=0.038017 rank=32
# [SoftImpute] Iter 22: observed MAE=0.038001 rank=32
# [SoftImpute] Iter 23: observed MAE=0.037984 rank=32
# [SoftImpute] Iter 24: observed MAE=0.037968 rank=32
# [SoftImpute] Iter 25: observed MAE=0.037953 rank=32
# [SoftImpute] Iter 26: observed MAE=0.037938 rank=32
# [SoftImpute] Iter 27: observed MAE=0.037923 rank=32
# [SoftImpute] Iter 28: observed MAE=0.037909 rank=32
# [SoftImpute] Iter 29: observed MAE=0.037896 rank=32
# [SoftImpute] Iter 30: observed MAE=0.037883 rank=32
# [SoftImpute] Iter 31: observed MAE=0.037871 rank=32
# [SoftImpute] Iter 32: observed MAE=0.037860 rank=32
# [SoftImpute] Iter 33: observed MAE=0.037849 rank=32
# [SoftImpute] Iter 34: observed MAE=0.037839 rank=32
# [SoftImpute] Iter 35: observed MAE=0.037829 rank=32
# [SoftImpute] Iter 36: observed MAE=0.037820 rank=32
# [SoftImpute] Iter 37: observed MAE=0.037812 rank=32
# [SoftImpute] Iter 38: observed MAE=0.037804 rank=32
# [SoftImpute] Iter 39: observed MAE=0.037797 rank=32
# [SoftImpute] Iter 40: observed MAE=0.037790 rank=32
# [SoftImpute] Iter 41: observed MAE=0.037783 rank=32
# [SoftImpute] Iter 42: observed MAE=0.037777 rank=32
# [SoftImpute] Iter 43: observed MAE=0.037771 rank=32
# [SoftImpute] Iter 44: observed MAE=0.037766 rank=32
# [SoftImpute] Iter 45: observed MAE=0.037761 rank=32
# [SoftImpute] Iter 46: observed MAE=0.037756 rank=32
# [SoftImpute] Iter 47: observed MAE=0.037751 rank=32
# [SoftImpute] Iter 48: observed MAE=0.037747 rank=32
# [SoftImpute] Iter 49: observed MAE=0.037743 rank=32
# [SoftImpute] Iter 50: observed MAE=0.037740 rank=32
# [SoftImpute] Iter 51: observed MAE=0.037736 rank=32
# [SoftImpute] Iter 52: observed MAE=0.037733 rank=32
# [SoftImpute] Iter 53: observed MAE=0.037730 rank=32
# [SoftImpute] Iter 54: observed MAE=0.037727 rank=32
# [SoftImpute] Iter 55: observed MAE=0.037724 rank=32
# [SoftImpute] Iter 56: observed MAE=0.037722 rank=32
# [SoftImpute] Iter 57: observed MAE=0.037719 rank=32
# [SoftImpute] Iter 58: observed MAE=0.037717 rank=32
# [SoftImpute] Iter 59: observed MAE=0.037715 rank=32
# [SoftImpute] Iter 60: observed MAE=0.037713 rank=32
# [SoftImpute] Iter 61: observed MAE=0.037711 rank=32
# [SoftImpute] Iter 62: observed MAE=0.037710 rank=32
# [SoftImpute] Iter 63: observed MAE=0.037708 rank=32
# [SoftImpute] Iter 64: observed MAE=0.037706 rank=32
# [SoftImpute] Iter 65: observed MAE=0.037705 rank=32
# [SoftImpute] Iter 66: observed MAE=0.037704 rank=32
# [SoftImpute] Iter 67: observed MAE=0.037703 rank=32
# [SoftImpute] Iter 68: observed MAE=0.037701 rank=32
# [SoftImpute] Iter 69: observed MAE=0.037700 rank=32
# [SoftImpute] Iter 70: observed MAE=0.037699 rank=32
# [SoftImpute] Iter 71: observed MAE=0.037698 rank=32
# [SoftImpute] Iter 72: observed MAE=0.037697 rank=32
# [SoftImpute] Iter 73: observed MAE=0.037697 rank=32
# [SoftImpute] Iter 74: observed MAE=0.037696 rank=32
# [SoftImpute] Iter 75: observed MAE=0.037695 rank=32
# [SoftImpute] Stopped after iteration 75 for lambda=0.929827
# [SoftImpute] Max Singular Value of X_init = 40.012090
# [SoftImpute] Iter 1: observed MAE=0.035896 rank=32
# [SoftImpute] Iter 2: observed MAE=0.035929 rank=32
# [SoftImpute] Iter 3: observed MAE=0.035957 rank=32
# [SoftImpute] Iter 4: observed MAE=0.035983 rank=32
# [SoftImpute] Iter 5: observed MAE=0.036006 rank=32
# [SoftImpute] Iter 6: observed MAE=0.036025 rank=32
# [SoftImpute] Iter 7: observed MAE=0.036042 rank=32
# [SoftImpute] Iter 8: observed MAE=0.036055 rank=32
# [SoftImpute] Iter 9: observed MAE=0.036064 rank=32
# [SoftImpute] Iter 10: observed MAE=0.036070 rank=32
# [SoftImpute] Iter 11: observed MAE=0.036072 rank=32
# [SoftImpute] Iter 12: observed MAE=0.036071 rank=32
# [SoftImpute] Iter 13: observed MAE=0.036068 rank=32
# [SoftImpute] Iter 14: observed MAE=0.036064 rank=32
# [SoftImpute] Iter 15: observed MAE=0.036057 rank=32
# [SoftImpute] Iter 16: observed MAE=0.036049 rank=32
# [SoftImpute] Iter 17: observed MAE=0.036038 rank=32
# [SoftImpute] Iter 18: observed MAE=0.036025 rank=32
# [SoftImpute] Iter 19: observed MAE=0.036011 rank=32
# [SoftImpute] Iter 20: observed MAE=0.035997 rank=32
# [SoftImpute] Iter 21: observed MAE=0.035981 rank=32
# [SoftImpute] Iter 22: observed MAE=0.035965 rank=32
# [SoftImpute] Iter 23: observed MAE=0.035948 rank=32
# [SoftImpute] Iter 24: observed MAE=0.035931 rank=32
# [SoftImpute] Iter 25: observed MAE=0.035913 rank=32
# [SoftImpute] Iter 26: observed MAE=0.035895 rank=32
# [SoftImpute] Iter 27: observed MAE=0.035877 rank=32
# [SoftImpute] Iter 28: observed MAE=0.035860 rank=32
# [SoftImpute] Iter 29: observed MAE=0.035842 rank=32
# [SoftImpute] Iter 30: observed MAE=0.035825 rank=32
# [SoftImpute] Iter 31: observed MAE=0.035808 rank=32
# [SoftImpute] Iter 32: observed MAE=0.035791 rank=32
# [SoftImpute] Iter 33: observed MAE=0.035775 rank=32
# [SoftImpute] Iter 34: observed MAE=0.035759 rank=32
# [SoftImpute] Iter 35: observed MAE=0.035744 rank=32
# [SoftImpute] Iter 36: observed MAE=0.035730 rank=32
# [SoftImpute] Iter 37: observed MAE=0.035716 rank=32
# [SoftImpute] Iter 38: observed MAE=0.035703 rank=32
# [SoftImpute] Iter 39: observed MAE=0.035690 rank=32
# [SoftImpute] Iter 40: observed MAE=0.035677 rank=32
# [SoftImpute] Iter 41: observed MAE=0.035665 rank=32
# [SoftImpute] Iter 42: observed MAE=0.035653 rank=32
# [SoftImpute] Iter 43: observed MAE=0.035642 rank=32
# [SoftImpute] Iter 44: observed MAE=0.035632 rank=32
# [SoftImpute] Iter 45: observed MAE=0.035622 rank=32
# [SoftImpute] Iter 46: observed MAE=0.035612 rank=32
# [SoftImpute] Iter 47: observed MAE=0.035603 rank=32
# [SoftImpute] Iter 48: observed MAE=0.035594 rank=32
# [SoftImpute] Iter 49: observed MAE=0.035585 rank=32
# [SoftImpute] Iter 50: observed MAE=0.035578 rank=32
# [SoftImpute] Iter 51: observed MAE=0.035570 rank=32
# [SoftImpute] Iter 52: observed MAE=0.035563 rank=32
# [SoftImpute] Iter 53: observed MAE=0.035556 rank=32
# [SoftImpute] Iter 54: observed MAE=0.035549 rank=32
# [SoftImpute] Iter 55: observed MAE=0.035543 rank=32
# [SoftImpute] Iter 56: observed MAE=0.035536 rank=32
# [SoftImpute] Iter 57: observed MAE=0.035531 rank=32
# [SoftImpute] Iter 58: observed MAE=0.035525 rank=32
# [SoftImpute] Iter 59: observed MAE=0.035520 rank=32
# [SoftImpute] Iter 60: observed MAE=0.035514 rank=32
# [SoftImpute] Iter 61: observed MAE=0.035510 rank=32
# [SoftImpute] Iter 62: observed MAE=0.035505 rank=32
# [SoftImpute] Iter 63: observed MAE=0.035500 rank=32
# [SoftImpute] Iter 64: observed MAE=0.035496 rank=32
# [SoftImpute] Iter 65: observed MAE=0.035492 rank=32
# [SoftImpute] Iter 66: observed MAE=0.035488 rank=32
# [SoftImpute] Iter 67: observed MAE=0.035485 rank=32
# [SoftImpute] Iter 68: observed MAE=0.035481 rank=32
# [SoftImpute] Iter 69: observed MAE=0.035478 rank=32
# [SoftImpute] Iter 70: observed MAE=0.035475 rank=32
# [SoftImpute] Iter 71: observed MAE=0.035472 rank=32
# [SoftImpute] Iter 72: observed MAE=0.035469 rank=32
# [SoftImpute] Iter 73: observed MAE=0.035466 rank=32
# [SoftImpute] Iter 74: observed MAE=0.035464 rank=32
# [SoftImpute] Iter 75: observed MAE=0.035461 rank=32
# [SoftImpute] Iter 76: observed MAE=0.035459 rank=32
# [SoftImpute] Iter 77: observed MAE=0.035457 rank=32
# [SoftImpute] Iter 78: observed MAE=0.035455 rank=32
# [SoftImpute] Iter 79: observed MAE=0.035453 rank=32
# [SoftImpute] Iter 80: observed MAE=0.035451 rank=32
# [SoftImpute] Iter 81: observed MAE=0.035449 rank=32
# [SoftImpute] Iter 82: observed MAE=0.035447 rank=32
# [SoftImpute] Iter 83: observed MAE=0.035445 rank=32
# [SoftImpute] Iter 84: observed MAE=0.035444 rank=32
# [SoftImpute] Iter 85: observed MAE=0.035442 rank=32
# [SoftImpute] Iter 86: observed MAE=0.035441 rank=32
# [SoftImpute] Iter 87: observed MAE=0.035439 rank=32
# [SoftImpute] Iter 88: observed MAE=0.035438 rank=32
# [SoftImpute] Iter 89: observed MAE=0.035436 rank=32
# [SoftImpute] Iter 90: observed MAE=0.035435 rank=32
# [SoftImpute] Iter 91: observed MAE=0.035434 rank=32
# [SoftImpute] Iter 92: observed MAE=0.035433 rank=32
# [SoftImpute] Iter 93: observed MAE=0.035432 rank=32
# [SoftImpute] Iter 94: observed MAE=0.035431 rank=32
# [SoftImpute] Iter 95: observed MAE=0.035430 rank=32
# [SoftImpute] Iter 96: observed MAE=0.035429 rank=32
# [SoftImpute] Stopped after iteration 96 for lambda=0.800242
# [SoftImpute] Max Singular Value of X_init = 40.610073
# [SoftImpute] Iter 1: observed MAE=0.036429 rank=32
# [SoftImpute] Iter 2: observed MAE=0.036459 rank=32
# [SoftImpute] Iter 3: observed MAE=0.036485 rank=32
# [SoftImpute] Iter 4: observed MAE=0.036506 rank=32
# [SoftImpute] Iter 5: observed MAE=0.036523 rank=32
# [SoftImpute] Iter 6: observed MAE=0.036537 rank=32
# [SoftImpute] Iter 7: observed MAE=0.036546 rank=32
# [SoftImpute] Iter 8: observed MAE=0.036552 rank=32
# [SoftImpute] Iter 9: observed MAE=0.036555 rank=32
# [SoftImpute] Iter 10: observed MAE=0.036555 rank=32
# [SoftImpute] Iter 11: observed MAE=0.036552 rank=32
# [SoftImpute] Iter 12: observed MAE=0.036548 rank=32
# [SoftImpute] Iter 13: observed MAE=0.036540 rank=32
# [SoftImpute] Iter 14: observed MAE=0.036530 rank=32
# [SoftImpute] Iter 15: observed MAE=0.036520 rank=32
# [SoftImpute] Iter 16: observed MAE=0.036507 rank=32
# [SoftImpute] Iter 17: observed MAE=0.036493 rank=32
# [SoftImpute] Iter 18: observed MAE=0.036477 rank=32
# [SoftImpute] Iter 19: observed MAE=0.036460 rank=32
# [SoftImpute] Iter 20: observed MAE=0.036443 rank=32
# [SoftImpute] Iter 21: observed MAE=0.036425 rank=32
# [SoftImpute] Iter 22: observed MAE=0.036407 rank=32
# [SoftImpute] Iter 23: observed MAE=0.036388 rank=32
# [SoftImpute] Iter 24: observed MAE=0.036369 rank=32
# [SoftImpute] Iter 25: observed MAE=0.036351 rank=32
# [SoftImpute] Iter 26: observed MAE=0.036332 rank=32
# [SoftImpute] Iter 27: observed MAE=0.036313 rank=32
# [SoftImpute] Iter 28: observed MAE=0.036294 rank=32
# [SoftImpute] Iter 29: observed MAE=0.036276 rank=32
# [SoftImpute] Iter 30: observed MAE=0.036259 rank=32
# [SoftImpute] Iter 31: observed MAE=0.036241 rank=32
# [SoftImpute] Iter 32: observed MAE=0.036224 rank=32
# [SoftImpute] Iter 33: observed MAE=0.036208 rank=32
# [SoftImpute] Iter 34: observed MAE=0.036192 rank=32
# [SoftImpute] Iter 35: observed MAE=0.036177 rank=32
# [SoftImpute] Iter 36: observed MAE=0.036162 rank=32
# [SoftImpute] Iter 37: observed MAE=0.036148 rank=32
# [SoftImpute] Iter 38: observed MAE=0.036134 rank=32
# [SoftImpute] Iter 39: observed MAE=0.036121 rank=32
# [SoftImpute] Iter 40: observed MAE=0.036108 rank=32
# [SoftImpute] Iter 41: observed MAE=0.036096 rank=32
# [SoftImpute] Iter 42: observed MAE=0.036085 rank=32
# [SoftImpute] Iter 43: observed MAE=0.036074 rank=32
# [SoftImpute] Iter 44: observed MAE=0.036063 rank=32
# [SoftImpute] Iter 45: observed MAE=0.036053 rank=32
# [SoftImpute] Iter 46: observed MAE=0.036043 rank=32
# [SoftImpute] Iter 47: observed MAE=0.036034 rank=32
# [SoftImpute] Iter 48: observed MAE=0.036025 rank=32
# [SoftImpute] Iter 49: observed MAE=0.036017 rank=32
# [SoftImpute] Iter 50: observed MAE=0.036009 rank=32
# [SoftImpute] Iter 51: observed MAE=0.036001 rank=32
# [SoftImpute] Iter 52: observed MAE=0.035994 rank=32
# [SoftImpute] Iter 53: observed MAE=0.035987 rank=32
# [SoftImpute] Iter 54: observed MAE=0.035980 rank=32
# [SoftImpute] Iter 55: observed MAE=0.035974 rank=32
# [SoftImpute] Iter 56: observed MAE=0.035968 rank=32
# [SoftImpute] Iter 57: observed MAE=0.035962 rank=32
# [SoftImpute] Iter 58: observed MAE=0.035957 rank=32
# ...
# [SoftImpute] Iter 1: observed MAE=0.031755 rank=32
# [SoftImpute] Iter 2: observed MAE=0.031764 rank=32
# [SoftImpute] Iter 3: observed MAE=0.031772 rank=32
# [SoftImpute] Iter 4: observed MAE=0.031779 rank=32
# [SoftImpute] Iter 5: observed MAE=0.031786 rank=32
# [SoftImpute] Iter 6: observed MAE=0.031791 rank=32
# [SoftImpute] Iter 7: observed MAE=0.031795 rank=32
# [SoftImpute] Iter 8: observed MAE=0.031799 rank=32
# [SoftImpute] Iter 9: observed MAE=0.031802 rank=32
# [SoftImpute] Iter 10: observed MAE=0.031804 rank=32
# [SoftImpute] Iter 11: observed MAE=0.031806 rank=32
# [SoftImpute] Iter 12: observed MAE=0.031806 rank=32
# [SoftImpute] Iter 13: observed MAE=0.031806 rank=32
# [SoftImpute] Iter 14: observed MAE=0.031806 rank=32
# [SoftImpute] Iter 15: observed MAE=0.031806 rank=32
# [SoftImpute] Iter 16: observed MAE=0.031805 rank=32
# [SoftImpute] Iter 17: observed MAE=0.031803 rank=32
# [SoftImpute] Iter 18: observed MAE=0.031800 rank=32
# [SoftImpute] Iter 19: observed MAE=0.031797 rank=32
# [SoftImpute] Iter 20: observed MAE=0.031793 rank=32
# [SoftImpute] Iter 21: observed MAE=0.031788 rank=32
# [SoftImpute] Iter 22: observed MAE=0.031783 rank=32
# [SoftImpute] Iter 23: observed MAE=0.031778 rank=32
# [SoftImpute] Iter 24: observed MAE=0.031772 rank=32
# [SoftImpute] Iter 25: observed MAE=0.031765 rank=32
# [SoftImpute] Iter 26: observed MAE=0.031758 rank=32
# [SoftImpute] Iter 27: observed MAE=0.031751 rank=32
# [SoftImpute] Iter 28: observed MAE=0.031743 rank=32
# [SoftImpute] Iter 29: observed MAE=0.031735 rank=32
# [SoftImpute] Iter 30: observed MAE=0.031727 rank=32
# [SoftImpute] Iter 31: observed MAE=0.031719 rank=32
# [SoftImpute] Iter 32: observed MAE=0.031711 rank=32
# [SoftImpute] Iter 33: observed MAE=0.031703 rank=32
# [SoftImpute] Iter 34: observed MAE=0.031694 rank=32
# [SoftImpute] Iter 35: observed MAE=0.031686 rank=32
# [SoftImpute] Iter 36: observed MAE=0.031677 rank=32
# [SoftImpute] Iter 37: observed MAE=0.031668 rank=32
# [SoftImpute] Iter 38: observed MAE=0.031658 rank=32
# [SoftImpute] Iter 39: observed MAE=0.031649 rank=32
# [SoftImpute] Iter 40: observed MAE=0.031639 rank=32
# [SoftImpute] Iter 41: observed MAE=0.031629 rank=32
# [SoftImpute] Iter 42: observed MAE=0.031619 rank=32
# [SoftImpute] Iter 43: observed MAE=0.031609 rank=32
# [SoftImpute] Iter 44: observed MAE=0.031598 rank=32
# [SoftImpute] Iter 45: observed MAE=0.031588 rank=32
# [SoftImpute] Iter 46: observed MAE=0.031577 rank=32
# [SoftImpute] Iter 47: observed MAE=0.031566 rank=32
# [SoftImpute] Iter 48: observed MAE=0.031556 rank=32
# [SoftImpute] Iter 49: observed MAE=0.031546 rank=32
# [SoftImpute] Iter 50: observed MAE=0.031535 rank=32
# [SoftImpute] Iter 51: observed MAE=0.031525 rank=32
# [SoftImpute] Iter 52: observed MAE=0.031515 rank=32
# [SoftImpute] Iter 53: observed MAE=0.031505 rank=32
# [SoftImpute] Iter 54: observed MAE=0.031495 rank=32
# [SoftImpute] Iter 55: observed MAE=0.031485 rank=32
# [SoftImpute] Iter 56: observed MAE=0.031476 rank=32
# [SoftImpute] Iter 57: observed MAE=0.031466 rank=32
# [SoftImpute] Iter 58: observed MAE=0.031457 rank=32
# [SoftImpute] Iter 59: observed MAE=0.031448 rank=32
# [SoftImpute] Iter 60: observed MAE=0.031439 rank=32
# [SoftImpute] Iter 61: observed MAE=0.031430 rank=32
# [SoftImpute] Iter 62: observed MAE=0.031422 rank=32
# [SoftImpute] Iter 63: observed MAE=0.031413 rank=32
# [SoftImpute] Iter 64: observed MAE=0.031405 rank=32
# [SoftImpute] Iter 65: observed MAE=0.031397 rank=32
# [SoftImpute] Iter 66: observed MAE=0.031389 rank=32
# [SoftImpute] Iter 67: observed MAE=0.031382 rank=32
# [SoftImpute] Iter 68: observed MAE=0.031374 rank=32
# [SoftImpute] Iter 69: observed MAE=0.031367 rank=32
# [SoftImpute] Iter 70: observed MAE=0.031360 rank=32
# [SoftImpute] Iter 71: observed MAE=0.031353 rank=32
# [SoftImpute] Iter 72: observed MAE=0.031347 rank=32
# [SoftImpute] Iter 73: observed MAE=0.031340 rank=32
# [SoftImpute] Iter 74: observed MAE=0.031333 rank=32
# [SoftImpute] Iter 75: observed MAE=0.031327 rank=32
# [SoftImpute] Iter 76: observed MAE=0.031321 rank=32
# [SoftImpute] Iter 77: observed MAE=0.031314 rank=32
# [SoftImpute] Iter 78: observed MAE=0.031308 rank=32
# [SoftImpute] Iter 79: observed MAE=0.031302 rank=32
# [SoftImpute] Iter 80: observed MAE=0.031297 rank=32
# [SoftImpute] Iter 81: observed MAE=0.031291 rank=32
# [SoftImpute] Iter 82: observed MAE=0.031286 rank=32
# [SoftImpute] Iter 83: observed MAE=0.031281 rank=32
# [SoftImpute] Iter 84: observed MAE=0.031275 rank=32
# [SoftImpute] Iter 85: observed MAE=0.031270 rank=32
# [SoftImpute] Iter 86: observed MAE=0.031266 rank=32
# [SoftImpute] Iter 87: observed MAE=0.031261 rank=32
# [SoftImpute] Iter 88: observed MAE=0.031256 rank=32
# [SoftImpute] Iter 89: observed MAE=0.031252 rank=32
# [SoftImpute] Iter 90: observed MAE=0.031247 rank=32
# [SoftImpute] Iter 91: observed MAE=0.031243 rank=32
# [SoftImpute] Iter 92: observed MAE=0.031239 rank=32
# [SoftImpute] Iter 93: observed MAE=0.031235 rank=32
# [SoftImpute] Iter 94: observed MAE=0.031231 rank=32
# [SoftImpute] Iter 95: observed MAE=0.031227 rank=32
# [SoftImpute] Iter 96: observed MAE=0.031223 rank=32
# [SoftImpute] Iter 97: observed MAE=0.031219 rank=32
# [SoftImpute] Iter 98: observed MAE=0.031216 rank=32
# [SoftImpute] Iter 99: observed MAE=0.031212 rank=32
# [SoftImpute] Iter 100: observed MAE=0.031209 rank=32
# [SoftImpute] Stopped after iteration 100 for lambda=0.540952
# [SoftImpute] Max Singular Value of X_init = 26.773262
# [SoftImpute] Iter 1: observed MAE=0.031556 rank=32
# [SoftImpute] Iter 2: observed MAE=0.031572 rank=32
# [SoftImpute] Iter 3: observed MAE=0.031587 rank=32
# [SoftImpute] Iter 4: observed MAE=0.031600 rank=32
# [SoftImpute] Iter 5: observed MAE=0.031613 rank=32
# [SoftImpute] Iter 6: observed MAE=0.031624 rank=32
# [SoftImpute] Iter 7: observed MAE=0.031634 rank=32
# [SoftImpute] Iter 8: observed MAE=0.031644 rank=32
# [SoftImpute] Iter 9: observed MAE=0.031652 rank=32
# [SoftImpute] Iter 10: observed MAE=0.031659 rank=32
# [SoftImpute] Iter 11: observed MAE=0.031666 rank=32
# [SoftImpute] Iter 12: observed MAE=0.031672 rank=32
# [SoftImpute] Iter 13: observed MAE=0.031676 rank=32
# [SoftImpute] Iter 14: observed MAE=0.031680 rank=32
# [SoftImpute] Iter 15: observed MAE=0.031682 rank=32
# [SoftImpute] Iter 16: observed MAE=0.031684 rank=32
# [SoftImpute] Iter 17: observed MAE=0.031686 rank=32
# [SoftImpute] Iter 18: observed MAE=0.031686 rank=32
# [SoftImpute] Iter 19: observed MAE=0.031686 rank=32
# [SoftImpute] Iter 20: observed MAE=0.031685 rank=32
# [SoftImpute] Iter 21: observed MAE=0.031683 rank=32
# [SoftImpute] Iter 22: observed MAE=0.031680 rank=32
# [SoftImpute] Iter 23: observed MAE=0.031676 rank=32
# [SoftImpute] Iter 24: observed MAE=0.031672 rank=32
# [SoftImpute] Iter 25: observed MAE=0.031668 rank=32
# [SoftImpute] Iter 26: observed MAE=0.031663 rank=32
# [SoftImpute] Iter 27: observed MAE=0.031657 rank=32
# [SoftImpute] Iter 28: observed MAE=0.031651 rank=32
# [SoftImpute] Iter 29: observed MAE=0.031645 rank=32
# [SoftImpute] Iter 30: observed MAE=0.031638 rank=32
# [SoftImpute] Iter 31: observed MAE=0.031630 rank=32
# [SoftImpute] Iter 32: observed MAE=0.031622 rank=32
# [SoftImpute] Iter 33: observed MAE=0.031614 rank=32
# [SoftImpute] Iter 34: observed MAE=0.031605 rank=32
# [SoftImpute] Iter 35: observed MAE=0.031597 rank=32
# [SoftImpute] Iter 36: observed MAE=0.031587 rank=32
# [SoftImpute] Iter 37: observed MAE=0.031577 rank=32
# [SoftImpute] Iter 38: observed MAE=0.031567 rank=32
# [SoftImpute] Iter 39: observed MAE=0.031557 rank=32
# [SoftImpute] Iter 40: observed MAE=0.031547 rank=32
# [SoftImpute] Iter 41: observed MAE=0.031536 rank=32
# [SoftImpute] Iter 42: observed MAE=0.031526 rank=32
# [SoftImpute] Iter 43: observed MAE=0.031516 rank=32
# [SoftImpute] Iter 44: observed MAE=0.031506 rank=32
# [SoftImpute] Iter 45: observed MAE=0.031496 rank=32
# [SoftImpute] Iter 46: observed MAE=0.031488 rank=32
# [SoftImpute] Iter 47: observed MAE=0.031479 rank=32
# [SoftImpute] Iter 48: observed MAE=0.031470 rank=32
# [SoftImpute] Iter 49: observed MAE=0.031461 rank=32
# [SoftImpute] Iter 50: observed MAE=0.031452 rank=32
# [SoftImpute] Iter 51: observed MAE=0.031443 rank=32
# [SoftImpute] Iter 52: observed MAE=0.031434 rank=32
# [SoftImpute] Iter 53: observed MAE=0.031426 rank=32
# [SoftImpute] Iter 54: observed MAE=0.031417 rank=32
# [SoftImpute] Iter 55: observed MAE=0.031410 rank=32
# [SoftImpute] Iter 56: observed MAE=0.031402 rank=32
# [SoftImpute] Iter 57: observed MAE=0.031394 rank=32
# [SoftImpute] Iter 58: observed MAE=0.031387 rank=32
# [SoftImpute] Iter 59: observed MAE=0.031380 rank=32
# [SoftImpute] Iter 60: observed MAE=0.031373 rank=32
# [SoftImpute] Iter 61: observed MAE=0.031366 rank=32
# [SoftImpute] Iter 62: observed MAE=0.031360 rank=32
# [SoftImpute] Iter 63: observed MAE=0.031353 rank=32
# [SoftImpute] Iter 64: observed MAE=0.031346 rank=32
# [SoftImpute] Iter 65: observed MAE=0.031340 rank=32
# [SoftImpute] Iter 66: observed MAE=0.031333 rank=32
# [SoftImpute] Iter 67: observed MAE=0.031327 rank=32
# [SoftImpute] Iter 68: observed MAE=0.031321 rank=32
# [SoftImpute] Iter 69: observed MAE=0.031315 rank=32
# [SoftImpute] Iter 70: observed MAE=0.031309 rank=32
# [SoftImpute] Iter 71: observed MAE=0.031304 rank=32
# [SoftImpute] Iter 72: observed MAE=0.031298 rank=32
# [SoftImpute] Iter 73: observed MAE=0.031293 rank=32
# [SoftImpute] Iter 74: observed MAE=0.031288 rank=32
# [SoftImpute] Iter 75: observed MAE=0.031282 rank=32
# [SoftImpute] Iter 76: observed MAE=0.031277 rank=32
# [SoftImpute] Iter 77: observed MAE=0.031272 rank=32
# [SoftImpute] Iter 78: observed MAE=0.031267 rank=32
# [SoftImpute] Iter 79: observed MAE=0.031262 rank=32
# [SoftImpute] Iter 80: observed MAE=0.031258 rank=32
# [SoftImpute] Iter 81: observed MAE=0.031253 rank=32
# [SoftImpute] Iter 82: observed MAE=0.031249 rank=32
# [SoftImpute] Iter 83: observed MAE=0.031245 rank=32
# [SoftImpute] Iter 84: observed MAE=0.031241 rank=32
# [SoftImpute] Iter 85: observed MAE=0.031237 rank=32
# [SoftImpute] Iter 86: observed MAE=0.031234 rank=32
# [SoftImpute] Iter 87: observed MAE=0.031230 rank=32
# [SoftImpute] Iter 88: observed MAE=0.031227 rank=32
# [SoftImpute] Iter 89: observed MAE=0.031224 rank=32
# [SoftImpute] Iter 90: observed MAE=0.031221 rank=32
# [SoftImpute] Iter 91: observed MAE=0.031218 rank=32
# [SoftImpute] Iter 92: observed MAE=0.031215 rank=32
# [SoftImpute] Iter 93: observed MAE=0.031212 rank=32
# [SoftImpute] Iter 94: observed MAE=0.031209 rank=32
# [SoftImpute] Iter 95: observed MAE=0.031206 rank=32
# [SoftImpute] Iter 96: observed MAE=0.031204 rank=32
# [SoftImpute] Iter 97: observed MAE=0.031201 rank=32
# [SoftImpute] Iter 98: observed MAE=0.031198 rank=32
# [SoftImpute] Iter 99: observed MAE=0.031196 rank=32
# [SoftImpute] Iter 100: observed MAE=0.031194 rank=32
# [SoftImpute] Stopped after iteration 100 for lambda=0.535465
# [SoftImpute] Max Singular Value of X_init = 27.426582
# [SoftImpute] Iter 1: observed MAE=0.032348 rank=32
# [SoftImpute] Iter 2: observed MAE=0.032363 rank=32
# [SoftImpute] Iter 3: observed MAE=0.032377 rank=32
# [SoftImpute] Iter 4: observed MAE=0.032389 rank=32
# [SoftImpute] Iter 5: observed MAE=0.032400 rank=32
# [SoftImpute] Iter 6: observed MAE=0.032410 rank=32
# [SoftImpute] Iter 7: observed MAE=0.032419 rank=32
# [SoftImpute] Iter 8: observed MAE=0.032427 rank=32
# [SoftImpute] Iter 9: observed MAE=0.032435 rank=32
# [SoftImpute] Iter 10: observed MAE=0.032442 rank=32
# [SoftImpute] Iter 11: observed MAE=0.032448 rank=32
# [SoftImpute] Iter 12: observed MAE=0.032454 rank=32
# [SoftImpute] Iter 13: observed MAE=0.032460 rank=32
# [SoftImpute] Iter 14: observed MAE=0.032464 rank=32
# [SoftImpute] Iter 15: observed MAE=0.032468 rank=32
# [SoftImpute] Iter 16: observed MAE=0.032471 rank=32
# [SoftImpute] Iter 17: observed MAE=0.032472 rank=32
# [SoftImpute] Iter 18: observed MAE=0.032473 rank=32
# [SoftImpute] Iter 19: observed MAE=0.032472 rank=32
# [SoftImpute] Iter 20: observed MAE=0.032472 rank=32
# [SoftImpute] Iter 21: observed MAE=0.032470 rank=32
# [SoftImpute] Iter 22: observed MAE=0.032468 rank=32
# [SoftImpute] Iter 23: observed MAE=0.032466 rank=32
# [SoftImpute] Iter 24: observed MAE=0.032462 rank=32
# [SoftImpute] Iter 25: observed MAE=0.032458 rank=32
# [SoftImpute] Iter 26: observed MAE=0.032454 rank=32
# [SoftImpute] Iter 27: observed MAE=0.032450 rank=32
# [SoftImpute] Iter 28: observed MAE=0.032445 rank=32
# [SoftImpute] Iter 29: observed MAE=0.032440 rank=32
# [SoftImpute] Iter 30: observed MAE=0.032434 rank=32
# [SoftImpute] Iter 31: observed MAE=0.032427 rank=32
# [SoftImpute] Iter 32: observed MAE=0.032421 rank=32
# [SoftImpute] Iter 33: observed MAE=0.032413 rank=32
# [SoftImpute] Iter 34: observed MAE=0.032405 rank=32
# [SoftImpute] Iter 35: observed MAE=0.032397 rank=32
# [SoftImpute] Iter 36: observed MAE=0.032388 rank=32
# [SoftImpute] Iter 37: observed MAE=0.032379 rank=32
# [SoftImpute] Iter 38: observed MAE=0.032369 rank=32
# [SoftImpute] Iter 39: observed MAE=0.032360 rank=32
# [SoftImpute] Iter 40: observed MAE=0.032350 rank=32
# [SoftImpute] Iter 41: observed MAE=0.032340 rank=32
# [SoftImpute] Iter 42: observed MAE=0.032330 rank=32
# [SoftImpute] Iter 43: observed MAE=0.032321 rank=32
# [SoftImpute] Iter 44: observed MAE=0.032311 rank=32
# [SoftImpute] Iter 45: observed MAE=0.032302 rank=32
# [SoftImpute] Iter 46: observed MAE=0.032293 rank=32
# [SoftImpute] Iter 47: observed MAE=0.032284 rank=32
# [SoftImpute] Iter 48: observed MAE=0.032275 rank=32
# [SoftImpute] Iter 49: observed MAE=0.032266 rank=32
# [SoftImpute] Iter 50: observed MAE=0.032257 rank=32
# [SoftImpute] Iter 51: observed MAE=0.032249 rank=32
# [SoftImpute] Iter 52: observed MAE=0.032240 rank=32
# [SoftImpute] Iter 53: observed MAE=0.032232 rank=32
# [SoftImpute] Iter 54: observed MAE=0.032224 rank=32
# [SoftImpute] Iter 55: observed MAE=0.032216 rank=32
# [SoftImpute] Iter 56: observed MAE=0.032208 rank=32
# [SoftImpute] Iter 57: observed MAE=0.032199 rank=32
# [SoftImpute] Iter 58: observed MAE=0.032191 rank=32
# [SoftImpute] Iter 59: observed MAE=0.032183 rank=32
# [SoftImpute] Iter 60: observed MAE=0.032175 rank=32
# [SoftImpute] Iter 61: observed MAE=0.032167 rank=32
# [SoftImpute] Iter 62: observed MAE=0.032159 rank=32
# [SoftImpute] Iter 63: observed MAE=0.032151 rank=32
# [SoftImpute] Iter 64: observed MAE=0.032144 rank=32
# [SoftImpute] Iter 65: observed MAE=0.032137 rank=32
# [SoftImpute] Iter 66: observed MAE=0.032130 rank=32
# [SoftImpute] Iter 67: observed MAE=0.032123 rank=32
# [SoftImpute] Iter 68: observed MAE=0.032116 rank=32
# [SoftImpute] Iter 69: observed MAE=0.032109 rank=32
# [SoftImpute] Iter 70: observed MAE=0.032102 rank=32
# [SoftImpute] Iter 71: observed MAE=0.032096 rank=32
# [SoftImpute] Iter 72: observed MAE=0.032089 rank=32
# [SoftImpute] Iter 73: observed MAE=0.032083 rank=32
# [SoftImpute] Iter 74: observed MAE=0.032076 rank=32
# [SoftImpute] Iter 75: observed MAE=0.032070 rank=32
# [SoftImpute] Iter 76: observed MAE=0.032064 rank=32
# [SoftImpute] Iter 77: observed MAE=0.032058 rank=32
# [SoftImpute] Iter 78: observed MAE=0.032052 rank=32
# [SoftImpute] Iter 79: observed MAE=0.032046 rank=32
# [SoftImpute] Iter 80: observed MAE=0.032040 rank=32
# [SoftImpute] Iter 81: observed MAE=0.032034 rank=32
# [SoftImpute] Iter 82: observed MAE=0.032029 rank=32
# [SoftImpute] Iter 83: observed MAE=0.032024 rank=32
# [SoftImpute] Iter 84: observed MAE=0.032018 rank=32
# [SoftImpute] Iter 85: observed MAE=0.032013 rank=32
# [SoftImpute] Iter 86: observed MAE=0.032008 rank=32
# [SoftImpute] Iter 87: observed MAE=0.032003 rank=32
# [SoftImpute] Iter 88: observed MAE=0.031998 rank=32
# [SoftImpute] Iter 89: observed MAE=0.031994 rank=32
# [SoftImpute] Iter 90: observed MAE=0.031989 rank=32
# [SoftImpute] Iter 91: observed MAE=0.031985 rank=32
# [SoftImpute] Iter 92: observed MAE=0.031981 rank=32
# [SoftImpute] Iter 93: observed MAE=0.031976 rank=32
# [SoftImpute] Iter 94: observed MAE=0.031972 rank=32
# [SoftImpute] Iter 95: observed MAE=0.031969 rank=32
# [SoftImpute] Iter 96: observed MAE=0.031965 rank=32
# [SoftImpute] Iter 97: observed MAE=0.031961 rank=32
# [SoftImpute] Iter 98: observed MAE=0.031958 rank=32
# [SoftImpute] Iter 99: observed MAE=0.031954 rank=32
# [SoftImpute] Iter 100: observed MAE=0.031951 rank=32
# [SoftImpute] Stopped after iteration 100 for lambda=0.548532
# array([[0.003, 0.   ],
#        [0.005, 0.   ],
#        [0.006, 0.001],
#        [0.008, 0.   ],
#        [0.009, 0.   ]])

# %% [markdown]
# # seeds

# %%
data = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/00236/seeds_dataset.txt',
                     sep = '\s+', header = None)
data = pd.DataFrame.to_numpy(data)
X,y = data[:,:7], data[:,7]-1 # reset the labels to go start from 0

# %%
G = 3
mle_err = np.array([compute_err_mle(X, y, G, .2, runs = 10),
                    compute_err_mle(X, y, G, .35, runs = 10),
                    compute_err_mle(X, y, G, .5, runs = 10),
                    compute_err_mle(X, y, G, .65, runs = 10),
                    compute_err_mle(X, y, G, .8, runs = 10)])
mle_err.round(3)
# Out:
# array([[0.004, 0.001],
#        [0.006, 0.001],
#        [0.008, 0.001],
#        [0.009, 0.001],
#        [0.012, 0.002]])

# %%
G = 3
mice_err = np.array([compute_err_mice(X, y, G, .2, runs = 10),
                    compute_err_mice(X, y, G, .35, runs = 10),
                    compute_err_mice(X, y, G, .5, runs = 10),
                    compute_err_mice(X, y, G, .65, runs = 10),
                    compute_err_mice(X, y, G, .8, runs = 10)])
mice_err.round(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# array([[0.004, 0.001],
#        [0.007, 0.002],
#        [0.013, 0.006],
#        [0.016, 0.002],
#        [0.023, 0.003]])

# %%
G = 3
soft_err = np.array([compute_err_soft(X, y, G, .2, runs = 10),
                    compute_err_soft(X, y, G, .35, runs = 10),
                    compute_err_soft(X, y, G, .5, runs = 10),
                    compute_err_soft(X, y, G, .65, runs = 10),
                    compute_err_soft(X, y, G, .8, runs = 10)])
soft_err.round(3)
# Out:
# [SoftImpute] Max Singular Value of X_init = 27.205454
# [SoftImpute] Iter 1: observed MAE=0.029558 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029637 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029718 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029802 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029886 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029972 rank=7
# [SoftImpute] Iter 7: observed MAE=0.030058 rank=7
# [SoftImpute] Iter 8: observed MAE=0.030144 rank=7
# [SoftImpute] Iter 9: observed MAE=0.030235 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030329 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030421 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030514 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030616 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030714 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030811 rank=7
# [SoftImpute] Iter 16: observed MAE=0.030911 rank=7
# [SoftImpute] Iter 17: observed MAE=0.031019 rank=7
# [SoftImpute] Iter 18: observed MAE=0.031132 rank=7
# [SoftImpute] Iter 19: observed MAE=0.031241 rank=7
# [SoftImpute] Iter 20: observed MAE=0.031363 rank=7
# [SoftImpute] Iter 21: observed MAE=0.031494 rank=7
# [SoftImpute] Iter 22: observed MAE=0.031624 rank=7
# [SoftImpute] Iter 23: observed MAE=0.031744 rank=7
# [SoftImpute] Iter 24: observed MAE=0.031867 rank=7
# [SoftImpute] Iter 25: observed MAE=0.031982 rank=7
# [SoftImpute] Iter 26: observed MAE=0.032090 rank=7
# [SoftImpute] Iter 27: observed MAE=0.032187 rank=7
# [SoftImpute] Iter 28: observed MAE=0.032205 rank=6
# [SoftImpute] Iter 29: observed MAE=0.032130 rank=6
# [SoftImpute] Iter 30: observed MAE=0.032096 rank=6
# [SoftImpute] Iter 31: observed MAE=0.032079 rank=6
# [SoftImpute] Iter 32: observed MAE=0.032073 rank=6
# [SoftImpute] Iter 33: observed MAE=0.032070 rank=6
# [SoftImpute] Iter 34: observed MAE=0.032069 rank=6
# [SoftImpute] Iter 35: observed MAE=0.032069 rank=6
# [SoftImpute] Iter 36: observed MAE=0.032070 rank=6
# [SoftImpute] Iter 37: observed MAE=0.032071 rank=6
# [SoftImpute] Iter 38: observed MAE=0.032072 rank=6
# [SoftImpute] Iter 39: observed MAE=0.032073 rank=6
# [SoftImpute] Iter 40: observed MAE=0.032073 rank=6
# [SoftImpute] Iter 41: observed MAE=0.032074 rank=6
# [SoftImpute] Iter 42: observed MAE=0.032074 rank=6
# [SoftImpute] Iter 43: observed MAE=0.032074 rank=6
# [SoftImpute] Iter 44: observed MAE=0.032075 rank=6
# [SoftImpute] Iter 45: observed MAE=0.032075 rank=6
# [SoftImpute] Iter 46: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 47: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 48: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 49: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 50: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 51: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 52: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 53: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 54: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 55: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 56: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 57: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 58: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 59: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 60: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 61: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 62: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 63: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 64: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 65: observed MAE=0.032076 rank=6
# [SoftImpute] Stopped after iteration 65 for lambda=0.544109
# [SoftImpute] Max Singular Value of X_init = 27.208377
# [SoftImpute] Iter 1: observed MAE=0.029870 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029955 rank=7
# [SoftImpute] Iter 3: observed MAE=0.030040 rank=7
# [SoftImpute] Iter 4: observed MAE=0.030132 rank=7
# [SoftImpute] Iter 5: observed MAE=0.030228 rank=7
# [SoftImpute] Iter 6: observed MAE=0.030324 rank=7
# [SoftImpute] Iter 7: observed MAE=0.030424 rank=7
# [SoftImpute] Iter 8: observed MAE=0.030532 rank=7
# [SoftImpute] Iter 9: observed MAE=0.030639 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030749 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030858 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030965 rank=7
# [SoftImpute] Iter 13: observed MAE=0.031082 rank=7
# [SoftImpute] Iter 14: observed MAE=0.031195 rank=7
# [SoftImpute] Iter 15: observed MAE=0.031304 rank=7
# [SoftImpute] Iter 16: observed MAE=0.031414 rank=7
# [SoftImpute] Iter 17: observed MAE=0.031519 rank=7
# [SoftImpute] Iter 18: observed MAE=0.031629 rank=7
# [SoftImpute] Iter 19: observed MAE=0.031743 rank=7
# [SoftImpute] Iter 20: observed MAE=0.031866 rank=7
# [SoftImpute] Iter 21: observed MAE=0.031968 rank=7
# [SoftImpute] Iter 22: observed MAE=0.032070 rank=7
# [SoftImpute] Iter 23: observed MAE=0.032157 rank=7
# [SoftImpute] Iter 24: observed MAE=0.032236 rank=7
# [SoftImpute] Iter 25: observed MAE=0.032316 rank=7
# [SoftImpute] Iter 26: observed MAE=0.032385 rank=7
# [SoftImpute] Iter 27: observed MAE=0.032316 rank=6
# [SoftImpute] Iter 28: observed MAE=0.032214 rank=6
# [SoftImpute] Iter 29: observed MAE=0.032160 rank=6
# [SoftImpute] Iter 30: observed MAE=0.032131 rank=6
# [SoftImpute] Iter 31: observed MAE=0.032115 rank=6
# [SoftImpute] Iter 32: observed MAE=0.032103 rank=6
# [SoftImpute] Iter 33: observed MAE=0.032094 rank=6
# [SoftImpute] Iter 34: observed MAE=0.032084 rank=6
# [SoftImpute] Iter 35: observed MAE=0.032076 rank=6
# [SoftImpute] Iter 36: observed MAE=0.032068 rank=6
# [SoftImpute] Iter 37: observed MAE=0.032061 rank=6
# [SoftImpute] Iter 38: observed MAE=0.032055 rank=6
# [SoftImpute] Iter 39: observed MAE=0.032049 rank=6
# [SoftImpute] Iter 40: observed MAE=0.032044 rank=6
# [SoftImpute] Iter 41: observed MAE=0.032040 rank=6
# [SoftImpute] Iter 42: observed MAE=0.032035 rank=6
# [SoftImpute] Iter 43: observed MAE=0.032031 rank=6
# [SoftImpute] Iter 44: observed MAE=0.032027 rank=6
# [SoftImpute] Iter 45: observed MAE=0.032023 rank=6
# [SoftImpute] Iter 46: observed MAE=0.032020 rank=6
# [SoftImpute] Iter 47: observed MAE=0.032017 rank=6
# [SoftImpute] Iter 48: observed MAE=0.032014 rank=6
# [SoftImpute] Iter 49: observed MAE=0.032011 rank=6
# [SoftImpute] Iter 50: observed MAE=0.032008 rank=6
# [SoftImpute] Iter 51: observed MAE=0.032006 rank=6
# [SoftImpute] Iter 52: observed MAE=0.032004 rank=6
# [SoftImpute] Iter 53: observed MAE=0.032002 rank=6
# [SoftImpute] Iter 54: observed MAE=0.032000 rank=6
# [SoftImpute] Iter 55: observed MAE=0.031998 rank=6
# [SoftImpute] Iter 56: observed MAE=0.031996 rank=6
# [SoftImpute] Stopped after iteration 56 for lambda=0.544168
# [SoftImpute] Max Singular Value of X_init = 27.181922
# [SoftImpute] Iter 1: observed MAE=0.029591 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029665 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029740 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029814 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029889 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029965 rank=7
# [SoftImpute] Iter 7: observed MAE=0.030039 rank=7
# [SoftImpute] Iter 8: observed MAE=0.030115 rank=7
# [SoftImpute] Iter 9: observed MAE=0.030200 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030290 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030383 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030482 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030584 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030686 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030796 rank=7
# [SoftImpute] Iter 16: observed MAE=0.030908 rank=7
# [SoftImpute] Iter 17: observed MAE=0.031045 rank=7
# [SoftImpute] Iter 18: observed MAE=0.031181 rank=7
# [SoftImpute] Iter 19: observed MAE=0.031317 rank=7
# [SoftImpute] Iter 20: observed MAE=0.031454 rank=7
# [SoftImpute] Iter 21: observed MAE=0.031594 rank=7
# [SoftImpute] Iter 22: observed MAE=0.031735 rank=7
# [SoftImpute] Iter 23: observed MAE=0.031885 rank=7
# [SoftImpute] Iter 24: observed MAE=0.032033 rank=7
# [SoftImpute] Iter 25: observed MAE=0.032175 rank=7
# [SoftImpute] Iter 26: observed MAE=0.032305 rank=7
# [SoftImpute] Iter 27: observed MAE=0.032423 rank=7
# [SoftImpute] Iter 28: observed MAE=0.032522 rank=7
# [SoftImpute] Iter 29: observed MAE=0.032598 rank=7
# [SoftImpute] Iter 30: observed MAE=0.032657 rank=7
# [SoftImpute] Iter 31: observed MAE=0.032703 rank=7
# [SoftImpute] Iter 32: observed MAE=0.032744 rank=7
# [SoftImpute] Iter 33: observed MAE=0.032778 rank=7
# [SoftImpute] Iter 34: observed MAE=0.032804 rank=7
# [SoftImpute] Iter 35: observed MAE=0.032824 rank=7
# [SoftImpute] Iter 36: observed MAE=0.032842 rank=7
# [SoftImpute] Iter 37: observed MAE=0.032857 rank=7
# [SoftImpute] Iter 38: observed MAE=0.032870 rank=7
# [SoftImpute] Iter 39: observed MAE=0.032881 rank=7
# [SoftImpute] Iter 40: observed MAE=0.032891 rank=7
# [SoftImpute] Iter 41: observed MAE=0.032900 rank=7
# [SoftImpute] Iter 42: observed MAE=0.032907 rank=7
# [SoftImpute] Iter 43: observed MAE=0.032913 rank=7
# [SoftImpute] Iter 44: observed MAE=0.032918 rank=7
# [SoftImpute] Iter 45: observed MAE=0.032923 rank=7
# [SoftImpute] Iter 46: observed MAE=0.032927 rank=7
# [SoftImpute] Iter 47: observed MAE=0.032931 rank=7
# [SoftImpute] Iter 48: observed MAE=0.032934 rank=7
# [SoftImpute] Iter 49: observed MAE=0.032937 rank=7
# [SoftImpute] Iter 50: observed MAE=0.032939 rank=7
# [SoftImpute] Iter 51: observed MAE=0.032942 rank=7
# [SoftImpute] Iter 52: observed MAE=0.032944 rank=7
# [SoftImpute] Iter 53: observed MAE=0.032946 rank=7
# [SoftImpute] Iter 54: observed MAE=0.032948 rank=7
# [SoftImpute] Iter 55: observed MAE=0.032949 rank=7
# [SoftImpute] Iter 56: observed MAE=0.032951 rank=7
# [SoftImpute] Iter 57: observed MAE=0.032952 rank=7
# [SoftImpute] Iter 58: observed MAE=0.032954 rank=7
# [SoftImpute] Iter 59: observed MAE=0.032955 rank=7
# [SoftImpute] Iter 60: observed MAE=0.032956 rank=7
# [SoftImpute] Iter 61: observed MAE=0.032957 rank=7
# [SoftImpute] Iter 62: observed MAE=0.032958 rank=7
# [SoftImpute] Iter 63: observed MAE=0.032959 rank=7
# [SoftImpute] Iter 64: observed MAE=0.032960 rank=7
# [SoftImpute] Iter 65: observed MAE=0.032961 rank=7
# [SoftImpute] Stopped after iteration 65 for lambda=0.543638
# [SoftImpute] Max Singular Value of X_init = 27.520497
# [SoftImpute] Iter 1: observed MAE=0.029522 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029590 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029658 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029728 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029799 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029872 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029951 rank=7
# [SoftImpute] Iter 8: observed MAE=0.030032 rank=7
# [SoftImpute] Iter 9: observed MAE=0.030113 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030198 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030301 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030419 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030552 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030703 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030870 rank=7
# [SoftImpute] Iter 16: observed MAE=0.031060 rank=7
# [SoftImpute] Iter 17: observed MAE=0.031266 rank=7
# [SoftImpute] Iter 18: observed MAE=0.031470 rank=7
# [SoftImpute] Iter 19: observed MAE=0.031663 rank=7
# [SoftImpute] Iter 20: observed MAE=0.031872 rank=7
# [SoftImpute] Iter 21: observed MAE=0.032071 rank=7
# [SoftImpute] Iter 22: observed MAE=0.032243 rank=7
# [SoftImpute] Iter 23: observed MAE=0.032382 rank=7
# [SoftImpute] Iter 24: observed MAE=0.032496 rank=7
# [SoftImpute] Iter 25: observed MAE=0.032584 rank=7
# [SoftImpute] Iter 26: observed MAE=0.032653 rank=7
# [SoftImpute] Iter 27: observed MAE=0.032706 rank=7
# [SoftImpute] Iter 28: observed MAE=0.032745 rank=7
# [SoftImpute] Iter 29: observed MAE=0.032775 rank=7
# [SoftImpute] Iter 30: observed MAE=0.032798 rank=7
# [SoftImpute] Iter 31: observed MAE=0.032816 rank=7
# [SoftImpute] Iter 32: observed MAE=0.032829 rank=7
# [SoftImpute] Iter 33: observed MAE=0.032840 rank=7
# [SoftImpute] Iter 34: observed MAE=0.032850 rank=7
# [SoftImpute] Iter 35: observed MAE=0.032859 rank=7
# [SoftImpute] Iter 36: observed MAE=0.032868 rank=7
# [SoftImpute] Iter 37: observed MAE=0.032876 rank=7
# [SoftImpute] Iter 38: observed MAE=0.032883 rank=7
# [SoftImpute] Iter 39: observed MAE=0.032889 rank=7
# [SoftImpute] Iter 40: observed MAE=0.032895 rank=7
# [SoftImpute] Iter 41: observed MAE=0.032899 rank=7
# [SoftImpute] Iter 42: observed MAE=0.032904 rank=7
# [SoftImpute] Iter 43: observed MAE=0.032908 rank=7
# [SoftImpute] Iter 44: observed MAE=0.032912 rank=7
# [SoftImpute] Iter 45: observed MAE=0.032916 rank=7
# [SoftImpute] Iter 46: observed MAE=0.032920 rank=7
# [SoftImpute] Iter 47: observed MAE=0.032923 rank=7
# [SoftImpute] Iter 48: observed MAE=0.032926 rank=7
# [SoftImpute] Iter 49: observed MAE=0.032929 rank=7
# [SoftImpute] Iter 50: observed MAE=0.032931 rank=7
# [SoftImpute] Iter 51: observed MAE=0.032934 rank=7
# [SoftImpute] Iter 52: observed MAE=0.032936 rank=7
# [SoftImpute] Iter 53: observed MAE=0.032937 rank=7
# [SoftImpute] Iter 54: observed MAE=0.032939 rank=7
# [SoftImpute] Iter 55: observed MAE=0.032941 rank=7
# [SoftImpute] Iter 56: observed MAE=0.032942 rank=7
# [SoftImpute] Stopped after iteration 56 for lambda=0.550410
# [SoftImpute] Max Singular Value of X_init = 26.783614
# [SoftImpute] Iter 1: observed MAE=0.029270 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029347 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029430 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029517 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029606 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029698 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029796 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029894 rank=7
# [SoftImpute] Iter 9: observed MAE=0.029992 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030095 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030201 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030308 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030417 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030531 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030650 rank=7
# [SoftImpute] Iter 16: observed MAE=0.030776 rank=7
# [SoftImpute] Iter 17: observed MAE=0.030902 rank=7
# [SoftImpute] Iter 18: observed MAE=0.031042 rank=7
# [SoftImpute] Iter 19: observed MAE=0.031183 rank=7
# [SoftImpute] Iter 20: observed MAE=0.031321 rank=7
# [SoftImpute] Iter 21: observed MAE=0.031458 rank=7
# [SoftImpute] Iter 22: observed MAE=0.031582 rank=7
# [SoftImpute] Iter 23: observed MAE=0.031689 rank=7
# [SoftImpute] Iter 24: observed MAE=0.031777 rank=7
# [SoftImpute] Iter 25: observed MAE=0.031847 rank=7
# [SoftImpute] Iter 26: observed MAE=0.031898 rank=7
# [SoftImpute] Iter 27: observed MAE=0.031949 rank=7
# [SoftImpute] Iter 28: observed MAE=0.031992 rank=7
# [SoftImpute] Iter 29: observed MAE=0.032031 rank=7
# [SoftImpute] Iter 30: observed MAE=0.032063 rank=7
# [SoftImpute] Iter 31: observed MAE=0.032089 rank=7
# [SoftImpute] Iter 32: observed MAE=0.032110 rank=7
# [SoftImpute] Iter 33: observed MAE=0.032127 rank=7
# [SoftImpute] Iter 34: observed MAE=0.032141 rank=7
# [SoftImpute] Iter 35: observed MAE=0.032145 rank=6
# [SoftImpute] Iter 36: observed MAE=0.032133 rank=6
# [SoftImpute] Iter 37: observed MAE=0.032125 rank=6
# [SoftImpute] Iter 38: observed MAE=0.032120 rank=6
# [SoftImpute] Iter 39: observed MAE=0.032116 rank=6
# [SoftImpute] Iter 40: observed MAE=0.032112 rank=6
# [SoftImpute] Iter 41: observed MAE=0.032109 rank=6
# [SoftImpute] Iter 42: observed MAE=0.032105 rank=6
# [SoftImpute] Iter 43: observed MAE=0.032102 rank=6
# [SoftImpute] Iter 44: observed MAE=0.032098 rank=6
# [SoftImpute] Iter 45: observed MAE=0.032095 rank=6
# [SoftImpute] Iter 46: observed MAE=0.032092 rank=6
# [SoftImpute] Iter 47: observed MAE=0.032089 rank=6
# [SoftImpute] Iter 48: observed MAE=0.032087 rank=6
# [SoftImpute] Iter 49: observed MAE=0.032084 rank=6
# [SoftImpute] Iter 50: observed MAE=0.032082 rank=6
# [SoftImpute] Iter 51: observed MAE=0.032080 rank=6
# [SoftImpute] Iter 52: observed MAE=0.032077 rank=6
# [SoftImpute] Iter 53: observed MAE=0.032075 rank=6
# [SoftImpute] Iter 54: observed MAE=0.032073 rank=6
# [SoftImpute] Iter 55: observed MAE=0.032071 rank=6
# [SoftImpute] Iter 56: observed MAE=0.032069 rank=6
# [SoftImpute] Iter 57: observed MAE=0.032067 rank=6
# [SoftImpute] Iter 58: observed MAE=0.032065 rank=6
# [SoftImpute] Iter 59: observed MAE=0.032063 rank=6
# [SoftImpute] Iter 60: observed MAE=0.032061 rank=6
# [SoftImpute] Iter 61: observed MAE=0.032060 rank=6
# [SoftImpute] Iter 62: observed MAE=0.032058 rank=6
# [SoftImpute] Iter 63: observed MAE=0.032056 rank=6
# [SoftImpute] Iter 64: observed MAE=0.032055 rank=6
# [SoftImpute] Iter 65: observed MAE=0.032053 rank=6
# [SoftImpute] Iter 66: observed MAE=0.032052 rank=6
# [SoftImpute] Iter 67: observed MAE=0.032050 rank=6
# [SoftImpute] Iter 68: observed MAE=0.032049 rank=6
# [SoftImpute] Iter 69: observed MAE=0.032048 rank=6
# [SoftImpute] Iter 70: observed MAE=0.032046 rank=6
# [SoftImpute] Iter 71: observed MAE=0.032045 rank=6
# [SoftImpute] Iter 72: observed MAE=0.032044 rank=6
# [SoftImpute] Stopped after iteration 72 for lambda=0.535672
# [SoftImpute] Max Singular Value of X_init = 27.339021
# [SoftImpute] Iter 1: observed MAE=0.029776 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029858 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029951 rank=7
# [SoftImpute] Iter 4: observed MAE=0.030047 rank=7
# [SoftImpute] Iter 5: observed MAE=0.030150 rank=7
# [SoftImpute] Iter 6: observed MAE=0.030259 rank=7
# [SoftImpute] Iter 7: observed MAE=0.030371 rank=7
# [SoftImpute] Iter 8: observed MAE=0.030483 rank=7
# [SoftImpute] Iter 9: observed MAE=0.030596 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030718 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030853 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030995 rank=7
# [SoftImpute] Iter 13: observed MAE=0.031147 rank=7
# [SoftImpute] Iter 14: observed MAE=0.031294 rank=7
# [SoftImpute] Iter 15: observed MAE=0.031445 rank=7
# [SoftImpute] Iter 16: observed MAE=0.031595 rank=7
# [SoftImpute] Iter 17: observed MAE=0.031736 rank=7
# [SoftImpute] Iter 18: observed MAE=0.031865 rank=7
# [SoftImpute] Iter 19: observed MAE=0.031997 rank=7
# [SoftImpute] Iter 20: observed MAE=0.032144 rank=7
# [SoftImpute] Iter 21: observed MAE=0.032289 rank=7
# [SoftImpute] Iter 22: observed MAE=0.032432 rank=7
# [SoftImpute] Iter 23: observed MAE=0.032539 rank=7
# [SoftImpute] Iter 24: observed MAE=0.032620 rank=7
# [SoftImpute] Iter 25: observed MAE=0.032692 rank=7
# [SoftImpute] Iter 26: observed MAE=0.032749 rank=7
# [SoftImpute] Iter 27: observed MAE=0.032795 rank=7
# [SoftImpute] Iter 28: observed MAE=0.032831 rank=7
# [SoftImpute] Iter 29: observed MAE=0.032861 rank=7
# [SoftImpute] Iter 30: observed MAE=0.032884 rank=7
# [SoftImpute] Iter 31: observed MAE=0.032903 rank=7
# [SoftImpute] Iter 32: observed MAE=0.032917 rank=7
# [SoftImpute] Iter 33: observed MAE=0.032928 rank=7
# [SoftImpute] Iter 34: observed MAE=0.032936 rank=7
# [SoftImpute] Iter 35: observed MAE=0.032942 rank=7
# [SoftImpute] Iter 36: observed MAE=0.032946 rank=7
# [SoftImpute] Iter 37: observed MAE=0.032950 rank=7
# [SoftImpute] Iter 38: observed MAE=0.032952 rank=7
# [SoftImpute] Iter 39: observed MAE=0.032955 rank=7
# [SoftImpute] Iter 40: observed MAE=0.032957 rank=7
# [SoftImpute] Iter 41: observed MAE=0.032959 rank=7
# [SoftImpute] Iter 42: observed MAE=0.032960 rank=7
# [SoftImpute] Iter 43: observed MAE=0.032962 rank=7
# [SoftImpute] Iter 44: observed MAE=0.032963 rank=7
# [SoftImpute] Iter 45: observed MAE=0.032964 rank=7
# [SoftImpute] Iter 46: observed MAE=0.032965 rank=7
# [SoftImpute] Iter 47: observed MAE=0.032966 rank=7
# [SoftImpute] Iter 48: observed MAE=0.032967 rank=7
# [SoftImpute] Iter 49: observed MAE=0.032967 rank=7
# [SoftImpute] Iter 50: observed MAE=0.032968 rank=7
# [SoftImpute] Iter 51: observed MAE=0.032968 rank=7
# [SoftImpute] Iter 52: observed MAE=0.032968 rank=7
# [SoftImpute] Iter 53: observed MAE=0.032969 rank=7
# [SoftImpute] Iter 54: observed MAE=0.032969 rank=7
# [SoftImpute] Iter 55: observed MAE=0.032969 rank=7
# [SoftImpute] Iter 56: observed MAE=0.032969 rank=7
# [SoftImpute] Iter 57: observed MAE=0.032970 rank=7
# [SoftImpute] Iter 58: observed MAE=0.032970 rank=7
# [SoftImpute] Iter 59: observed MAE=0.032970 rank=7
# [SoftImpute] Iter 60: observed MAE=0.032970 rank=7
# [SoftImpute] Iter 61: observed MAE=0.032970 rank=7
# [SoftImpute] Stopped after iteration 61 for lambda=0.546780
# [SoftImpute] Max Singular Value of X_init = 27.073869
# [SoftImpute] Iter 1: observed MAE=0.029638 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029702 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029769 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029839 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029909 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029980 rank=7
# [SoftImpute] Iter 7: observed MAE=0.030054 rank=7
# [SoftImpute] Iter 8: observed MAE=0.030126 rank=7
# [SoftImpute] Iter 9: observed MAE=0.030193 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030260 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030331 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030399 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030465 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030533 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030598 rank=7
# [SoftImpute] Iter 16: observed MAE=0.030661 rank=7
# [SoftImpute] Iter 17: observed MAE=0.030729 rank=7
# [SoftImpute] Iter 18: observed MAE=0.030793 rank=7
# [SoftImpute] Iter 19: observed MAE=0.030861 rank=7
# [SoftImpute] Iter 20: observed MAE=0.030932 rank=7
# [SoftImpute] Iter 21: observed MAE=0.030996 rank=7
# [SoftImpute] Iter 22: observed MAE=0.031059 rank=7
# [SoftImpute] Iter 23: observed MAE=0.031130 rank=7
# [SoftImpute] Iter 24: observed MAE=0.031203 rank=7
# [SoftImpute] Iter 25: observed MAE=0.031270 rank=7
# [SoftImpute] Iter 26: observed MAE=0.031345 rank=7
# [SoftImpute] Iter 27: observed MAE=0.031422 rank=7
# [SoftImpute] Iter 28: observed MAE=0.031497 rank=7
# [SoftImpute] Iter 29: observed MAE=0.031575 rank=7
# [SoftImpute] Iter 30: observed MAE=0.031662 rank=7
# [SoftImpute] Iter 31: observed MAE=0.031746 rank=7
# [SoftImpute] Iter 32: observed MAE=0.031830 rank=7
# [SoftImpute] Iter 33: observed MAE=0.031908 rank=7
# [SoftImpute] Iter 34: observed MAE=0.031986 rank=7
# [SoftImpute] Iter 35: observed MAE=0.032053 rank=7
# [SoftImpute] Iter 36: observed MAE=0.032111 rank=7
# [SoftImpute] Iter 37: observed MAE=0.032162 rank=7
# [SoftImpute] Iter 38: observed MAE=0.032204 rank=7
# [SoftImpute] Iter 39: observed MAE=0.032238 rank=7
# [SoftImpute] Iter 40: observed MAE=0.032267 rank=7
# [SoftImpute] Iter 41: observed MAE=0.032291 rank=7
# [SoftImpute] Iter 42: observed MAE=0.032312 rank=7
# [SoftImpute] Iter 43: observed MAE=0.032329 rank=7
# [SoftImpute] Iter 44: observed MAE=0.032344 rank=7
# [SoftImpute] Iter 45: observed MAE=0.032357 rank=7
# [SoftImpute] Iter 46: observed MAE=0.032368 rank=7
# [SoftImpute] Iter 47: observed MAE=0.032378 rank=7
# [SoftImpute] Iter 48: observed MAE=0.032386 rank=7
# [SoftImpute] Iter 49: observed MAE=0.032393 rank=7
# [SoftImpute] Iter 50: observed MAE=0.032400 rank=7
# [SoftImpute] Iter 51: observed MAE=0.032405 rank=7
# [SoftImpute] Iter 52: observed MAE=0.032410 rank=7
# [SoftImpute] Iter 53: observed MAE=0.032415 rank=7
# [SoftImpute] Iter 54: observed MAE=0.032419 rank=7
# [SoftImpute] Iter 55: observed MAE=0.032422 rank=7
# [SoftImpute] Iter 56: observed MAE=0.032425 rank=7
# [SoftImpute] Iter 57: observed MAE=0.032428 rank=7
# [SoftImpute] Iter 58: observed MAE=0.032430 rank=7
# [SoftImpute] Iter 59: observed MAE=0.032432 rank=7
# [SoftImpute] Iter 60: observed MAE=0.032434 rank=7
# [SoftImpute] Stopped after iteration 60 for lambda=0.541477
# [SoftImpute] Max Singular Value of X_init = 26.867325
# [SoftImpute] Iter 1: observed MAE=0.029437 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029502 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029570 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029638 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029707 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029779 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029854 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029932 rank=7
# [SoftImpute] Iter 9: observed MAE=0.030013 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030097 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030181 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030264 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030345 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030435 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030537 rank=7
# [SoftImpute] Iter 16: observed MAE=0.030649 rank=7
# [SoftImpute] Iter 17: observed MAE=0.030767 rank=7
# [SoftImpute] Iter 18: observed MAE=0.030886 rank=7
# [SoftImpute] Iter 19: observed MAE=0.031017 rank=7
# [SoftImpute] Iter 20: observed MAE=0.031165 rank=7
# [SoftImpute] Iter 21: observed MAE=0.031328 rank=7
# [SoftImpute] Iter 22: observed MAE=0.031509 rank=7
# [SoftImpute] Iter 23: observed MAE=0.031697 rank=7
# [SoftImpute] Iter 24: observed MAE=0.031881 rank=7
# [SoftImpute] Iter 25: observed MAE=0.032036 rank=7
# [SoftImpute] Iter 26: observed MAE=0.032158 rank=7
# [SoftImpute] Iter 27: observed MAE=0.032254 rank=7
# [SoftImpute] Iter 28: observed MAE=0.032331 rank=7
# [SoftImpute] Iter 29: observed MAE=0.032391 rank=7
# [SoftImpute] Iter 30: observed MAE=0.032383 rank=6
# [SoftImpute] Iter 31: observed MAE=0.032382 rank=6
# [SoftImpute] Iter 32: observed MAE=0.032386 rank=6
# [SoftImpute] Iter 33: observed MAE=0.032391 rank=6
# [SoftImpute] Iter 34: observed MAE=0.032394 rank=6
# [SoftImpute] Iter 35: observed MAE=0.032395 rank=6
# [SoftImpute] Iter 36: observed MAE=0.032394 rank=6
# [SoftImpute] Iter 37: observed MAE=0.032392 rank=6
# [SoftImpute] Iter 38: observed MAE=0.032389 rank=6
# [SoftImpute] Iter 39: observed MAE=0.032385 rank=6
# [SoftImpute] Iter 40: observed MAE=0.032381 rank=6
# [SoftImpute] Iter 41: observed MAE=0.032377 rank=6
# [SoftImpute] Iter 42: observed MAE=0.032373 rank=6
# [SoftImpute] Iter 43: observed MAE=0.032368 rank=6
# [SoftImpute] Iter 44: observed MAE=0.032364 rank=6
# [SoftImpute] Iter 45: observed MAE=0.032360 rank=6
# [SoftImpute] Iter 46: observed MAE=0.032356 rank=6
# [SoftImpute] Iter 47: observed MAE=0.032352 rank=6
# [SoftImpute] Iter 48: observed MAE=0.032348 rank=6
# [SoftImpute] Iter 49: observed MAE=0.032345 rank=6
# [SoftImpute] Iter 50: observed MAE=0.032342 rank=6
# [SoftImpute] Iter 51: observed MAE=0.032339 rank=6
# [SoftImpute] Iter 52: observed MAE=0.032336 rank=6
# [SoftImpute] Iter 53: observed MAE=0.032333 rank=6
# [SoftImpute] Iter 54: observed MAE=0.032331 rank=6
# [SoftImpute] Iter 55: observed MAE=0.032329 rank=6
# [SoftImpute] Iter 56: observed MAE=0.032326 rank=6
# [SoftImpute] Iter 57: observed MAE=0.032324 rank=6
# [SoftImpute] Iter 58: observed MAE=0.032322 rank=6
# [SoftImpute] Iter 59: observed MAE=0.032321 rank=6
# [SoftImpute] Iter 60: observed MAE=0.032319 rank=6
# [SoftImpute] Iter 61: observed MAE=0.032317 rank=6
# [SoftImpute] Iter 62: observed MAE=0.032316 rank=6
# [SoftImpute] Iter 63: observed MAE=0.032314 rank=6
# [SoftImpute] Iter 64: observed MAE=0.032313 rank=6
# [SoftImpute] Iter 65: observed MAE=0.032311 rank=6
# [SoftImpute] Stopped after iteration 65 for lambda=0.537347
# [SoftImpute] Max Singular Value of X_init = 26.968840
# [SoftImpute] Iter 1: observed MAE=0.029479 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029546 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029612 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029676 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029738 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029802 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029868 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029932 rank=7
# [SoftImpute] Iter 9: observed MAE=0.029995 rank=7
# [SoftImpute] Iter 10: observed MAE=0.030055 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030120 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030186 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030253 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030322 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030392 rank=7
# [SoftImpute] Iter 16: observed MAE=0.030469 rank=7
# [SoftImpute] Iter 17: observed MAE=0.030555 rank=7
# [SoftImpute] Iter 18: observed MAE=0.030640 rank=7
# [SoftImpute] Iter 19: observed MAE=0.030735 rank=7
# [SoftImpute] Iter 20: observed MAE=0.030834 rank=7
# [SoftImpute] Iter 21: observed MAE=0.030942 rank=7
# [SoftImpute] Iter 22: observed MAE=0.031056 rank=7
# [SoftImpute] Iter 23: observed MAE=0.031190 rank=7
# [SoftImpute] Iter 24: observed MAE=0.031323 rank=7
# [SoftImpute] Iter 25: observed MAE=0.031448 rank=7
# [SoftImpute] Iter 26: observed MAE=0.031571 rank=7
# [SoftImpute] Iter 27: observed MAE=0.031687 rank=7
# [SoftImpute] Iter 28: observed MAE=0.031795 rank=7
# [SoftImpute] Iter 29: observed MAE=0.031746 rank=6
# [SoftImpute] Iter 30: observed MAE=0.031672 rank=6
# [SoftImpute] Iter 31: observed MAE=0.031640 rank=6
# [SoftImpute] Iter 32: observed MAE=0.031629 rank=6
# [SoftImpute] Iter 33: observed MAE=0.031627 rank=6
# [SoftImpute] Iter 34: observed MAE=0.031630 rank=6
# [SoftImpute] Iter 35: observed MAE=0.031635 rank=6
# [SoftImpute] Iter 36: observed MAE=0.031640 rank=6
# [SoftImpute] Iter 37: observed MAE=0.031645 rank=6
# [SoftImpute] Iter 38: observed MAE=0.031651 rank=6
# [SoftImpute] Iter 39: observed MAE=0.031656 rank=6
# [SoftImpute] Iter 40: observed MAE=0.031661 rank=6
# [SoftImpute] Iter 41: observed MAE=0.031667 rank=6
# [SoftImpute] Iter 42: observed MAE=0.031672 rank=6
# [SoftImpute] Iter 43: observed MAE=0.031677 rank=6
# [SoftImpute] Iter 44: observed MAE=0.031681 rank=6
# [SoftImpute] Iter 45: observed MAE=0.031684 rank=6
# [SoftImpute] Iter 46: observed MAE=0.031687 rank=6
# [SoftImpute] Iter 47: observed MAE=0.031690 rank=6
# [SoftImpute] Iter 48: observed MAE=0.031692 rank=6
# [SoftImpute] Iter 49: observed MAE=0.031695 rank=6
# [SoftImpute] Iter 50: observed MAE=0.031697 rank=6
# [SoftImpute] Iter 51: observed MAE=0.031698 rank=6
# [SoftImpute] Iter 52: observed MAE=0.031700 rank=6
# [SoftImpute] Iter 53: observed MAE=0.031701 rank=6
# [SoftImpute] Iter 54: observed MAE=0.031702 rank=6
# [SoftImpute] Iter 55: observed MAE=0.031703 rank=6
# [SoftImpute] Iter 56: observed MAE=0.031704 rank=6
# [SoftImpute] Iter 57: observed MAE=0.031705 rank=6
# [SoftImpute] Iter 58: observed MAE=0.031705 rank=6
# [SoftImpute] Iter 59: observed MAE=0.031706 rank=6
# [SoftImpute] Iter 60: observed MAE=0.031706 rank=6
# [SoftImpute] Iter 61: observed MAE=0.031707 rank=6
# [SoftImpute] Iter 62: observed MAE=0.031707 rank=6
# [SoftImpute] Iter 63: observed MAE=0.031707 rank=6
# [SoftImpute] Iter 64: observed MAE=0.031708 rank=6
# [SoftImpute] Iter 65: observed MAE=0.031708 rank=6
# [SoftImpute] Stopped after iteration 65 for lambda=0.539377
# [SoftImpute] Max Singular Value of X_init = 26.787361
# [SoftImpute] Iter 1: observed MAE=0.029456 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029506 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029560 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029616 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029674 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029734 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029791 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029847 rank=7
# [SoftImpute] Iter 9: observed MAE=0.029902 rank=7
# [SoftImpute] Iter 10: observed MAE=0.029955 rank=7
# [SoftImpute] Iter 11: observed MAE=0.030007 rank=7
# [SoftImpute] Iter 12: observed MAE=0.030064 rank=7
# [SoftImpute] Iter 13: observed MAE=0.030125 rank=7
# [SoftImpute] Iter 14: observed MAE=0.030185 rank=7
# [SoftImpute] Iter 15: observed MAE=0.030249 rank=7
# [SoftImpute] Iter 16: observed MAE=0.030317 rank=7
# [SoftImpute] Iter 17: observed MAE=0.030392 rank=7
# [SoftImpute] Iter 18: observed MAE=0.030472 rank=7
# [SoftImpute] Iter 19: observed MAE=0.030549 rank=7
# [SoftImpute] Iter 20: observed MAE=0.030627 rank=7
# [SoftImpute] Iter 21: observed MAE=0.030705 rank=7
# [SoftImpute] Iter 22: observed MAE=0.030786 rank=7
# [SoftImpute] Iter 23: observed MAE=0.030872 rank=7
# [SoftImpute] Iter 24: observed MAE=0.030955 rank=7
# [SoftImpute] Iter 25: observed MAE=0.031034 rank=7
# [SoftImpute] Iter 26: observed MAE=0.031105 rank=7
# [SoftImpute] Iter 27: observed MAE=0.031193 rank=7
# [SoftImpute] Iter 28: observed MAE=0.031294 rank=7
# [SoftImpute] Iter 29: observed MAE=0.031395 rank=7
# [SoftImpute] Iter 30: observed MAE=0.031490 rank=7
# [SoftImpute] Iter 31: observed MAE=0.031573 rank=7
# [SoftImpute] Iter 32: observed MAE=0.031508 rank=6
# [SoftImpute] Iter 33: observed MAE=0.031457 rank=6
# [SoftImpute] Iter 34: observed MAE=0.031438 rank=6
# [SoftImpute] Iter 35: observed MAE=0.031433 rank=6
# [SoftImpute] Iter 36: observed MAE=0.031437 rank=6
# [SoftImpute] Iter 37: observed MAE=0.031445 rank=6
# [SoftImpute] Iter 38: observed MAE=0.031453 rank=6
# [SoftImpute] Iter 39: observed MAE=0.031461 rank=6
# [SoftImpute] Iter 40: observed MAE=0.031467 rank=6
# [SoftImpute] Iter 41: observed MAE=0.031474 rank=6
# [SoftImpute] Iter 42: observed MAE=0.031480 rank=6
# [SoftImpute] Iter 43: observed MAE=0.031485 rank=6
# [SoftImpute] Iter 44: observed MAE=0.031491 rank=6
# [SoftImpute] Iter 45: observed MAE=0.031495 rank=6
# [SoftImpute] Iter 46: observed MAE=0.031499 rank=6
# [SoftImpute] Iter 47: observed MAE=0.031502 rank=6
# [SoftImpute] Iter 48: observed MAE=0.031504 rank=6
# [SoftImpute] Iter 49: observed MAE=0.031506 rank=6
# [SoftImpute] Iter 50: observed MAE=0.031507 rank=6
# [SoftImpute] Iter 51: observed MAE=0.031508 rank=6
# [SoftImpute] Iter 52: observed MAE=0.031509 rank=6
# [SoftImpute] Iter 53: observed MAE=0.031510 rank=6
# [SoftImpute] Iter 54: observed MAE=0.031511 rank=6
# [SoftImpute] Iter 55: observed MAE=0.031511 rank=6
# [SoftImpute] Iter 56: observed MAE=0.031511 rank=6
# [SoftImpute] Iter 57: observed MAE=0.031512 rank=6
# [SoftImpute] Iter 58: observed MAE=0.031512 rank=6
# [SoftImpute] Iter 59: observed MAE=0.031512 rank=6
# [SoftImpute] Iter 60: observed MAE=0.031513 rank=6
# [SoftImpute] Iter 61: observed MAE=0.031513 rank=6
# [SoftImpute] Iter 62: observed MAE=0.031513 rank=6
# [SoftImpute] Stopped after iteration 62 for lambda=0.535747
# [SoftImpute] Max Singular Value of X_init = 23.985007
# [SoftImpute] Iter 1: observed MAE=0.029115 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029146 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029176 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029204 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029232 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029260 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029287 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029313 rank=7
# [SoftImpute] Iter 9: observed MAE=0.029337 rank=7
# [SoftImpute] Iter 10: observed MAE=0.029360 rank=7
# [SoftImpute] Iter 11: observed MAE=0.029383 rank=7
# [SoftImpute] Iter 12: observed MAE=0.029404 rank=7
# [SoftImpute] Iter 13: observed MAE=0.029426 rank=7
# [SoftImpute] Iter 14: observed MAE=0.029446 rank=7
# [SoftImpute] Iter 15: observed MAE=0.029466 rank=7
# [SoftImpute] Iter 16: observed MAE=0.029486 rank=7
# [SoftImpute] Iter 17: observed MAE=0.029505 rank=7
# [SoftImpute] Iter 18: observed MAE=0.029525 rank=7
# [SoftImpute] Iter 19: observed MAE=0.029550 rank=7
# [SoftImpute] Iter 20: observed MAE=0.029577 rank=7
# [SoftImpute] Iter 21: observed MAE=0.029608 rank=7
# [SoftImpute] Iter 22: observed MAE=0.029642 rank=7
# [SoftImpute] Iter 23: observed MAE=0.029678 rank=7
# [SoftImpute] Iter 24: observed MAE=0.029715 rank=7
# [SoftImpute] Iter 25: observed MAE=0.029755 rank=7
# [SoftImpute] Iter 26: observed MAE=0.029803 rank=7
# [SoftImpute] Iter 27: observed MAE=0.029852 rank=7
# [SoftImpute] Iter 28: observed MAE=0.029903 rank=7
# [SoftImpute] Iter 29: observed MAE=0.029953 rank=7
# [SoftImpute] Iter 30: observed MAE=0.030005 rank=7
# [SoftImpute] Iter 31: observed MAE=0.030057 rank=7
# [SoftImpute] Iter 32: observed MAE=0.030116 rank=7
# [SoftImpute] Iter 33: observed MAE=0.030174 rank=7
# [SoftImpute] Iter 34: observed MAE=0.030232 rank=7
# [SoftImpute] Iter 35: observed MAE=0.030298 rank=7
# [SoftImpute] Iter 36: observed MAE=0.030373 rank=7
# [SoftImpute] Iter 37: observed MAE=0.030445 rank=7
# [SoftImpute] Iter 38: observed MAE=0.030510 rank=7
# [SoftImpute] Iter 39: observed MAE=0.030568 rank=7
# [SoftImpute] Iter 40: observed MAE=0.030616 rank=7
# [SoftImpute] Iter 41: observed MAE=0.030657 rank=7
# [SoftImpute] Iter 42: observed MAE=0.030696 rank=7
# [SoftImpute] Iter 43: observed MAE=0.030730 rank=7
# [SoftImpute] Iter 44: observed MAE=0.030760 rank=7
# [SoftImpute] Iter 45: observed MAE=0.030786 rank=7
# [SoftImpute] Iter 46: observed MAE=0.030807 rank=7
# [SoftImpute] Iter 47: observed MAE=0.030824 rank=7
# [SoftImpute] Iter 48: observed MAE=0.030839 rank=7
# [SoftImpute] Iter 49: observed MAE=0.030852 rank=7
# [SoftImpute] Iter 50: observed MAE=0.030863 rank=7
# [SoftImpute] Iter 51: observed MAE=0.030872 rank=7
# [SoftImpute] Iter 52: observed MAE=0.030881 rank=7
# [SoftImpute] Iter 53: observed MAE=0.030888 rank=7
# [SoftImpute] Iter 54: observed MAE=0.030893 rank=7
# [SoftImpute] Iter 55: observed MAE=0.030898 rank=7
# [SoftImpute] Iter 56: observed MAE=0.030902 rank=7
# [SoftImpute] Iter 57: observed MAE=0.030905 rank=7
# [SoftImpute] Iter 58: observed MAE=0.030907 rank=7
# [SoftImpute] Iter 59: observed MAE=0.030910 rank=7
# [SoftImpute] Iter 60: observed MAE=0.030913 rank=7
# [SoftImpute] Iter 61: observed MAE=0.030915 rank=7
# [SoftImpute] Iter 62: observed MAE=0.030917 rank=7
# [SoftImpute] Iter 63: observed MAE=0.030919 rank=7
# [SoftImpute] Iter 64: observed MAE=0.030920 rank=7
# [SoftImpute] Iter 65: observed MAE=0.030922 rank=7
# [SoftImpute] Iter 66: observed MAE=0.030923 rank=7
# [SoftImpute] Iter 67: observed MAE=0.030924 rank=7
# [SoftImpute] Iter 68: observed MAE=0.030926 rank=7
# [SoftImpute] Iter 69: observed MAE=0.030927 rank=7
# [SoftImpute] Iter 70: observed MAE=0.030928 rank=7
# [SoftImpute] Iter 71: observed MAE=0.030929 rank=7
# [SoftImpute] Iter 72: observed MAE=0.030930 rank=7
# [SoftImpute] Iter 73: observed MAE=0.030931 rank=7
# [SoftImpute] Iter 74: observed MAE=0.030932 rank=7
# [SoftImpute] Iter 75: observed MAE=0.030932 rank=7
# [SoftImpute] Iter 76: observed MAE=0.030933 rank=7
# [SoftImpute] Iter 77: observed MAE=0.030933 rank=7
# [SoftImpute] Iter 78: observed MAE=0.030934 rank=7
# [SoftImpute] Iter 79: observed MAE=0.030934 rank=7
# [SoftImpute] Iter 80: observed MAE=0.030935 rank=7
# [SoftImpute] Iter 81: observed MAE=0.030935 rank=7
# [SoftImpute] Stopped after iteration 81 for lambda=0.479700
# [SoftImpute] Max Singular Value of X_init = 23.887931
# [SoftImpute] Iter 1: observed MAE=0.029522 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029552 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029579 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029604 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029628 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029651 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029673 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029694 rank=7
# [SoftImpute] Iter 9: observed MAE=0.029716 rank=7
# [SoftImpute] Iter 10: observed MAE=0.029733 rank=7
# [SoftImpute] Iter 11: observed MAE=0.029750 rank=7
# [SoftImpute] Iter 12: observed MAE=0.029765 rank=7
# [SoftImpute] Iter 13: observed MAE=0.029777 rank=7
# [SoftImpute] Iter 14: observed MAE=0.029787 rank=7
# [SoftImpute] Iter 15: observed MAE=0.029794 rank=7
# [SoftImpute] Iter 16: observed MAE=0.029798 rank=7
# [SoftImpute] Iter 17: observed MAE=0.029799 rank=7
# [SoftImpute] Iter 18: observed MAE=0.029797 rank=7
# [SoftImpute] Iter 19: observed MAE=0.029790 rank=7
# [SoftImpute] Iter 20: observed MAE=0.029782 rank=7
# [SoftImpute] Iter 21: observed MAE=0.029771 rank=7
# [SoftImpute] Iter 22: observed MAE=0.029757 rank=7
# [SoftImpute] Iter 23: observed MAE=0.029740 rank=7
# [SoftImpute] Iter 24: observed MAE=0.029720 rank=7
# [SoftImpute] Iter 25: observed MAE=0.029696 rank=7
# [SoftImpute] Iter 26: observed MAE=0.029674 rank=7
# [SoftImpute] Iter 27: observed MAE=0.029657 rank=7
# [SoftImpute] Iter 28: observed MAE=0.029640 rank=7
# [SoftImpute] Iter 29: observed MAE=0.029626 rank=7
# [SoftImpute] Iter 30: observed MAE=0.029610 rank=7
# [SoftImpute] Iter 31: observed MAE=0.029592 rank=7
# [SoftImpute] Iter 32: observed MAE=0.029571 rank=7
# [SoftImpute] Iter 33: observed MAE=0.029552 rank=7
# [SoftImpute] Iter 34: observed MAE=0.029536 rank=7
# [SoftImpute] Iter 35: observed MAE=0.029524 rank=7
# [SoftImpute] Iter 36: observed MAE=0.029520 rank=7
# [SoftImpute] Iter 37: observed MAE=0.029516 rank=7
# [SoftImpute] Iter 38: observed MAE=0.029512 rank=7
# [SoftImpute] Iter 39: observed MAE=0.029508 rank=7
# [SoftImpute] Iter 40: observed MAE=0.029505 rank=7
# [SoftImpute] Iter 41: observed MAE=0.029503 rank=7
# [SoftImpute] Iter 42: observed MAE=0.029508 rank=7
# [SoftImpute] Iter 43: observed MAE=0.029515 rank=7
# [SoftImpute] Iter 44: observed MAE=0.029524 rank=7
# [SoftImpute] Iter 45: observed MAE=0.029538 rank=7
# [SoftImpute] Iter 46: observed MAE=0.029557 rank=7
# [SoftImpute] Iter 47: observed MAE=0.029580 rank=7
# [SoftImpute] Iter 48: observed MAE=0.029605 rank=7
# [SoftImpute] Iter 49: observed MAE=0.029631 rank=7
# [SoftImpute] Iter 50: observed MAE=0.029661 rank=7
# [SoftImpute] Iter 51: observed MAE=0.029695 rank=7
# [SoftImpute] Iter 52: observed MAE=0.029730 rank=7
# [SoftImpute] Iter 53: observed MAE=0.029768 rank=7
# [SoftImpute] Iter 54: observed MAE=0.029811 rank=7
# [SoftImpute] Iter 55: observed MAE=0.029858 rank=7
# [SoftImpute] Iter 56: observed MAE=0.029906 rank=7
# [SoftImpute] Iter 57: observed MAE=0.029951 rank=7
# [SoftImpute] Iter 58: observed MAE=0.029996 rank=7
# [SoftImpute] Iter 59: observed MAE=0.030037 rank=7
# [SoftImpute] Iter 60: observed MAE=0.030076 rank=7
# [SoftImpute] Iter 61: observed MAE=0.030113 rank=7
# [SoftImpute] Iter 62: observed MAE=0.030146 rank=7
# [SoftImpute] Iter 63: observed MAE=0.030176 rank=7
# [SoftImpute] Iter 64: observed MAE=0.030202 rank=7
# [SoftImpute] Iter 65: observed MAE=0.030225 rank=7
# [SoftImpute] Iter 66: observed MAE=0.030246 rank=7
# [SoftImpute] Iter 67: observed MAE=0.030265 rank=7
# [SoftImpute] Iter 68: observed MAE=0.030281 rank=7
# [SoftImpute] Iter 69: observed MAE=0.030296 rank=7
# [SoftImpute] Iter 70: observed MAE=0.030309 rank=7
# [SoftImpute] Iter 71: observed MAE=0.030321 rank=7
# [SoftImpute] Iter 72: observed MAE=0.030331 rank=7
# [SoftImpute] Iter 73: observed MAE=0.030341 rank=7
# [SoftImpute] Iter 74: observed MAE=0.030349 rank=7
# [SoftImpute] Iter 75: observed MAE=0.030357 rank=7
# [SoftImpute] Iter 76: observed MAE=0.030364 rank=7
# [SoftImpute] Iter 77: observed MAE=0.030370 rank=7
# [SoftImpute] Iter 78: observed MAE=0.030376 rank=7
# [SoftImpute] Iter 79: observed MAE=0.030382 rank=7
# [SoftImpute] Iter 80: observed MAE=0.030387 rank=7
# [SoftImpute] Iter 81: observed MAE=0.030391 rank=7
# [SoftImpute] Iter 82: observed MAE=0.030388 rank=6
# [SoftImpute] Iter 83: observed MAE=0.030385 rank=6
# [SoftImpute] Iter 84: observed MAE=0.030383 rank=6
# [SoftImpute] Iter 85: observed MAE=0.030381 rank=6
# [SoftImpute] Iter 86: observed MAE=0.030380 rank=6
# [SoftImpute] Iter 87: observed MAE=0.030380 rank=6
# [SoftImpute] Iter 88: observed MAE=0.030379 rank=6
# [SoftImpute] Stopped after iteration 88 for lambda=0.477759
# [SoftImpute] Max Singular Value of X_init = 23.921367
# [SoftImpute] Iter 1: observed MAE=0.029431 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029471 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029509 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029545 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029585 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029625 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029665 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029704 rank=7
# [SoftImpute] Iter 9: observed MAE=0.029742 rank=7
# [SoftImpute] Iter 10: observed MAE=0.029782 rank=7
# [SoftImpute] Iter 11: observed MAE=0.029819 rank=7
# [SoftImpute] Iter 12: observed MAE=0.029855 rank=7
# [SoftImpute] Iter 13: observed MAE=0.029889 rank=7
# [SoftImpute] Iter 14: observed MAE=0.029926 rank=7
# [SoftImpute] Iter 15: observed MAE=0.029962 rank=7
# [SoftImpute] Iter 16: observed MAE=0.029999 rank=7
# [SoftImpute] Iter 17: observed MAE=0.030033 rank=7
# [SoftImpute] Iter 18: observed MAE=0.030070 rank=7
# [SoftImpute] Iter 19: observed MAE=0.030114 rank=7
# [SoftImpute] Iter 20: observed MAE=0.030159 rank=7
# [SoftImpute] Iter 21: observed MAE=0.030202 rank=7
# [SoftImpute] Iter 22: observed MAE=0.030243 rank=7
# [SoftImpute] Iter 23: observed MAE=0.030288 rank=7
# [SoftImpute] Iter 24: observed MAE=0.030331 rank=7
# [SoftImpute] Iter 25: observed MAE=0.030371 rank=7
# [SoftImpute] Iter 26: observed MAE=0.030410 rank=7
# [SoftImpute] Iter 27: observed MAE=0.030450 rank=7
# [SoftImpute] Iter 28: observed MAE=0.030489 rank=7
# [SoftImpute] Iter 29: observed MAE=0.030529 rank=7
# [SoftImpute] Iter 30: observed MAE=0.030570 rank=7
# [SoftImpute] Iter 31: observed MAE=0.030613 rank=7
# [SoftImpute] Iter 32: observed MAE=0.030652 rank=7
# [SoftImpute] Iter 33: observed MAE=0.030690 rank=7
# [SoftImpute] Iter 34: observed MAE=0.030724 rank=7
# [SoftImpute] Iter 35: observed MAE=0.030753 rank=7
# [SoftImpute] Iter 36: observed MAE=0.030779 rank=7
# [SoftImpute] Iter 37: observed MAE=0.030810 rank=7
# [SoftImpute] Iter 38: observed MAE=0.030840 rank=7
# [SoftImpute] Iter 39: observed MAE=0.030869 rank=7
# [SoftImpute] Iter 40: observed MAE=0.030902 rank=7
# [SoftImpute] Iter 41: observed MAE=0.030937 rank=7
# [SoftImpute] Iter 42: observed MAE=0.030970 rank=7
# [SoftImpute] Iter 43: observed MAE=0.031003 rank=7
# [SoftImpute] Iter 44: observed MAE=0.031034 rank=7
# [SoftImpute] Iter 45: observed MAE=0.031061 rank=7
# [SoftImpute] Iter 46: observed MAE=0.031088 rank=7
# [SoftImpute] Iter 47: observed MAE=0.031112 rank=7
# [SoftImpute] Iter 48: observed MAE=0.031136 rank=7
# [SoftImpute] Iter 49: observed MAE=0.031157 rank=7
# [SoftImpute] Iter 50: observed MAE=0.031176 rank=7
# [SoftImpute] Iter 51: observed MAE=0.031193 rank=7
# [SoftImpute] Iter 52: observed MAE=0.031208 rank=7
# [SoftImpute] Iter 53: observed MAE=0.031222 rank=7
# [SoftImpute] Iter 54: observed MAE=0.031234 rank=7
# [SoftImpute] Iter 55: observed MAE=0.031245 rank=7
# [SoftImpute] Iter 56: observed MAE=0.031254 rank=7
# [SoftImpute] Iter 57: observed MAE=0.031262 rank=7
# [SoftImpute] Iter 58: observed MAE=0.031268 rank=7
# [SoftImpute] Iter 59: observed MAE=0.031274 rank=7
# [SoftImpute] Iter 60: observed MAE=0.031279 rank=7
# [SoftImpute] Iter 61: observed MAE=0.031283 rank=7
# [SoftImpute] Iter 62: observed MAE=0.031287 rank=7
# [SoftImpute] Iter 63: observed MAE=0.031291 rank=7
# [SoftImpute] Iter 64: observed MAE=0.031294 rank=7
# [SoftImpute] Iter 65: observed MAE=0.031296 rank=7
# [SoftImpute] Iter 66: observed MAE=0.031298 rank=7
# [SoftImpute] Iter 67: observed MAE=0.031300 rank=7
# [SoftImpute] Iter 68: observed MAE=0.031301 rank=7
# [SoftImpute] Iter 69: observed MAE=0.031303 rank=7
# [SoftImpute] Iter 70: observed MAE=0.031304 rank=7
# [SoftImpute] Iter 71: observed MAE=0.031306 rank=7
# [SoftImpute] Iter 72: observed MAE=0.031307 rank=7
# [SoftImpute] Iter 73: observed MAE=0.031308 rank=7
# [SoftImpute] Iter 74: observed MAE=0.031308 rank=7
# [SoftImpute] Iter 75: observed MAE=0.031309 rank=7
# [SoftImpute] Iter 76: observed MAE=0.031310 rank=7
# [SoftImpute] Iter 77: observed MAE=0.031311 rank=7
# [SoftImpute] Iter 78: observed MAE=0.031312 rank=7
# [SoftImpute] Iter 79: observed MAE=0.031313 rank=7
# [SoftImpute] Iter 80: observed MAE=0.031314 rank=7
# [SoftImpute] Iter 81: observed MAE=0.031314 rank=7
# [SoftImpute] Iter 82: observed MAE=0.031315 rank=7
# [SoftImpute] Iter 83: observed MAE=0.031315 rank=7
# [SoftImpute] Iter 84: observed MAE=0.031316 rank=7
# [SoftImpute] Iter 85: observed MAE=0.031316 rank=7
# [SoftImpute] Iter 86: observed MAE=0.031317 rank=7
# [SoftImpute] Iter 87: observed MAE=0.031317 rank=7
# [SoftImpute] Iter 88: observed MAE=0.031317 rank=7
# [SoftImpute] Stopped after iteration 88 for lambda=0.478427
# [SoftImpute] Max Singular Value of X_init = 23.806095
# [SoftImpute] Iter 1: observed MAE=0.029069 rank=7
# [SoftImpute] Iter 2: observed MAE=0.029104 rank=7
# [SoftImpute] Iter 3: observed MAE=0.029139 rank=7
# [SoftImpute] Iter 4: observed MAE=0.029176 rank=7
# [SoftImpute] Iter 5: observed MAE=0.029212 rank=7
# [SoftImpute] Iter 6: observed MAE=0.029247 rank=7
# [SoftImpute] Iter 7: observed MAE=0.029282 rank=7
# [SoftImpute] Iter 8: observed MAE=0.029316 rank=7
# [SoftImpute] Iter 9: observed MAE=0.029350 rank=7
# [SoftImpute] Iter 10: observed MAE=0.029384 rank=7
# [SoftImpute] Iter 11: observed MAE=0.029416 rank=7
# [SoftImpute] Iter 12: observed MAE=0.029451 rank=7
# [SoftImpute] Iter 13: observed MAE=0.029488 rank=7
# [SoftImpute] Iter 14: observed MAE=0.029523 rank=7
# [SoftImpute] Iter 15: observed MAE=0.029558 rank=7
# [SoftImpute] Iter 16: observed MAE=0.029591 rank=7
# [SoftImpute] Iter 17: observed MAE=0.029624 rank=7
# [SoftImpute] Iter 18: observed MAE=0.029656 rank=7
# [SoftImpute] Iter 19: observed MAE=0.029686 rank=7
# [SoftImpute] Iter 20: observed MAE=0.029715 rank=7
# [SoftImpute] Iter 21: observed MAE=0.029743 rank=7
# [SoftImpute] Iter 22: observed MAE=0.029770 rank=7
# [SoftImpute] Iter 23: observed MAE=0.029799 rank=7
# [SoftImpute] Iter 24: observed MAE=0.029826 rank=7
# [SoftImpute] Iter 25: observed MAE=0.029850 rank=7
# [SoftImpute] Iter 26: observed MAE=0.029876 rank=7
# [SoftImpute] Iter 27: observed MAE=0.029900 rank=7
# [SoftImpute] Iter 28: observed MAE=0.029925 rank=7
# [SoftImpute] Iter 29: observed MAE=0.029952 rank=7
# ...
# [SoftImpute] Iter 98: observed MAE=0.026305 rank=7
# [SoftImpute] Iter 99: observed MAE=0.026302 rank=7
# [SoftImpute] Iter 100: observed MAE=0.026298 rank=7
# [SoftImpute] Stopped after iteration 100 for lambda=0.326417
# [SoftImpute] Max Singular Value of X_init = 16.262049
# [SoftImpute] Iter 1: observed MAE=0.026756 rank=7
# [SoftImpute] Iter 2: observed MAE=0.026761 rank=7
# [SoftImpute] Iter 3: observed MAE=0.026765 rank=7
# [SoftImpute] Iter 4: observed MAE=0.026768 rank=7
# [SoftImpute] Iter 5: observed MAE=0.026772 rank=7
# [SoftImpute] Iter 6: observed MAE=0.026774 rank=7
# [SoftImpute] Iter 7: observed MAE=0.026777 rank=7
# [SoftImpute] Iter 8: observed MAE=0.026779 rank=7
# [SoftImpute] Iter 9: observed MAE=0.026780 rank=7
# [SoftImpute] Iter 10: observed MAE=0.026782 rank=7
# [SoftImpute] Iter 11: observed MAE=0.026784 rank=7
# [SoftImpute] Iter 12: observed MAE=0.026785 rank=7
# [SoftImpute] Iter 13: observed MAE=0.026786 rank=7
# [SoftImpute] Iter 14: observed MAE=0.026788 rank=7
# [SoftImpute] Iter 15: observed MAE=0.026790 rank=7
# [SoftImpute] Iter 16: observed MAE=0.026791 rank=7
# [SoftImpute] Iter 17: observed MAE=0.026792 rank=7
# [SoftImpute] Iter 18: observed MAE=0.026792 rank=7
# [SoftImpute] Iter 19: observed MAE=0.026792 rank=7
# [SoftImpute] Iter 20: observed MAE=0.026791 rank=7
# [SoftImpute] Iter 21: observed MAE=0.026789 rank=7
# [SoftImpute] Iter 22: observed MAE=0.026787 rank=7
# [SoftImpute] Iter 23: observed MAE=0.026785 rank=7
# [SoftImpute] Iter 24: observed MAE=0.026782 rank=7
# [SoftImpute] Iter 25: observed MAE=0.026778 rank=7
# [SoftImpute] Iter 26: observed MAE=0.026775 rank=7
# [SoftImpute] Iter 27: observed MAE=0.026771 rank=7
# [SoftImpute] Iter 28: observed MAE=0.026766 rank=7
# [SoftImpute] Iter 29: observed MAE=0.026761 rank=7
# [SoftImpute] Iter 30: observed MAE=0.026756 rank=7
# [SoftImpute] Iter 31: observed MAE=0.026751 rank=7
# [SoftImpute] Iter 32: observed MAE=0.026747 rank=7
# [SoftImpute] Iter 33: observed MAE=0.026744 rank=7
# [SoftImpute] Iter 34: observed MAE=0.026741 rank=7
# [SoftImpute] Iter 35: observed MAE=0.026737 rank=7
# [SoftImpute] Iter 36: observed MAE=0.026733 rank=7
# [SoftImpute] Iter 37: observed MAE=0.026729 rank=7
# [SoftImpute] Iter 38: observed MAE=0.026725 rank=7
# [SoftImpute] Iter 39: observed MAE=0.026720 rank=7
# [SoftImpute] Iter 40: observed MAE=0.026715 rank=7
# [SoftImpute] Iter 41: observed MAE=0.026711 rank=7
# [SoftImpute] Iter 42: observed MAE=0.026705 rank=7
# [SoftImpute] Iter 43: observed MAE=0.026700 rank=7
# [SoftImpute] Iter 44: observed MAE=0.026694 rank=7
# [SoftImpute] Iter 45: observed MAE=0.026687 rank=7
# [SoftImpute] Iter 46: observed MAE=0.026680 rank=7
# [SoftImpute] Iter 47: observed MAE=0.026672 rank=7
# [SoftImpute] Iter 48: observed MAE=0.026664 rank=7
# [SoftImpute] Iter 49: observed MAE=0.026657 rank=7
# [SoftImpute] Iter 50: observed MAE=0.026649 rank=7
# [SoftImpute] Iter 51: observed MAE=0.026642 rank=7
# [SoftImpute] Iter 52: observed MAE=0.026635 rank=7
# [SoftImpute] Iter 53: observed MAE=0.026627 rank=7
# [SoftImpute] Iter 54: observed MAE=0.026620 rank=7
# [SoftImpute] Iter 55: observed MAE=0.026611 rank=7
# [SoftImpute] Iter 56: observed MAE=0.026604 rank=7
# [SoftImpute] Iter 57: observed MAE=0.026596 rank=7
# [SoftImpute] Iter 58: observed MAE=0.026588 rank=7
# [SoftImpute] Iter 59: observed MAE=0.026579 rank=7
# [SoftImpute] Iter 60: observed MAE=0.026570 rank=7
# [SoftImpute] Iter 61: observed MAE=0.026561 rank=7
# [SoftImpute] Iter 62: observed MAE=0.026552 rank=7
# [SoftImpute] Iter 63: observed MAE=0.026545 rank=7
# [SoftImpute] Iter 64: observed MAE=0.026538 rank=7
# [SoftImpute] Iter 65: observed MAE=0.026532 rank=7
# [SoftImpute] Iter 66: observed MAE=0.026527 rank=7
# [SoftImpute] Iter 67: observed MAE=0.026523 rank=7
# [SoftImpute] Iter 68: observed MAE=0.026519 rank=7
# [SoftImpute] Iter 69: observed MAE=0.026515 rank=7
# [SoftImpute] Iter 70: observed MAE=0.026510 rank=7
# [SoftImpute] Iter 71: observed MAE=0.026505 rank=7
# [SoftImpute] Iter 72: observed MAE=0.026501 rank=7
# [SoftImpute] Iter 73: observed MAE=0.026496 rank=7
# [SoftImpute] Iter 74: observed MAE=0.026491 rank=7
# [SoftImpute] Iter 75: observed MAE=0.026486 rank=7
# [SoftImpute] Iter 76: observed MAE=0.026481 rank=7
# [SoftImpute] Iter 77: observed MAE=0.026478 rank=7
# [SoftImpute] Iter 78: observed MAE=0.026475 rank=7
# [SoftImpute] Iter 79: observed MAE=0.026474 rank=7
# [SoftImpute] Iter 80: observed MAE=0.026473 rank=7
# [SoftImpute] Iter 81: observed MAE=0.026472 rank=7
# [SoftImpute] Iter 82: observed MAE=0.026471 rank=7
# [SoftImpute] Iter 83: observed MAE=0.026470 rank=7
# [SoftImpute] Iter 84: observed MAE=0.026471 rank=7
# [SoftImpute] Iter 85: observed MAE=0.026471 rank=7
# [SoftImpute] Iter 86: observed MAE=0.026471 rank=7
# [SoftImpute] Iter 87: observed MAE=0.026472 rank=7
# [SoftImpute] Iter 88: observed MAE=0.026473 rank=7
# [SoftImpute] Iter 89: observed MAE=0.026475 rank=7
# [SoftImpute] Iter 90: observed MAE=0.026478 rank=7
# [SoftImpute] Iter 91: observed MAE=0.026481 rank=7
# [SoftImpute] Iter 92: observed MAE=0.026484 rank=7
# [SoftImpute] Iter 93: observed MAE=0.026487 rank=7
# [SoftImpute] Iter 94: observed MAE=0.026490 rank=7
# [SoftImpute] Iter 95: observed MAE=0.026494 rank=7
# [SoftImpute] Iter 96: observed MAE=0.026499 rank=7
# [SoftImpute] Iter 97: observed MAE=0.026504 rank=7
# [SoftImpute] Iter 98: observed MAE=0.026509 rank=7
# [SoftImpute] Iter 99: observed MAE=0.026514 rank=7
# [SoftImpute] Iter 100: observed MAE=0.026519 rank=7
# [SoftImpute] Stopped after iteration 100 for lambda=0.325241
# [SoftImpute] Max Singular Value of X_init = 16.287202
# [SoftImpute] Iter 1: observed MAE=0.026909 rank=7
# [SoftImpute] Iter 2: observed MAE=0.026912 rank=7
# [SoftImpute] Iter 3: observed MAE=0.026914 rank=7
# [SoftImpute] Iter 4: observed MAE=0.026916 rank=7
# [SoftImpute] Iter 5: observed MAE=0.026918 rank=7
# [SoftImpute] Iter 6: observed MAE=0.026919 rank=7
# [SoftImpute] Iter 7: observed MAE=0.026921 rank=7
# [SoftImpute] Iter 8: observed MAE=0.026922 rank=7
# [SoftImpute] Iter 9: observed MAE=0.026923 rank=7
# [SoftImpute] Iter 10: observed MAE=0.026924 rank=7
# [SoftImpute] Iter 11: observed MAE=0.026924 rank=7
# [SoftImpute] Iter 12: observed MAE=0.026925 rank=7
# [SoftImpute] Iter 13: observed MAE=0.026927 rank=7
# [SoftImpute] Iter 14: observed MAE=0.026928 rank=7
# [SoftImpute] Iter 15: observed MAE=0.026929 rank=7
# [SoftImpute] Iter 16: observed MAE=0.026930 rank=7
# [SoftImpute] Iter 17: observed MAE=0.026930 rank=7
# [SoftImpute] Iter 18: observed MAE=0.026930 rank=7
# [SoftImpute] Iter 19: observed MAE=0.026931 rank=7
# [SoftImpute] Iter 20: observed MAE=0.026931 rank=7
# [SoftImpute] Iter 21: observed MAE=0.026930 rank=7
# [SoftImpute] Iter 22: observed MAE=0.026929 rank=7
# [SoftImpute] Iter 23: observed MAE=0.026928 rank=7
# [SoftImpute] Iter 24: observed MAE=0.026926 rank=7
# [SoftImpute] Iter 25: observed MAE=0.026924 rank=7
# [SoftImpute] Iter 26: observed MAE=0.026923 rank=7
# [SoftImpute] Iter 27: observed MAE=0.026922 rank=7
# [SoftImpute] Iter 28: observed MAE=0.026921 rank=7
# [SoftImpute] Iter 29: observed MAE=0.026919 rank=7
# [SoftImpute] Iter 30: observed MAE=0.026917 rank=7
# [SoftImpute] Iter 31: observed MAE=0.026916 rank=7
# [SoftImpute] Iter 32: observed MAE=0.026914 rank=7
# [SoftImpute] Iter 33: observed MAE=0.026912 rank=7
# [SoftImpute] Iter 34: observed MAE=0.026909 rank=7
# [SoftImpute] Iter 35: observed MAE=0.026906 rank=7
# [SoftImpute] Iter 36: observed MAE=0.026904 rank=7
# [SoftImpute] Iter 37: observed MAE=0.026900 rank=7
# [SoftImpute] Iter 38: observed MAE=0.026897 rank=7
# [SoftImpute] Iter 39: observed MAE=0.026894 rank=7
# [SoftImpute] Iter 40: observed MAE=0.026892 rank=7
# [SoftImpute] Iter 41: observed MAE=0.026888 rank=7
# [SoftImpute] Iter 42: observed MAE=0.026886 rank=7
# [SoftImpute] Iter 43: observed MAE=0.026882 rank=7
# [SoftImpute] Iter 44: observed MAE=0.026879 rank=7
# [SoftImpute] Iter 45: observed MAE=0.026876 rank=7
# [SoftImpute] Iter 46: observed MAE=0.026873 rank=7
# [SoftImpute] Iter 47: observed MAE=0.026870 rank=7
# [SoftImpute] Iter 48: observed MAE=0.026866 rank=7
# [SoftImpute] Iter 49: observed MAE=0.026864 rank=7
# [SoftImpute] Iter 50: observed MAE=0.026860 rank=7
# [SoftImpute] Iter 51: observed MAE=0.026857 rank=7
# [SoftImpute] Iter 52: observed MAE=0.026853 rank=7
# [SoftImpute] Iter 53: observed MAE=0.026850 rank=7
# [SoftImpute] Iter 54: observed MAE=0.026846 rank=7
# [SoftImpute] Iter 55: observed MAE=0.026842 rank=7
# [SoftImpute] Iter 56: observed MAE=0.026838 rank=7
# [SoftImpute] Iter 57: observed MAE=0.026833 rank=7
# [SoftImpute] Iter 58: observed MAE=0.026828 rank=7
# [SoftImpute] Iter 59: observed MAE=0.026822 rank=7
# [SoftImpute] Iter 60: observed MAE=0.026817 rank=7
# [SoftImpute] Iter 61: observed MAE=0.026812 rank=7
# [SoftImpute] Iter 62: observed MAE=0.026807 rank=7
# [SoftImpute] Iter 63: observed MAE=0.026802 rank=7
# [SoftImpute] Iter 64: observed MAE=0.026797 rank=7
# [SoftImpute] Iter 65: observed MAE=0.026792 rank=7
# [SoftImpute] Iter 66: observed MAE=0.026786 rank=7
# [SoftImpute] Iter 67: observed MAE=0.026780 rank=7
# [SoftImpute] Iter 68: observed MAE=0.026774 rank=7
# [SoftImpute] Iter 69: observed MAE=0.026767 rank=7
# [SoftImpute] Iter 70: observed MAE=0.026759 rank=7
# [SoftImpute] Iter 71: observed MAE=0.026752 rank=7
# [SoftImpute] Iter 72: observed MAE=0.026744 rank=7
# [SoftImpute] Iter 73: observed MAE=0.026736 rank=7
# [SoftImpute] Iter 74: observed MAE=0.026728 rank=7
# [SoftImpute] Iter 75: observed MAE=0.026719 rank=7
# [SoftImpute] Iter 76: observed MAE=0.026711 rank=7
# [SoftImpute] Iter 77: observed MAE=0.026701 rank=7
# [SoftImpute] Iter 78: observed MAE=0.026693 rank=7
# [SoftImpute] Iter 79: observed MAE=0.026684 rank=7
# [SoftImpute] Iter 80: observed MAE=0.026676 rank=7
# [SoftImpute] Iter 81: observed MAE=0.026668 rank=7
# [SoftImpute] Iter 82: observed MAE=0.026660 rank=7
# [SoftImpute] Iter 83: observed MAE=0.026652 rank=7
# [SoftImpute] Iter 84: observed MAE=0.026644 rank=7
# [SoftImpute] Iter 85: observed MAE=0.026636 rank=7
# [SoftImpute] Iter 86: observed MAE=0.026628 rank=7
# [SoftImpute] Iter 87: observed MAE=0.026621 rank=7
# [SoftImpute] Iter 88: observed MAE=0.026614 rank=7
# [SoftImpute] Iter 89: observed MAE=0.026606 rank=7
# [SoftImpute] Iter 90: observed MAE=0.026598 rank=7
# [SoftImpute] Iter 91: observed MAE=0.026591 rank=7
# [SoftImpute] Iter 92: observed MAE=0.026585 rank=7
# [SoftImpute] Iter 93: observed MAE=0.026579 rank=7
# [SoftImpute] Iter 94: observed MAE=0.026573 rank=7
# [SoftImpute] Iter 95: observed MAE=0.026567 rank=7
# [SoftImpute] Iter 96: observed MAE=0.026562 rank=7
# [SoftImpute] Iter 97: observed MAE=0.026557 rank=7
# [SoftImpute] Iter 98: observed MAE=0.026554 rank=7
# [SoftImpute] Iter 99: observed MAE=0.026552 rank=7
# [SoftImpute] Iter 100: observed MAE=0.026551 rank=7
# [SoftImpute] Stopped after iteration 100 for lambda=0.325744
# [SoftImpute] Max Singular Value of X_init = 16.240576
# [SoftImpute] Iter 1: observed MAE=0.027266 rank=7
# [SoftImpute] Iter 2: observed MAE=0.027269 rank=7
# [SoftImpute] Iter 3: observed MAE=0.027271 rank=7
# [SoftImpute] Iter 4: observed MAE=0.027274 rank=7
# [SoftImpute] Iter 5: observed MAE=0.027275 rank=7
# [SoftImpute] Iter 6: observed MAE=0.027277 rank=7
# [SoftImpute] Iter 7: observed MAE=0.027278 rank=7
# [SoftImpute] Iter 8: observed MAE=0.027280 rank=7
# [SoftImpute] Iter 9: observed MAE=0.027281 rank=7
# [SoftImpute] Iter 10: observed MAE=0.027281 rank=7
# [SoftImpute] Iter 11: observed MAE=0.027282 rank=7
# [SoftImpute] Iter 12: observed MAE=0.027283 rank=7
# [SoftImpute] Iter 13: observed MAE=0.027283 rank=7
# [SoftImpute] Iter 14: observed MAE=0.027284 rank=7
# [SoftImpute] Iter 15: observed MAE=0.027285 rank=7
# [SoftImpute] Iter 16: observed MAE=0.027285 rank=7
# [SoftImpute] Iter 17: observed MAE=0.027285 rank=7
# [SoftImpute] Iter 18: observed MAE=0.027285 rank=7
# [SoftImpute] Iter 19: observed MAE=0.027285 rank=7
# [SoftImpute] Iter 20: observed MAE=0.027284 rank=7
# [SoftImpute] Iter 21: observed MAE=0.027282 rank=7
# [SoftImpute] Iter 22: observed MAE=0.027280 rank=7
# [SoftImpute] Iter 23: observed MAE=0.027279 rank=7
# [SoftImpute] Iter 24: observed MAE=0.027277 rank=7
# [SoftImpute] Iter 25: observed MAE=0.027274 rank=7
# [SoftImpute] Iter 26: observed MAE=0.027271 rank=7
# [SoftImpute] Iter 27: observed MAE=0.027269 rank=7
# [SoftImpute] Iter 28: observed MAE=0.027265 rank=7
# [SoftImpute] Iter 29: observed MAE=0.027262 rank=7
# [SoftImpute] Iter 30: observed MAE=0.027258 rank=7
# [SoftImpute] Iter 31: observed MAE=0.027255 rank=7
# [SoftImpute] Iter 32: observed MAE=0.027252 rank=7
# [SoftImpute] Iter 33: observed MAE=0.027248 rank=7
# [SoftImpute] Iter 34: observed MAE=0.027244 rank=7
# [SoftImpute] Iter 35: observed MAE=0.027239 rank=7
# [SoftImpute] Iter 36: observed MAE=0.027235 rank=7
# [SoftImpute] Iter 37: observed MAE=0.027230 rank=7
# [SoftImpute] Iter 38: observed MAE=0.027226 rank=7
# [SoftImpute] Iter 39: observed MAE=0.027222 rank=7
# [SoftImpute] Iter 40: observed MAE=0.027218 rank=7
# [SoftImpute] Iter 41: observed MAE=0.027214 rank=7
# [SoftImpute] Iter 42: observed MAE=0.027211 rank=7
# [SoftImpute] Iter 43: observed MAE=0.027208 rank=7
# [SoftImpute] Iter 44: observed MAE=0.027204 rank=7
# [SoftImpute] Iter 45: observed MAE=0.027200 rank=7
# [SoftImpute] Iter 46: observed MAE=0.027195 rank=7
# [SoftImpute] Iter 47: observed MAE=0.027189 rank=7
# [SoftImpute] Iter 48: observed MAE=0.027183 rank=7
# [SoftImpute] Iter 49: observed MAE=0.027177 rank=7
# [SoftImpute] Iter 50: observed MAE=0.027171 rank=7
# [SoftImpute] Iter 51: observed MAE=0.027164 rank=7
# [SoftImpute] Iter 52: observed MAE=0.027157 rank=7
# [SoftImpute] Iter 53: observed MAE=0.027149 rank=7
# [SoftImpute] Iter 54: observed MAE=0.027142 rank=7
# [SoftImpute] Iter 55: observed MAE=0.027134 rank=7
# [SoftImpute] Iter 56: observed MAE=0.027127 rank=7
# [SoftImpute] Iter 57: observed MAE=0.027120 rank=7
# [SoftImpute] Iter 58: observed MAE=0.027114 rank=7
# [SoftImpute] Iter 59: observed MAE=0.027109 rank=7
# [SoftImpute] Iter 60: observed MAE=0.027103 rank=7
# [SoftImpute] Iter 61: observed MAE=0.027097 rank=7
# [SoftImpute] Iter 62: observed MAE=0.027091 rank=7
# [SoftImpute] Iter 63: observed MAE=0.027085 rank=7
# [SoftImpute] Iter 64: observed MAE=0.027078 rank=7
# [SoftImpute] Iter 65: observed MAE=0.027071 rank=7
# [SoftImpute] Iter 66: observed MAE=0.027065 rank=7
# [SoftImpute] Iter 67: observed MAE=0.027059 rank=7
# [SoftImpute] Iter 68: observed MAE=0.027053 rank=7
# [SoftImpute] Iter 69: observed MAE=0.027047 rank=7
# [SoftImpute] Iter 70: observed MAE=0.027041 rank=7
# [SoftImpute] Iter 71: observed MAE=0.027034 rank=7
# [SoftImpute] Iter 72: observed MAE=0.027027 rank=7
# [SoftImpute] Iter 73: observed MAE=0.027021 rank=7
# [SoftImpute] Iter 74: observed MAE=0.027014 rank=7
# [SoftImpute] Iter 75: observed MAE=0.027008 rank=7
# [SoftImpute] Iter 76: observed MAE=0.027002 rank=7
# [SoftImpute] Iter 77: observed MAE=0.026996 rank=7
# [SoftImpute] Iter 78: observed MAE=0.026990 rank=7
# [SoftImpute] Iter 79: observed MAE=0.026985 rank=7
# [SoftImpute] Iter 80: observed MAE=0.026979 rank=7
# [SoftImpute] Iter 81: observed MAE=0.026973 rank=7
# [SoftImpute] Iter 82: observed MAE=0.026967 rank=7
# [SoftImpute] Iter 83: observed MAE=0.026961 rank=7
# [SoftImpute] Iter 84: observed MAE=0.026955 rank=7
# [SoftImpute] Iter 85: observed MAE=0.026949 rank=7
# [SoftImpute] Iter 86: observed MAE=0.026943 rank=7
# [SoftImpute] Iter 87: observed MAE=0.026938 rank=7
# [SoftImpute] Iter 88: observed MAE=0.026934 rank=7
# [SoftImpute] Iter 89: observed MAE=0.026931 rank=7
# [SoftImpute] Iter 90: observed MAE=0.026927 rank=7
# [SoftImpute] Iter 91: observed MAE=0.026925 rank=7
# [SoftImpute] Iter 92: observed MAE=0.026922 rank=7
# [SoftImpute] Iter 93: observed MAE=0.026920 rank=7
# [SoftImpute] Iter 94: observed MAE=0.026917 rank=7
# [SoftImpute] Iter 95: observed MAE=0.026914 rank=7
# [SoftImpute] Iter 96: observed MAE=0.026911 rank=7
# [SoftImpute] Iter 97: observed MAE=0.026908 rank=7
# [SoftImpute] Iter 98: observed MAE=0.026905 rank=7
# [SoftImpute] Iter 99: observed MAE=0.026901 rank=7
# [SoftImpute] Iter 100: observed MAE=0.026898 rank=7
# [SoftImpute] Stopped after iteration 100 for lambda=0.324812
# array([[0.006, 0.002],
#        [0.011, 0.002],
#        [0.017, 0.002],
#        [0.023, 0.002],
#        [0.031, 0.004]])

# %% [markdown]
# # wine
# The data set is also available in sklearn, as noted in the package's website. So, we load it directly from sklearn

# %%
wine = datasets.load_wine()
X,y = wine.data, wine.target.ravel() 
# sum(y==0), sum(y==1), sum(y==2)

# %%
mle_err = np.array([compute_err_mle(X, y, G, .2, runs = 10),
                    compute_err_mle(X, y, G, .35, runs = 10),
                    compute_err_mle(X, y, G, .5, runs = 10),
                    compute_err_mle(X, y, G, .65, runs = 10),
                    compute_err_mle(X, y, G, .8, runs = 10)])
mle_err.round(3)
# Out:
# array([[0.005, 0.001],
#        [0.007, 0.001],
#        [0.009, 0.001],
#        [0.01 , 0.001],
#        [0.013, 0.002]])

# %%
G = 3
mice_err = np.array([compute_err_mice(X, y, G, .2, runs = 10),
                    compute_err_mice(X, y, G, .35, runs = 10),
                    compute_err_mice(X, y, G, .5, runs = 10),
                    compute_err_mice(X, y, G, .65, runs = 10),
                    compute_err_mice(X, y, G, .8, runs = 10)])
mice_err.round(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# array([[0.006, 0.002],
#        [0.01 , 0.001],
#        [0.012, 0.001],
#        [0.016, 0.001],
#        [0.021, 0.001]])

# %%
G = 3
soft_err = np.array([compute_err_soft(X, y, G, .2, runs = 10),
                    compute_err_soft(X, y, G, .35, runs = 10),
                    compute_err_soft(X, y, G, .5, runs = 10),
                    compute_err_soft(X, y, G, .65, runs = 10),
                    compute_err_soft(X, y, G, .8, runs = 10)])
soft_err.round(3)
# Out:
# [SoftImpute] Max Singular Value of X_init = 24.720707
# [SoftImpute] Iter 1: observed MAE=0.031373 rank=13
# [SoftImpute] Iter 2: observed MAE=0.031426 rank=13
# [SoftImpute] Iter 3: observed MAE=0.031476 rank=13
# [SoftImpute] Iter 4: observed MAE=0.031525 rank=13
# [SoftImpute] Iter 5: observed MAE=0.031573 rank=13
# [SoftImpute] Iter 6: observed MAE=0.031617 rank=13
# [SoftImpute] Iter 7: observed MAE=0.031659 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031698 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031735 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031769 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031800 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031829 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031855 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031879 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031901 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031922 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031942 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031960 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031977 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031993 rank=13
# [SoftImpute] Iter 21: observed MAE=0.032007 rank=13
# [SoftImpute] Iter 22: observed MAE=0.032020 rank=13
# [SoftImpute] Iter 23: observed MAE=0.032032 rank=13
# [SoftImpute] Iter 24: observed MAE=0.032042 rank=13
# [SoftImpute] Iter 25: observed MAE=0.032051 rank=13
# [SoftImpute] Iter 26: observed MAE=0.032058 rank=13
# [SoftImpute] Iter 27: observed MAE=0.032064 rank=13
# [SoftImpute] Iter 28: observed MAE=0.032070 rank=13
# [SoftImpute] Iter 29: observed MAE=0.032074 rank=13
# [SoftImpute] Iter 30: observed MAE=0.032078 rank=13
# [SoftImpute] Iter 31: observed MAE=0.032082 rank=13
# [SoftImpute] Iter 32: observed MAE=0.032084 rank=13
# [SoftImpute] Iter 33: observed MAE=0.032086 rank=13
# [SoftImpute] Iter 34: observed MAE=0.032088 rank=13
# [SoftImpute] Iter 35: observed MAE=0.032090 rank=13
# [SoftImpute] Iter 36: observed MAE=0.032091 rank=13
# [SoftImpute] Iter 37: observed MAE=0.032093 rank=13
# [SoftImpute] Iter 38: observed MAE=0.032094 rank=13
# [SoftImpute] Iter 39: observed MAE=0.032095 rank=13
# [SoftImpute] Iter 40: observed MAE=0.032096 rank=13
# [SoftImpute] Iter 41: observed MAE=0.032097 rank=13
# [SoftImpute] Iter 42: observed MAE=0.032097 rank=13
# [SoftImpute] Iter 43: observed MAE=0.032098 rank=13
# [SoftImpute] Iter 44: observed MAE=0.032098 rank=13
# [SoftImpute] Iter 45: observed MAE=0.032098 rank=13
# [SoftImpute] Iter 46: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 47: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 48: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 49: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 50: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 51: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 52: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 53: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 54: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 55: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 56: observed MAE=0.032100 rank=13
# [SoftImpute] Iter 57: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 58: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 59: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 60: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 61: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 62: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 63: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 64: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 65: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 66: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 67: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 68: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 69: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 70: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 71: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 72: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 73: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 74: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 75: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 76: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 77: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 78: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 79: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 80: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 81: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 82: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 83: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 84: observed MAE=0.032099 rank=13
# [SoftImpute] Iter 85: observed MAE=0.032098 rank=13
# [SoftImpute] Iter 86: observed MAE=0.032098 rank=13
# [SoftImpute] Stopped after iteration 86 for lambda=0.494414
# [SoftImpute] Max Singular Value of X_init = 24.226085
# [SoftImpute] Iter 1: observed MAE=0.030687 rank=13
# [SoftImpute] Iter 2: observed MAE=0.030741 rank=13
# [SoftImpute] Iter 3: observed MAE=0.030792 rank=13
# [SoftImpute] Iter 4: observed MAE=0.030839 rank=13
# [SoftImpute] Iter 5: observed MAE=0.030885 rank=13
# [SoftImpute] Iter 6: observed MAE=0.030927 rank=13
# [SoftImpute] Iter 7: observed MAE=0.030967 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031004 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031038 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031070 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031101 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031130 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031158 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031184 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031207 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031229 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031248 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031264 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031280 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031294 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031307 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031318 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031328 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031338 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031346 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031353 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031359 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031365 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031370 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031374 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031378 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031382 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031385 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031388 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031390 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031392 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031394 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031395 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031396 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031397 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031398 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031397 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031397 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031397 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031397 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031397 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031396 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031396 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031396 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031396 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031395 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031395 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031395 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031395 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031395 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031395 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031394 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031394 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031394 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031394 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031394 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031394 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031393 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031393 rank=13
# [SoftImpute] Stopped after iteration 88 for lambda=0.484522
# [SoftImpute] Max Singular Value of X_init = 24.734396
# [SoftImpute] Iter 1: observed MAE=0.031459 rank=13
# [SoftImpute] Iter 2: observed MAE=0.031520 rank=13
# [SoftImpute] Iter 3: observed MAE=0.031579 rank=13
# [SoftImpute] Iter 4: observed MAE=0.031635 rank=13
# [SoftImpute] Iter 5: observed MAE=0.031688 rank=13
# [SoftImpute] Iter 6: observed MAE=0.031737 rank=13
# [SoftImpute] Iter 7: observed MAE=0.031783 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031827 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031868 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031905 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031939 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031970 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031998 rank=13
# [SoftImpute] Iter 14: observed MAE=0.032024 rank=13
# [SoftImpute] Iter 15: observed MAE=0.032048 rank=13
# [SoftImpute] Iter 16: observed MAE=0.032070 rank=13
# [SoftImpute] Iter 17: observed MAE=0.032090 rank=13
# [SoftImpute] Iter 18: observed MAE=0.032109 rank=13
# [SoftImpute] Iter 19: observed MAE=0.032125 rank=13
# [SoftImpute] Iter 20: observed MAE=0.032139 rank=13
# [SoftImpute] Iter 21: observed MAE=0.032152 rank=13
# [SoftImpute] Iter 22: observed MAE=0.032164 rank=13
# [SoftImpute] Iter 23: observed MAE=0.032175 rank=13
# [SoftImpute] Iter 24: observed MAE=0.032184 rank=13
# [SoftImpute] Iter 25: observed MAE=0.032193 rank=13
# [SoftImpute] Iter 26: observed MAE=0.032201 rank=13
# [SoftImpute] Iter 27: observed MAE=0.032208 rank=13
# [SoftImpute] Iter 28: observed MAE=0.032214 rank=13
# [SoftImpute] Iter 29: observed MAE=0.032220 rank=13
# [SoftImpute] Iter 30: observed MAE=0.032226 rank=13
# [SoftImpute] Iter 31: observed MAE=0.032231 rank=13
# [SoftImpute] Iter 32: observed MAE=0.032235 rank=13
# [SoftImpute] Iter 33: observed MAE=0.032239 rank=13
# [SoftImpute] Iter 34: observed MAE=0.032243 rank=13
# [SoftImpute] Iter 35: observed MAE=0.032246 rank=13
# [SoftImpute] Iter 36: observed MAE=0.032249 rank=13
# [SoftImpute] Iter 37: observed MAE=0.032251 rank=13
# [SoftImpute] Iter 38: observed MAE=0.032253 rank=13
# [SoftImpute] Iter 39: observed MAE=0.032255 rank=13
# [SoftImpute] Iter 40: observed MAE=0.032257 rank=13
# [SoftImpute] Iter 41: observed MAE=0.032258 rank=13
# [SoftImpute] Iter 42: observed MAE=0.032260 rank=13
# [SoftImpute] Iter 43: observed MAE=0.032261 rank=13
# [SoftImpute] Iter 44: observed MAE=0.032262 rank=13
# [SoftImpute] Iter 45: observed MAE=0.032263 rank=13
# [SoftImpute] Iter 46: observed MAE=0.032263 rank=13
# [SoftImpute] Iter 47: observed MAE=0.032264 rank=13
# [SoftImpute] Iter 48: observed MAE=0.032264 rank=13
# [SoftImpute] Iter 49: observed MAE=0.032265 rank=13
# [SoftImpute] Iter 50: observed MAE=0.032265 rank=13
# [SoftImpute] Iter 51: observed MAE=0.032266 rank=13
# [SoftImpute] Iter 52: observed MAE=0.032266 rank=13
# [SoftImpute] Iter 53: observed MAE=0.032267 rank=13
# [SoftImpute] Iter 54: observed MAE=0.032267 rank=13
# [SoftImpute] Iter 55: observed MAE=0.032267 rank=13
# [SoftImpute] Iter 56: observed MAE=0.032267 rank=13
# [SoftImpute] Iter 57: observed MAE=0.032267 rank=13
# [SoftImpute] Iter 58: observed MAE=0.032267 rank=13
# [SoftImpute] Iter 59: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 60: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 61: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 62: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 63: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 64: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 65: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 66: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 67: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 68: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 69: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 70: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 71: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 72: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 73: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 74: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 75: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 76: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 77: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 78: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 79: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 80: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 81: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 82: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 83: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 84: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 85: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 86: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 87: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 88: observed MAE=0.032268 rank=13
# [SoftImpute] Iter 89: observed MAE=0.032268 rank=13
# [SoftImpute] Stopped after iteration 89 for lambda=0.494688
# [SoftImpute] Max Singular Value of X_init = 24.204889
# [SoftImpute] Iter 1: observed MAE=0.030631 rank=13
# [SoftImpute] Iter 2: observed MAE=0.030681 rank=13
# [SoftImpute] Iter 3: observed MAE=0.030729 rank=13
# [SoftImpute] Iter 4: observed MAE=0.030773 rank=13
# [SoftImpute] Iter 5: observed MAE=0.030814 rank=13
# [SoftImpute] Iter 6: observed MAE=0.030853 rank=13
# [SoftImpute] Iter 7: observed MAE=0.030891 rank=13
# [SoftImpute] Iter 8: observed MAE=0.030927 rank=13
# [SoftImpute] Iter 9: observed MAE=0.030962 rank=13
# [SoftImpute] Iter 10: observed MAE=0.030994 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031023 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031051 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031078 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031103 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031125 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031145 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031164 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031180 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031194 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031207 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031218 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031228 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031236 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031244 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031250 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031256 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031261 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031266 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031269 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031273 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031276 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031279 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031281 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031283 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031285 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031286 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031287 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031293 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031291 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031290 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031289 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 89: observed MAE=0.031288 rank=13
# [SoftImpute] Iter 90: observed MAE=0.031288 rank=13
# [SoftImpute] Stopped after iteration 90 for lambda=0.484098
# [SoftImpute] Max Singular Value of X_init = 24.322388
# [SoftImpute] Iter 1: observed MAE=0.030945 rank=13
# [SoftImpute] Iter 2: observed MAE=0.030995 rank=13
# [SoftImpute] Iter 3: observed MAE=0.031043 rank=13
# [SoftImpute] Iter 4: observed MAE=0.031088 rank=13
# [SoftImpute] Iter 5: observed MAE=0.031130 rank=13
# [SoftImpute] Iter 6: observed MAE=0.031170 rank=13
# [SoftImpute] Iter 7: observed MAE=0.031206 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031241 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031273 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031303 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031331 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031356 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031379 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031399 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031418 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031434 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031448 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031461 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031472 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031482 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031491 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031499 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031507 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031514 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031520 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031526 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031530 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031534 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031538 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031541 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031544 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031546 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031548 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031549 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031550 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031551 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031552 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031553 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031553 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031553 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031554 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031554 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031553 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031553 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031553 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031552 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031552 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031551 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031551 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031550 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031549 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031549 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031548 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031547 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031547 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031546 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031546 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031545 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031545 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031544 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031544 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031543 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031543 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031543 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031542 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031542 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031541 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031541 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031540 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031540 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031540 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031539 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031539 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031538 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031538 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031538 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031538 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031537 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031537 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031537 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031536 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031536 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031536 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031536 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031535 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031535 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031535 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031535 rank=13
# [SoftImpute] Iter 89: observed MAE=0.031535 rank=13
# [SoftImpute] Iter 90: observed MAE=0.031535 rank=13
# [SoftImpute] Iter 91: observed MAE=0.031534 rank=13
# [SoftImpute] Iter 92: observed MAE=0.031534 rank=13
# [SoftImpute] Stopped after iteration 92 for lambda=0.486448
# [SoftImpute] Max Singular Value of X_init = 24.316222
# [SoftImpute] Iter 1: observed MAE=0.030866 rank=13
# [SoftImpute] Iter 2: observed MAE=0.030913 rank=13
# [SoftImpute] Iter 3: observed MAE=0.030957 rank=13
# [SoftImpute] Iter 4: observed MAE=0.030999 rank=13
# [SoftImpute] Iter 5: observed MAE=0.031039 rank=13
# [SoftImpute] Iter 6: observed MAE=0.031077 rank=13
# [SoftImpute] Iter 7: observed MAE=0.031112 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031145 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031176 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031206 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031235 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031262 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031287 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031310 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031332 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031352 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031370 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031387 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031403 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031417 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031430 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031442 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031452 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031462 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031472 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031480 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031488 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031495 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031501 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031507 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031512 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031516 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031520 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031524 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031528 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031531 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031534 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031537 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031540 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031542 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031545 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031547 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031548 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031550 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031552 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031553 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031554 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031555 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031556 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031556 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031557 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031558 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031558 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031558 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031559 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031559 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031559 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 89: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 90: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 91: observed MAE=0.031560 rank=13
# [SoftImpute] Iter 92: observed MAE=0.031560 rank=13
# [SoftImpute] Stopped after iteration 92 for lambda=0.486324
# [SoftImpute] Max Singular Value of X_init = 24.353245
# [SoftImpute] Iter 1: observed MAE=0.030951 rank=13
# [SoftImpute] Iter 2: observed MAE=0.031009 rank=13
# [SoftImpute] Iter 3: observed MAE=0.031063 rank=13
# [SoftImpute] Iter 4: observed MAE=0.031115 rank=13
# [SoftImpute] Iter 5: observed MAE=0.031163 rank=13
# [SoftImpute] Iter 6: observed MAE=0.031208 rank=13
# [SoftImpute] Iter 7: observed MAE=0.031251 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031292 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031331 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031367 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031400 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031431 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031460 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031488 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031514 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031537 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031559 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031579 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031597 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031613 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031627 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031640 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031652 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031663 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031673 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031681 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031689 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031695 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031701 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031707 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031712 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031716 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031720 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031723 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031726 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031728 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031730 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031731 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031732 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031733 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031734 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031735 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031736 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031736 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031737 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031737 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031738 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031738 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031738 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031738 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031738 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031738 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031737 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031737 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031737 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031737 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031736 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031736 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031736 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031736 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031735 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031735 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031735 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031735 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031734 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031734 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031734 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031733 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031733 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031733 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031733 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031732 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031732 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031732 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031732 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031731 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031731 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031731 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031731 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031731 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031730 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031730 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031730 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031730 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031729 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031729 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031729 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031729 rank=13
# [SoftImpute] Iter 89: observed MAE=0.031729 rank=13
# [SoftImpute] Iter 90: observed MAE=0.031729 rank=13
# [SoftImpute] Stopped after iteration 90 for lambda=0.487065
# [SoftImpute] Max Singular Value of X_init = 24.490607
# [SoftImpute] Iter 1: observed MAE=0.031224 rank=13
# [SoftImpute] Iter 2: observed MAE=0.031274 rank=13
# [SoftImpute] Iter 3: observed MAE=0.031323 rank=13
# [SoftImpute] Iter 4: observed MAE=0.031368 rank=13
# [SoftImpute] Iter 5: observed MAE=0.031409 rank=13
# [SoftImpute] Iter 6: observed MAE=0.031446 rank=13
# [SoftImpute] Iter 7: observed MAE=0.031480 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031512 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031539 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031565 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031588 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031608 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031626 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031641 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031655 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031667 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031679 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031690 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031699 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031707 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031715 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031722 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031728 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031733 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031738 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031742 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031746 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031748 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031750 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031752 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031757 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031758 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031759 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031760 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031760 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031761 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031760 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031760 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031760 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031759 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031759 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031759 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031759 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031758 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031758 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031758 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031757 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031757 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031757 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031756 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031756 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031756 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031756 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031755 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031754 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031753 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031753 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031753 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031753 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031753 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031753 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031753 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031753 rank=13
# [SoftImpute] Stopped after iteration 88 for lambda=0.489812
# [SoftImpute] Max Singular Value of X_init = 24.054529
# [SoftImpute] Iter 1: observed MAE=0.030604 rank=13
# [SoftImpute] Iter 2: observed MAE=0.030646 rank=13
# [SoftImpute] Iter 3: observed MAE=0.030686 rank=13
# [SoftImpute] Iter 4: observed MAE=0.030725 rank=13
# [SoftImpute] Iter 5: observed MAE=0.030763 rank=13
# [SoftImpute] Iter 6: observed MAE=0.030798 rank=13
# [SoftImpute] Iter 7: observed MAE=0.030831 rank=13
# [SoftImpute] Iter 8: observed MAE=0.030863 rank=13
# [SoftImpute] Iter 9: observed MAE=0.030892 rank=13
# [SoftImpute] Iter 10: observed MAE=0.030920 rank=13
# [SoftImpute] Iter 11: observed MAE=0.030945 rank=13
# [SoftImpute] Iter 12: observed MAE=0.030969 rank=13
# [SoftImpute] Iter 13: observed MAE=0.030991 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031012 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031031 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031048 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031064 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031078 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031090 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031100 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031110 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031117 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031124 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031129 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031134 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031138 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031142 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031145 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031148 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031151 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031153 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031155 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031157 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031158 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031159 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031160 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031161 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031161 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031160 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031160 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031160 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031159 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031158 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031158 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031157 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031156 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031155 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031155 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031154 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031153 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031152 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031151 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031150 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031149 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031149 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031148 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031147 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031146 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031146 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031145 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031145 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031144 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031143 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031143 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031142 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031142 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031141 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031141 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031141 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031140 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031140 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031139 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031139 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031139 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031138 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031138 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031137 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031137 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031137 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031137 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031136 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031136 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031136 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031136 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031135 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031135 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031135 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031135 rank=13
# [SoftImpute] Iter 89: observed MAE=0.031134 rank=13
# [SoftImpute] Stopped after iteration 89 for lambda=0.481091
# [SoftImpute] Max Singular Value of X_init = 24.281770
# [SoftImpute] Iter 1: observed MAE=0.030975 rank=13
# [SoftImpute] Iter 2: observed MAE=0.031022 rank=13
# [SoftImpute] Iter 3: observed MAE=0.031067 rank=13
# [SoftImpute] Iter 4: observed MAE=0.031108 rank=13
# [SoftImpute] Iter 5: observed MAE=0.031148 rank=13
# [SoftImpute] Iter 6: observed MAE=0.031185 rank=13
# [SoftImpute] Iter 7: observed MAE=0.031220 rank=13
# [SoftImpute] Iter 8: observed MAE=0.031252 rank=13
# [SoftImpute] Iter 9: observed MAE=0.031281 rank=13
# [SoftImpute] Iter 10: observed MAE=0.031309 rank=13
# [SoftImpute] Iter 11: observed MAE=0.031335 rank=13
# [SoftImpute] Iter 12: observed MAE=0.031360 rank=13
# [SoftImpute] Iter 13: observed MAE=0.031382 rank=13
# [SoftImpute] Iter 14: observed MAE=0.031403 rank=13
# [SoftImpute] Iter 15: observed MAE=0.031423 rank=13
# [SoftImpute] Iter 16: observed MAE=0.031440 rank=13
# [SoftImpute] Iter 17: observed MAE=0.031456 rank=13
# [SoftImpute] Iter 18: observed MAE=0.031471 rank=13
# [SoftImpute] Iter 19: observed MAE=0.031484 rank=13
# [SoftImpute] Iter 20: observed MAE=0.031496 rank=13
# [SoftImpute] Iter 21: observed MAE=0.031507 rank=13
# [SoftImpute] Iter 22: observed MAE=0.031518 rank=13
# [SoftImpute] Iter 23: observed MAE=0.031527 rank=13
# [SoftImpute] Iter 24: observed MAE=0.031536 rank=13
# [SoftImpute] Iter 25: observed MAE=0.031543 rank=13
# [SoftImpute] Iter 26: observed MAE=0.031550 rank=13
# [SoftImpute] Iter 27: observed MAE=0.031556 rank=13
# [SoftImpute] Iter 28: observed MAE=0.031561 rank=13
# [SoftImpute] Iter 29: observed MAE=0.031565 rank=13
# [SoftImpute] Iter 30: observed MAE=0.031569 rank=13
# [SoftImpute] Iter 31: observed MAE=0.031572 rank=13
# [SoftImpute] Iter 32: observed MAE=0.031575 rank=13
# [SoftImpute] Iter 33: observed MAE=0.031578 rank=13
# [SoftImpute] Iter 34: observed MAE=0.031580 rank=13
# [SoftImpute] Iter 35: observed MAE=0.031582 rank=13
# [SoftImpute] Iter 36: observed MAE=0.031584 rank=13
# [SoftImpute] Iter 37: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 38: observed MAE=0.031586 rank=13
# [SoftImpute] Iter 39: observed MAE=0.031587 rank=13
# [SoftImpute] Iter 40: observed MAE=0.031588 rank=13
# [SoftImpute] Iter 41: observed MAE=0.031588 rank=13
# [SoftImpute] Iter 42: observed MAE=0.031589 rank=13
# [SoftImpute] Iter 43: observed MAE=0.031590 rank=13
# [SoftImpute] Iter 44: observed MAE=0.031590 rank=13
# [SoftImpute] Iter 45: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 46: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 47: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 48: observed MAE=0.031592 rank=13
# [SoftImpute] Iter 49: observed MAE=0.031592 rank=13
# [SoftImpute] Iter 50: observed MAE=0.031592 rank=13
# [SoftImpute] Iter 51: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 52: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 53: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 54: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 55: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 56: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 57: observed MAE=0.031591 rank=13
# [SoftImpute] Iter 58: observed MAE=0.031590 rank=13
# [SoftImpute] Iter 59: observed MAE=0.031590 rank=13
# [SoftImpute] Iter 60: observed MAE=0.031590 rank=13
# [SoftImpute] Iter 61: observed MAE=0.031590 rank=13
# [SoftImpute] Iter 62: observed MAE=0.031589 rank=13
# [SoftImpute] Iter 63: observed MAE=0.031589 rank=13
# [SoftImpute] Iter 64: observed MAE=0.031589 rank=13
# [SoftImpute] Iter 65: observed MAE=0.031588 rank=13
# [SoftImpute] Iter 66: observed MAE=0.031588 rank=13
# [SoftImpute] Iter 67: observed MAE=0.031588 rank=13
# [SoftImpute] Iter 68: observed MAE=0.031588 rank=13
# [SoftImpute] Iter 69: observed MAE=0.031587 rank=13
# [SoftImpute] Iter 70: observed MAE=0.031587 rank=13
# [SoftImpute] Iter 71: observed MAE=0.031587 rank=13
# [SoftImpute] Iter 72: observed MAE=0.031587 rank=13
# [SoftImpute] Iter 73: observed MAE=0.031587 rank=13
# [SoftImpute] Iter 74: observed MAE=0.031586 rank=13
# [SoftImpute] Iter 75: observed MAE=0.031586 rank=13
# [SoftImpute] Iter 76: observed MAE=0.031586 rank=13
# [SoftImpute] Iter 77: observed MAE=0.031586 rank=13
# [SoftImpute] Iter 78: observed MAE=0.031586 rank=13
# [SoftImpute] Iter 79: observed MAE=0.031586 rank=13
# [SoftImpute] Iter 80: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 81: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 82: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 83: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 84: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 85: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 86: observed MAE=0.031585 rank=13
# [SoftImpute] Iter 87: observed MAE=0.031584 rank=13
# [SoftImpute] Iter 88: observed MAE=0.031584 rank=13
# [SoftImpute] Iter 89: observed MAE=0.031584 rank=13
# [SoftImpute] Iter 90: observed MAE=0.031584 rank=13
# [SoftImpute] Iter 91: observed MAE=0.031584 rank=13
# [SoftImpute] Stopped after iteration 91 for lambda=0.485635
# [SoftImpute] Max Singular Value of X_init = 21.730674
# [SoftImpute] Iter 1: observed MAE=0.030294 rank=13
# [SoftImpute] Iter 2: observed MAE=0.030322 rank=13
# [SoftImpute] Iter 3: observed MAE=0.030348 rank=13
# [SoftImpute] Iter 4: observed MAE=0.030371 rank=13
# [SoftImpute] Iter 5: observed MAE=0.030392 rank=13
# [SoftImpute] Iter 6: observed MAE=0.030413 rank=13
# ...
# [SoftImpute] Iter 1: observed MAE=0.025531 rank=13
# [SoftImpute] Iter 2: observed MAE=0.025539 rank=13
# [SoftImpute] Iter 3: observed MAE=0.025546 rank=13
# [SoftImpute] Iter 4: observed MAE=0.025554 rank=13
# [SoftImpute] Iter 5: observed MAE=0.025561 rank=13
# [SoftImpute] Iter 6: observed MAE=0.025568 rank=13
# [SoftImpute] Iter 7: observed MAE=0.025575 rank=13
# [SoftImpute] Iter 8: observed MAE=0.025582 rank=13
# [SoftImpute] Iter 9: observed MAE=0.025588 rank=13
# [SoftImpute] Iter 10: observed MAE=0.025594 rank=13
# [SoftImpute] Iter 11: observed MAE=0.025600 rank=13
# [SoftImpute] Iter 12: observed MAE=0.025605 rank=13
# [SoftImpute] Iter 13: observed MAE=0.025610 rank=13
# [SoftImpute] Iter 14: observed MAE=0.025615 rank=13
# [SoftImpute] Iter 15: observed MAE=0.025619 rank=13
# [SoftImpute] Iter 16: observed MAE=0.025624 rank=13
# [SoftImpute] Iter 17: observed MAE=0.025628 rank=13
# [SoftImpute] Iter 18: observed MAE=0.025633 rank=13
# [SoftImpute] Iter 19: observed MAE=0.025638 rank=13
# [SoftImpute] Iter 20: observed MAE=0.025643 rank=13
# [SoftImpute] Iter 21: observed MAE=0.025648 rank=13
# [SoftImpute] Iter 22: observed MAE=0.025653 rank=13
# [SoftImpute] Iter 23: observed MAE=0.025657 rank=13
# [SoftImpute] Iter 24: observed MAE=0.025661 rank=13
# [SoftImpute] Iter 25: observed MAE=0.025665 rank=13
# [SoftImpute] Iter 26: observed MAE=0.025669 rank=13
# [SoftImpute] Iter 27: observed MAE=0.025673 rank=13
# [SoftImpute] Iter 28: observed MAE=0.025676 rank=13
# [SoftImpute] Iter 29: observed MAE=0.025679 rank=13
# [SoftImpute] Iter 30: observed MAE=0.025682 rank=13
# [SoftImpute] Iter 31: observed MAE=0.025686 rank=13
# [SoftImpute] Iter 32: observed MAE=0.025689 rank=13
# [SoftImpute] Iter 33: observed MAE=0.025692 rank=13
# [SoftImpute] Iter 34: observed MAE=0.025696 rank=13
# [SoftImpute] Iter 35: observed MAE=0.025699 rank=13
# [SoftImpute] Iter 36: observed MAE=0.025702 rank=13
# [SoftImpute] Iter 37: observed MAE=0.025705 rank=13
# [SoftImpute] Iter 38: observed MAE=0.025707 rank=13
# [SoftImpute] Iter 39: observed MAE=0.025709 rank=13
# [SoftImpute] Iter 40: observed MAE=0.025711 rank=13
# [SoftImpute] Iter 41: observed MAE=0.025713 rank=13
# [SoftImpute] Iter 42: observed MAE=0.025715 rank=13
# [SoftImpute] Iter 43: observed MAE=0.025717 rank=13
# [SoftImpute] Iter 44: observed MAE=0.025718 rank=13
# [SoftImpute] Iter 45: observed MAE=0.025719 rank=13
# [SoftImpute] Iter 46: observed MAE=0.025720 rank=13
# [SoftImpute] Iter 47: observed MAE=0.025721 rank=13
# [SoftImpute] Iter 48: observed MAE=0.025722 rank=13
# [SoftImpute] Iter 49: observed MAE=0.025722 rank=13
# [SoftImpute] Iter 50: observed MAE=0.025723 rank=13
# [SoftImpute] Iter 51: observed MAE=0.025724 rank=13
# [SoftImpute] Iter 52: observed MAE=0.025725 rank=13
# [SoftImpute] Iter 53: observed MAE=0.025726 rank=13
# [SoftImpute] Iter 54: observed MAE=0.025727 rank=13
# [SoftImpute] Iter 55: observed MAE=0.025727 rank=13
# [SoftImpute] Iter 56: observed MAE=0.025728 rank=13
# [SoftImpute] Iter 57: observed MAE=0.025728 rank=13
# [SoftImpute] Iter 58: observed MAE=0.025728 rank=13
# [SoftImpute] Iter 59: observed MAE=0.025728 rank=13
# [SoftImpute] Iter 60: observed MAE=0.025729 rank=13
# [SoftImpute] Iter 61: observed MAE=0.025729 rank=13
# [SoftImpute] Iter 62: observed MAE=0.025729 rank=13
# [SoftImpute] Iter 63: observed MAE=0.025729 rank=13
# [SoftImpute] Iter 64: observed MAE=0.025730 rank=13
# [SoftImpute] Iter 65: observed MAE=0.025730 rank=13
# [SoftImpute] Iter 66: observed MAE=0.025730 rank=13
# [SoftImpute] Iter 67: observed MAE=0.025730 rank=13
# [SoftImpute] Iter 68: observed MAE=0.025730 rank=13
# [SoftImpute] Iter 69: observed MAE=0.025730 rank=13
# [SoftImpute] Iter 70: observed MAE=0.025730 rank=13
# [SoftImpute] Iter 71: observed MAE=0.025731 rank=13
# [SoftImpute] Iter 72: observed MAE=0.025731 rank=13
# [SoftImpute] Iter 73: observed MAE=0.025731 rank=13
# [SoftImpute] Iter 74: observed MAE=0.025731 rank=13
# [SoftImpute] Iter 75: observed MAE=0.025731 rank=13
# [SoftImpute] Iter 76: observed MAE=0.025732 rank=13
# [SoftImpute] Iter 77: observed MAE=0.025732 rank=13
# [SoftImpute] Iter 78: observed MAE=0.025732 rank=13
# [SoftImpute] Iter 79: observed MAE=0.025732 rank=13
# [SoftImpute] Iter 80: observed MAE=0.025733 rank=13
# [SoftImpute] Iter 81: observed MAE=0.025733 rank=13
# [SoftImpute] Iter 82: observed MAE=0.025733 rank=13
# [SoftImpute] Iter 83: observed MAE=0.025733 rank=13
# [SoftImpute] Iter 84: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 85: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 86: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 87: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 88: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 89: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 90: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 91: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 92: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 93: observed MAE=0.025734 rank=13
# [SoftImpute] Iter 94: observed MAE=0.025735 rank=13
# [SoftImpute] Iter 95: observed MAE=0.025735 rank=13
# [SoftImpute] Iter 96: observed MAE=0.025735 rank=13
# [SoftImpute] Iter 97: observed MAE=0.025735 rank=13
# [SoftImpute] Iter 98: observed MAE=0.025735 rank=13
# [SoftImpute] Iter 99: observed MAE=0.025736 rank=13
# [SoftImpute] Iter 100: observed MAE=0.025736 rank=13
# [SoftImpute] Stopped after iteration 100 for lambda=0.291544
# [SoftImpute] Max Singular Value of X_init = 14.090195
# [SoftImpute] Iter 1: observed MAE=0.025227 rank=13
# [SoftImpute] Iter 2: observed MAE=0.025232 rank=13
# [SoftImpute] Iter 3: observed MAE=0.025238 rank=13
# [SoftImpute] Iter 4: observed MAE=0.025243 rank=13
# [SoftImpute] Iter 5: observed MAE=0.025249 rank=13
# [SoftImpute] Iter 6: observed MAE=0.025255 rank=13
# [SoftImpute] Iter 7: observed MAE=0.025261 rank=13
# [SoftImpute] Iter 8: observed MAE=0.025267 rank=13
# [SoftImpute] Iter 9: observed MAE=0.025273 rank=13
# [SoftImpute] Iter 10: observed MAE=0.025280 rank=13
# [SoftImpute] Iter 11: observed MAE=0.025286 rank=13
# [SoftImpute] Iter 12: observed MAE=0.025291 rank=13
# [SoftImpute] Iter 13: observed MAE=0.025297 rank=13
# [SoftImpute] Iter 14: observed MAE=0.025304 rank=13
# [SoftImpute] Iter 15: observed MAE=0.025310 rank=13
# [SoftImpute] Iter 16: observed MAE=0.025316 rank=13
# [SoftImpute] Iter 17: observed MAE=0.025322 rank=13
# [SoftImpute] Iter 18: observed MAE=0.025329 rank=13
# [SoftImpute] Iter 19: observed MAE=0.025334 rank=13
# [SoftImpute] Iter 20: observed MAE=0.025340 rank=13
# [SoftImpute] Iter 21: observed MAE=0.025345 rank=13
# [SoftImpute] Iter 22: observed MAE=0.025350 rank=13
# [SoftImpute] Iter 23: observed MAE=0.025356 rank=13
# [SoftImpute] Iter 24: observed MAE=0.025361 rank=13
# [SoftImpute] Iter 25: observed MAE=0.025367 rank=13
# [SoftImpute] Iter 26: observed MAE=0.025372 rank=13
# [SoftImpute] Iter 27: observed MAE=0.025377 rank=13
# [SoftImpute] Iter 28: observed MAE=0.025382 rank=13
# [SoftImpute] Iter 29: observed MAE=0.025387 rank=13
# [SoftImpute] Iter 30: observed MAE=0.025392 rank=13
# [SoftImpute] Iter 31: observed MAE=0.025397 rank=13
# [SoftImpute] Iter 32: observed MAE=0.025402 rank=13
# [SoftImpute] Iter 33: observed MAE=0.025407 rank=13
# [SoftImpute] Iter 34: observed MAE=0.025413 rank=13
# [SoftImpute] Iter 35: observed MAE=0.025418 rank=13
# [SoftImpute] Iter 36: observed MAE=0.025423 rank=13
# [SoftImpute] Iter 37: observed MAE=0.025427 rank=13
# [SoftImpute] Iter 38: observed MAE=0.025432 rank=13
# [SoftImpute] Iter 39: observed MAE=0.025436 rank=13
# [SoftImpute] Iter 40: observed MAE=0.025441 rank=13
# [SoftImpute] Iter 41: observed MAE=0.025446 rank=13
# [SoftImpute] Iter 42: observed MAE=0.025450 rank=13
# [SoftImpute] Iter 43: observed MAE=0.025455 rank=13
# [SoftImpute] Iter 44: observed MAE=0.025459 rank=13
# [SoftImpute] Iter 45: observed MAE=0.025463 rank=13
# [SoftImpute] Iter 46: observed MAE=0.025466 rank=13
# [SoftImpute] Iter 47: observed MAE=0.025470 rank=13
# [SoftImpute] Iter 48: observed MAE=0.025473 rank=13
# [SoftImpute] Iter 49: observed MAE=0.025477 rank=13
# [SoftImpute] Iter 50: observed MAE=0.025480 rank=13
# [SoftImpute] Iter 51: observed MAE=0.025484 rank=13
# [SoftImpute] Iter 52: observed MAE=0.025487 rank=13
# [SoftImpute] Iter 53: observed MAE=0.025490 rank=13
# [SoftImpute] Iter 54: observed MAE=0.025493 rank=13
# [SoftImpute] Iter 55: observed MAE=0.025496 rank=13
# [SoftImpute] Iter 56: observed MAE=0.025499 rank=13
# [SoftImpute] Iter 57: observed MAE=0.025502 rank=13
# [SoftImpute] Iter 58: observed MAE=0.025504 rank=13
# [SoftImpute] Iter 59: observed MAE=0.025507 rank=13
# [SoftImpute] Iter 60: observed MAE=0.025509 rank=13
# [SoftImpute] Iter 61: observed MAE=0.025511 rank=13
# [SoftImpute] Iter 62: observed MAE=0.025513 rank=13
# [SoftImpute] Iter 63: observed MAE=0.025515 rank=13
# [SoftImpute] Iter 64: observed MAE=0.025517 rank=13
# [SoftImpute] Iter 65: observed MAE=0.025518 rank=13
# [SoftImpute] Iter 66: observed MAE=0.025520 rank=13
# [SoftImpute] Iter 67: observed MAE=0.025522 rank=13
# [SoftImpute] Iter 68: observed MAE=0.025524 rank=13
# [SoftImpute] Iter 69: observed MAE=0.025526 rank=13
# [SoftImpute] Iter 70: observed MAE=0.025528 rank=13
# [SoftImpute] Iter 71: observed MAE=0.025530 rank=13
# [SoftImpute] Iter 72: observed MAE=0.025532 rank=13
# [SoftImpute] Iter 73: observed MAE=0.025533 rank=13
# [SoftImpute] Iter 74: observed MAE=0.025535 rank=13
# [SoftImpute] Iter 75: observed MAE=0.025537 rank=13
# [SoftImpute] Iter 76: observed MAE=0.025539 rank=13
# [SoftImpute] Iter 77: observed MAE=0.025542 rank=13
# [SoftImpute] Iter 78: observed MAE=0.025543 rank=13
# [SoftImpute] Iter 79: observed MAE=0.025545 rank=13
# [SoftImpute] Iter 80: observed MAE=0.025547 rank=13
# [SoftImpute] Iter 81: observed MAE=0.025549 rank=13
# [SoftImpute] Iter 82: observed MAE=0.025550 rank=13
# [SoftImpute] Iter 83: observed MAE=0.025552 rank=13
# [SoftImpute] Iter 84: observed MAE=0.025553 rank=13
# [SoftImpute] Iter 85: observed MAE=0.025555 rank=13
# [SoftImpute] Iter 86: observed MAE=0.025556 rank=13
# [SoftImpute] Iter 87: observed MAE=0.025557 rank=13
# [SoftImpute] Iter 88: observed MAE=0.025559 rank=13
# [SoftImpute] Iter 89: observed MAE=0.025560 rank=13
# [SoftImpute] Iter 90: observed MAE=0.025561 rank=13
# [SoftImpute] Iter 91: observed MAE=0.025562 rank=13
# [SoftImpute] Iter 92: observed MAE=0.025564 rank=13
# [SoftImpute] Iter 93: observed MAE=0.025565 rank=13
# [SoftImpute] Iter 94: observed MAE=0.025567 rank=13
# [SoftImpute] Iter 95: observed MAE=0.025568 rank=13
# [SoftImpute] Iter 96: observed MAE=0.025570 rank=13
# [SoftImpute] Iter 97: observed MAE=0.025571 rank=13
# [SoftImpute] Iter 98: observed MAE=0.025573 rank=13
# [SoftImpute] Iter 99: observed MAE=0.025574 rank=13
# [SoftImpute] Iter 100: observed MAE=0.025576 rank=13
# [SoftImpute] Stopped after iteration 100 for lambda=0.281804
# [SoftImpute] Max Singular Value of X_init = 13.718672
# [SoftImpute] Iter 1: observed MAE=0.024683 rank=13
# [SoftImpute] Iter 2: observed MAE=0.024690 rank=13
# [SoftImpute] Iter 3: observed MAE=0.024697 rank=13
# [SoftImpute] Iter 4: observed MAE=0.024703 rank=13
# [SoftImpute] Iter 5: observed MAE=0.024708 rank=13
# [SoftImpute] Iter 6: observed MAE=0.024714 rank=13
# [SoftImpute] Iter 7: observed MAE=0.024719 rank=13
# [SoftImpute] Iter 8: observed MAE=0.024725 rank=13
# [SoftImpute] Iter 9: observed MAE=0.024730 rank=13
# [SoftImpute] Iter 10: observed MAE=0.024735 rank=13
# [SoftImpute] Iter 11: observed MAE=0.024739 rank=13
# [SoftImpute] Iter 12: observed MAE=0.024744 rank=13
# [SoftImpute] Iter 13: observed MAE=0.024749 rank=13
# [SoftImpute] Iter 14: observed MAE=0.024753 rank=13
# [SoftImpute] Iter 15: observed MAE=0.024758 rank=13
# [SoftImpute] Iter 16: observed MAE=0.024762 rank=13
# [SoftImpute] Iter 17: observed MAE=0.024765 rank=13
# [SoftImpute] Iter 18: observed MAE=0.024769 rank=13
# [SoftImpute] Iter 19: observed MAE=0.024772 rank=13
# [SoftImpute] Iter 20: observed MAE=0.024775 rank=13
# [SoftImpute] Iter 21: observed MAE=0.024777 rank=13
# [SoftImpute] Iter 22: observed MAE=0.024781 rank=13
# [SoftImpute] Iter 23: observed MAE=0.024784 rank=13
# [SoftImpute] Iter 24: observed MAE=0.024787 rank=13
# [SoftImpute] Iter 25: observed MAE=0.024790 rank=13
# [SoftImpute] Iter 26: observed MAE=0.024794 rank=13
# [SoftImpute] Iter 27: observed MAE=0.024797 rank=13
# [SoftImpute] Iter 28: observed MAE=0.024800 rank=13
# [SoftImpute] Iter 29: observed MAE=0.024802 rank=13
# [SoftImpute] Iter 30: observed MAE=0.024805 rank=13
# [SoftImpute] Iter 31: observed MAE=0.024807 rank=13
# [SoftImpute] Iter 32: observed MAE=0.024809 rank=13
# [SoftImpute] Iter 33: observed MAE=0.024811 rank=13
# [SoftImpute] Iter 34: observed MAE=0.024813 rank=13
# [SoftImpute] Iter 35: observed MAE=0.024814 rank=13
# [SoftImpute] Iter 36: observed MAE=0.024815 rank=13
# [SoftImpute] Iter 37: observed MAE=0.024817 rank=13
# [SoftImpute] Iter 38: observed MAE=0.024818 rank=13
# [SoftImpute] Iter 39: observed MAE=0.024819 rank=13
# [SoftImpute] Iter 40: observed MAE=0.024819 rank=13
# [SoftImpute] Iter 41: observed MAE=0.024820 rank=13
# [SoftImpute] Iter 42: observed MAE=0.024821 rank=13
# [SoftImpute] Iter 43: observed MAE=0.024821 rank=13
# [SoftImpute] Iter 44: observed MAE=0.024822 rank=13
# [SoftImpute] Iter 45: observed MAE=0.024822 rank=13
# [SoftImpute] Iter 46: observed MAE=0.024823 rank=13
# [SoftImpute] Iter 47: observed MAE=0.024824 rank=13
# [SoftImpute] Iter 48: observed MAE=0.024824 rank=13
# [SoftImpute] Iter 49: observed MAE=0.024825 rank=13
# [SoftImpute] Iter 50: observed MAE=0.024826 rank=13
# [SoftImpute] Iter 51: observed MAE=0.024828 rank=13
# [SoftImpute] Iter 52: observed MAE=0.024830 rank=13
# [SoftImpute] Iter 53: observed MAE=0.024832 rank=13
# [SoftImpute] Iter 54: observed MAE=0.024833 rank=13
# [SoftImpute] Iter 55: observed MAE=0.024835 rank=13
# [SoftImpute] Iter 56: observed MAE=0.024836 rank=13
# [SoftImpute] Iter 57: observed MAE=0.024837 rank=13
# [SoftImpute] Iter 58: observed MAE=0.024839 rank=13
# [SoftImpute] Iter 59: observed MAE=0.024840 rank=13
# [SoftImpute] Iter 60: observed MAE=0.024842 rank=13
# [SoftImpute] Iter 61: observed MAE=0.024843 rank=13
# [SoftImpute] Iter 62: observed MAE=0.024845 rank=13
# [SoftImpute] Iter 63: observed MAE=0.024846 rank=13
# [SoftImpute] Iter 64: observed MAE=0.024848 rank=13
# [SoftImpute] Iter 65: observed MAE=0.024849 rank=13
# [SoftImpute] Iter 66: observed MAE=0.024851 rank=13
# [SoftImpute] Iter 67: observed MAE=0.024853 rank=13
# [SoftImpute] Iter 68: observed MAE=0.024855 rank=13
# [SoftImpute] Iter 69: observed MAE=0.024857 rank=13
# [SoftImpute] Iter 70: observed MAE=0.024858 rank=13
# [SoftImpute] Iter 71: observed MAE=0.024860 rank=13
# [SoftImpute] Iter 72: observed MAE=0.024862 rank=13
# [SoftImpute] Iter 73: observed MAE=0.024863 rank=13
# [SoftImpute] Iter 74: observed MAE=0.024865 rank=13
# [SoftImpute] Iter 75: observed MAE=0.024866 rank=13
# [SoftImpute] Iter 76: observed MAE=0.024868 rank=13
# [SoftImpute] Iter 77: observed MAE=0.024869 rank=13
# [SoftImpute] Iter 78: observed MAE=0.024871 rank=13
# [SoftImpute] Iter 79: observed MAE=0.024872 rank=13
# [SoftImpute] Iter 80: observed MAE=0.024873 rank=13
# [SoftImpute] Iter 81: observed MAE=0.024874 rank=13
# [SoftImpute] Iter 82: observed MAE=0.024876 rank=13
# [SoftImpute] Iter 83: observed MAE=0.024877 rank=13
# [SoftImpute] Iter 84: observed MAE=0.024877 rank=13
# [SoftImpute] Iter 85: observed MAE=0.024878 rank=13
# [SoftImpute] Iter 86: observed MAE=0.024879 rank=13
# [SoftImpute] Iter 87: observed MAE=0.024880 rank=13
# [SoftImpute] Iter 88: observed MAE=0.024881 rank=13
# [SoftImpute] Iter 89: observed MAE=0.024882 rank=13
# [SoftImpute] Iter 90: observed MAE=0.024883 rank=13
# [SoftImpute] Iter 91: observed MAE=0.024884 rank=13
# [SoftImpute] Iter 92: observed MAE=0.024884 rank=13
# [SoftImpute] Iter 93: observed MAE=0.024885 rank=13
# [SoftImpute] Iter 94: observed MAE=0.024886 rank=13
# [SoftImpute] Iter 95: observed MAE=0.024887 rank=13
# [SoftImpute] Iter 96: observed MAE=0.024888 rank=13
# [SoftImpute] Iter 97: observed MAE=0.024888 rank=13
# [SoftImpute] Iter 98: observed MAE=0.024889 rank=13
# [SoftImpute] Iter 99: observed MAE=0.024889 rank=13
# [SoftImpute] Iter 100: observed MAE=0.024890 rank=13
# [SoftImpute] Stopped after iteration 100 for lambda=0.274373
# array([[0.007, 0.   ],
#        [0.012, 0.001],
#        [0.016, 0.001],
#        [0.021, 0.001],
#        [0.027, 0.002]])

# %% [markdown]
# # Iris
# The data set is also available in sklearn, as noted in the package's website. So, we load it directly from sklearn

# %%
iris = datasets.load_iris()
X,y = iris.data, iris.target.ravel() 
G = 3

# %%
mle_err = np.array([compute_err_mle(X, y, G, .2, runs = 10),
                    compute_err_mle(X, y, G, .35, runs = 10),
                    compute_err_mle(X, y, G, .5, runs = 10),
                    compute_err_mle(X, y, G, .65, runs = 10),
                    compute_err_mle(X, y, G, .8, runs = 10)])
mle_err.round(3)
# Out:
# array([[0.007, 0.002],
#        [0.011, 0.002],
#        [0.013, 0.003],
#        [0.016, 0.005],
#        [0.014, 0.004]])

# %%
G = 3
mice_err = np.array([compute_err_mice(X, y, G, .2, runs = 10),
                    compute_err_mice(X, y, G, .35, runs = 10),
                    compute_err_mice(X, y, G, .5, runs = 10),
                    compute_err_mice(X, y, G, .65, runs = 10),
                    compute_err_mice(X, y, G, .8, runs = 10)])
mice_err.round(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# array([[0.008, 0.002],
#        [0.015, 0.004],
#        [0.023, 0.003],
#        [0.035, 0.006],
#        [0.052, 0.009]])

# %%
G = 3
soft_err = np.array([compute_err_soft(X, y, G, .2, runs = 10),
                    compute_err_soft(X, y, G, .35, runs = 10),
                    compute_err_soft(X, y, G, .5, runs = 10),
                    compute_err_soft(X, y, G, .65, runs = 10),
                    compute_err_soft(X, y, G, .8, runs = 10)])
soft_err.round(3)
# Out:
# Streaming output truncated to the last 5000 lines.
# [SoftImpute] Iter 7: observed MAE=0.024121 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024138 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024153 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024168 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024183 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024198 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024212 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024226 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024239 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024251 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024264 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024276 rank=4
# [SoftImpute] Iter 19: observed MAE=0.024287 rank=4
# [SoftImpute] Iter 20: observed MAE=0.024297 rank=4
# [SoftImpute] Iter 21: observed MAE=0.024307 rank=4
# [SoftImpute] Iter 22: observed MAE=0.024318 rank=4
# [SoftImpute] Iter 23: observed MAE=0.024329 rank=4
# [SoftImpute] Iter 24: observed MAE=0.024344 rank=4
# [SoftImpute] Iter 25: observed MAE=0.024362 rank=4
# [SoftImpute] Iter 26: observed MAE=0.024383 rank=4
# [SoftImpute] Iter 27: observed MAE=0.024404 rank=4
# [SoftImpute] Iter 28: observed MAE=0.024425 rank=4
# [SoftImpute] Iter 29: observed MAE=0.024446 rank=4
# [SoftImpute] Iter 30: observed MAE=0.024466 rank=4
# [SoftImpute] Iter 31: observed MAE=0.024484 rank=4
# [SoftImpute] Iter 32: observed MAE=0.024502 rank=4
# [SoftImpute] Iter 33: observed MAE=0.024519 rank=4
# [SoftImpute] Iter 34: observed MAE=0.024535 rank=4
# [SoftImpute] Iter 35: observed MAE=0.024553 rank=4
# [SoftImpute] Iter 36: observed MAE=0.024573 rank=4
# [SoftImpute] Iter 37: observed MAE=0.024593 rank=4
# [SoftImpute] Iter 38: observed MAE=0.024613 rank=4
# [SoftImpute] Iter 39: observed MAE=0.024633 rank=4
# [SoftImpute] Iter 40: observed MAE=0.024654 rank=4
# [SoftImpute] Iter 41: observed MAE=0.024674 rank=4
# [SoftImpute] Iter 42: observed MAE=0.024693 rank=4
# [SoftImpute] Iter 43: observed MAE=0.024711 rank=4
# [SoftImpute] Iter 44: observed MAE=0.024729 rank=4
# [SoftImpute] Iter 45: observed MAE=0.024746 rank=4
# [SoftImpute] Iter 46: observed MAE=0.024762 rank=4
# [SoftImpute] Iter 47: observed MAE=0.024777 rank=4
# [SoftImpute] Iter 48: observed MAE=0.024792 rank=4
# [SoftImpute] Iter 49: observed MAE=0.024806 rank=4
# [SoftImpute] Iter 50: observed MAE=0.024819 rank=4
# [SoftImpute] Iter 51: observed MAE=0.024832 rank=4
# [SoftImpute] Iter 52: observed MAE=0.024843 rank=4
# [SoftImpute] Iter 53: observed MAE=0.024854 rank=4
# [SoftImpute] Iter 54: observed MAE=0.024864 rank=4
# [SoftImpute] Iter 55: observed MAE=0.024873 rank=4
# [SoftImpute] Iter 56: observed MAE=0.024882 rank=4
# [SoftImpute] Iter 57: observed MAE=0.024890 rank=4
# [SoftImpute] Iter 58: observed MAE=0.024897 rank=4
# [SoftImpute] Iter 59: observed MAE=0.024904 rank=4
# [SoftImpute] Iter 60: observed MAE=0.024911 rank=4
# [SoftImpute] Iter 61: observed MAE=0.024916 rank=4
# [SoftImpute] Iter 62: observed MAE=0.024921 rank=4
# [SoftImpute] Iter 63: observed MAE=0.024927 rank=4
# [SoftImpute] Iter 64: observed MAE=0.024932 rank=4
# [SoftImpute] Iter 65: observed MAE=0.024937 rank=4
# [SoftImpute] Iter 66: observed MAE=0.024942 rank=4
# [SoftImpute] Iter 67: observed MAE=0.024946 rank=4
# [SoftImpute] Iter 68: observed MAE=0.024950 rank=4
# [SoftImpute] Iter 69: observed MAE=0.024954 rank=4
# [SoftImpute] Iter 70: observed MAE=0.024957 rank=4
# [SoftImpute] Iter 71: observed MAE=0.024960 rank=4
# [SoftImpute] Iter 72: observed MAE=0.024963 rank=4
# [SoftImpute] Iter 73: observed MAE=0.024966 rank=4
# [SoftImpute] Iter 74: observed MAE=0.024968 rank=4
# [SoftImpute] Iter 75: observed MAE=0.024971 rank=4
# [SoftImpute] Iter 76: observed MAE=0.024973 rank=4
# [SoftImpute] Iter 77: observed MAE=0.024975 rank=4
# [SoftImpute] Iter 78: observed MAE=0.024976 rank=4
# [SoftImpute] Iter 79: observed MAE=0.024978 rank=4
# [SoftImpute] Iter 80: observed MAE=0.024980 rank=4
# [SoftImpute] Iter 81: observed MAE=0.024981 rank=4
# [SoftImpute] Iter 82: observed MAE=0.024983 rank=4
# [SoftImpute] Iter 83: observed MAE=0.024984 rank=4
# [SoftImpute] Iter 84: observed MAE=0.024985 rank=4
# [SoftImpute] Iter 85: observed MAE=0.024987 rank=4
# [SoftImpute] Iter 86: observed MAE=0.024988 rank=4
# [SoftImpute] Iter 87: observed MAE=0.024989 rank=4
# [SoftImpute] Iter 88: observed MAE=0.024990 rank=4
# [SoftImpute] Iter 89: observed MAE=0.024991 rank=4
# [SoftImpute] Iter 90: observed MAE=0.024992 rank=4
# [SoftImpute] Iter 91: observed MAE=0.024993 rank=4
# [SoftImpute] Iter 92: observed MAE=0.024994 rank=4
# [SoftImpute] Iter 93: observed MAE=0.024994 rank=4
# [SoftImpute] Iter 94: observed MAE=0.024995 rank=4
# [SoftImpute] Iter 95: observed MAE=0.024996 rank=4
# [SoftImpute] Stopped after iteration 95 for lambda=0.348208
# [SoftImpute] Max Singular Value of X_init = 17.967238
# [SoftImpute] Iter 1: observed MAE=0.024706 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024746 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024784 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024823 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024860 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024934 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024970 rank=4
# [SoftImpute] Iter 9: observed MAE=0.025008 rank=4
# [SoftImpute] Iter 10: observed MAE=0.025053 rank=4
# [SoftImpute] Iter 11: observed MAE=0.025097 rank=4
# [SoftImpute] Iter 12: observed MAE=0.025141 rank=4
# [SoftImpute] Iter 13: observed MAE=0.025182 rank=4
# [SoftImpute] Iter 14: observed MAE=0.025222 rank=4
# [SoftImpute] Iter 15: observed MAE=0.025260 rank=4
# [SoftImpute] Iter 16: observed MAE=0.025299 rank=4
# [SoftImpute] Iter 17: observed MAE=0.025339 rank=4
# [SoftImpute] Iter 18: observed MAE=0.025377 rank=4
# [SoftImpute] Iter 19: observed MAE=0.025412 rank=4
# [SoftImpute] Iter 20: observed MAE=0.025448 rank=4
# [SoftImpute] Iter 21: observed MAE=0.025481 rank=4
# [SoftImpute] Iter 22: observed MAE=0.025513 rank=4
# [SoftImpute] Iter 23: observed MAE=0.025541 rank=4
# [SoftImpute] Iter 24: observed MAE=0.025567 rank=4
# [SoftImpute] Iter 25: observed MAE=0.025591 rank=4
# [SoftImpute] Iter 26: observed MAE=0.025619 rank=4
# [SoftImpute] Iter 27: observed MAE=0.025644 rank=4
# [SoftImpute] Iter 28: observed MAE=0.025669 rank=4
# [SoftImpute] Iter 29: observed MAE=0.025692 rank=4
# [SoftImpute] Iter 30: observed MAE=0.025712 rank=4
# [SoftImpute] Iter 31: observed MAE=0.025729 rank=4
# [SoftImpute] Iter 32: observed MAE=0.025745 rank=4
# [SoftImpute] Iter 33: observed MAE=0.025758 rank=4
# [SoftImpute] Iter 34: observed MAE=0.025770 rank=4
# [SoftImpute] Iter 35: observed MAE=0.025781 rank=4
# [SoftImpute] Iter 36: observed MAE=0.025789 rank=4
# [SoftImpute] Iter 37: observed MAE=0.025797 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025803 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025808 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025814 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025819 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025824 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025829 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025833 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025837 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025840 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025843 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025847 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025849 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025852 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025854 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025857 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025859 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025861 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025862 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025864 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025865 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025866 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025868 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025869 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025870 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025871 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025871 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025872 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025873 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025874 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025874 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025875 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025875 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025876 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025876 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025877 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025877 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025878 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025878 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025878 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025879 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025879 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025879 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025880 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025880 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025880 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025881 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025881 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025881 rank=4
# [SoftImpute] Iter 86: observed MAE=0.025882 rank=4
# [SoftImpute] Iter 87: observed MAE=0.025882 rank=4
# [SoftImpute] Stopped after iteration 87 for lambda=0.359345
# [SoftImpute] Max Singular Value of X_init = 17.512119
# [SoftImpute] Iter 1: observed MAE=0.024159 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024178 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024197 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024219 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024241 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024263 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024285 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024308 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024332 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024355 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024378 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024400 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024422 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024444 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024469 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024496 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024522 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024546 rank=4
# [SoftImpute] Iter 19: observed MAE=0.024569 rank=4
# [SoftImpute] Iter 20: observed MAE=0.024593 rank=4
# [SoftImpute] Iter 21: observed MAE=0.024619 rank=4
# [SoftImpute] Iter 22: observed MAE=0.024644 rank=4
# [SoftImpute] Iter 23: observed MAE=0.024670 rank=4
# [SoftImpute] Iter 24: observed MAE=0.024694 rank=4
# [SoftImpute] Iter 25: observed MAE=0.024719 rank=4
# [SoftImpute] Iter 26: observed MAE=0.024742 rank=4
# [SoftImpute] Iter 27: observed MAE=0.024764 rank=4
# [SoftImpute] Iter 28: observed MAE=0.024784 rank=4
# [SoftImpute] Iter 29: observed MAE=0.024803 rank=4
# [SoftImpute] Iter 30: observed MAE=0.024820 rank=4
# [SoftImpute] Iter 31: observed MAE=0.024834 rank=4
# [SoftImpute] Iter 32: observed MAE=0.024846 rank=4
# [SoftImpute] Iter 33: observed MAE=0.024857 rank=4
# [SoftImpute] Iter 34: observed MAE=0.024866 rank=4
# [SoftImpute] Iter 35: observed MAE=0.024873 rank=4
# [SoftImpute] Iter 36: observed MAE=0.024880 rank=4
# [SoftImpute] Iter 37: observed MAE=0.024886 rank=4
# [SoftImpute] Iter 38: observed MAE=0.024890 rank=4
# [SoftImpute] Iter 39: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 40: observed MAE=0.024897 rank=4
# [SoftImpute] Iter 41: observed MAE=0.024899 rank=4
# [SoftImpute] Iter 42: observed MAE=0.024900 rank=4
# [SoftImpute] Iter 43: observed MAE=0.024902 rank=4
# [SoftImpute] Iter 44: observed MAE=0.024902 rank=4
# [SoftImpute] Iter 45: observed MAE=0.024903 rank=4
# [SoftImpute] Iter 46: observed MAE=0.024903 rank=4
# [SoftImpute] Iter 47: observed MAE=0.024902 rank=4
# [SoftImpute] Iter 48: observed MAE=0.024903 rank=4
# [SoftImpute] Iter 49: observed MAE=0.024904 rank=4
# [SoftImpute] Iter 50: observed MAE=0.024904 rank=4
# [SoftImpute] Iter 51: observed MAE=0.024904 rank=4
# [SoftImpute] Iter 52: observed MAE=0.024903 rank=4
# [SoftImpute] Iter 53: observed MAE=0.024902 rank=4
# [SoftImpute] Iter 54: observed MAE=0.024901 rank=4
# [SoftImpute] Iter 55: observed MAE=0.024900 rank=4
# [SoftImpute] Iter 56: observed MAE=0.024899 rank=4
# [SoftImpute] Iter 57: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 58: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 59: observed MAE=0.024897 rank=4
# [SoftImpute] Iter 60: observed MAE=0.024896 rank=4
# [SoftImpute] Iter 61: observed MAE=0.024896 rank=4
# [SoftImpute] Iter 62: observed MAE=0.024895 rank=4
# [SoftImpute] Iter 63: observed MAE=0.024895 rank=4
# [SoftImpute] Iter 64: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 65: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 66: observed MAE=0.024893 rank=4
# [SoftImpute] Iter 67: observed MAE=0.024893 rank=4
# [SoftImpute] Iter 68: observed MAE=0.024893 rank=4
# [SoftImpute] Iter 69: observed MAE=0.024893 rank=4
# [SoftImpute] Iter 70: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 71: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 72: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 73: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 74: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 75: observed MAE=0.024894 rank=4
# [SoftImpute] Iter 76: observed MAE=0.024895 rank=4
# [SoftImpute] Iter 77: observed MAE=0.024895 rank=4
# [SoftImpute] Iter 78: observed MAE=0.024895 rank=4
# [SoftImpute] Iter 79: observed MAE=0.024895 rank=4
# [SoftImpute] Iter 80: observed MAE=0.024895 rank=4
# [SoftImpute] Iter 81: observed MAE=0.024896 rank=4
# [SoftImpute] Iter 82: observed MAE=0.024896 rank=4
# [SoftImpute] Iter 83: observed MAE=0.024896 rank=4
# [SoftImpute] Iter 84: observed MAE=0.024896 rank=4
# [SoftImpute] Iter 85: observed MAE=0.024896 rank=4
# [SoftImpute] Iter 86: observed MAE=0.024897 rank=4
# [SoftImpute] Iter 87: observed MAE=0.024897 rank=4
# [SoftImpute] Iter 88: observed MAE=0.024897 rank=4
# [SoftImpute] Iter 89: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 90: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 91: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 92: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 93: observed MAE=0.024898 rank=4
# [SoftImpute] Iter 94: observed MAE=0.024899 rank=4
# [SoftImpute] Iter 95: observed MAE=0.024899 rank=4
# [SoftImpute] Iter 96: observed MAE=0.024899 rank=4
# [SoftImpute] Iter 97: observed MAE=0.024899 rank=4
# [SoftImpute] Stopped after iteration 97 for lambda=0.350242
# [SoftImpute] Max Singular Value of X_init = 17.581610
# [SoftImpute] Iter 1: observed MAE=0.024333 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024368 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024404 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024438 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024471 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024504 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024538 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024571 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024605 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024638 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024671 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024703 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024738 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024773 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024808 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024844 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024880 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024914 rank=4
# [SoftImpute] Iter 19: observed MAE=0.024946 rank=4
# [SoftImpute] Iter 20: observed MAE=0.024979 rank=4
# [SoftImpute] Iter 21: observed MAE=0.025011 rank=4
# [SoftImpute] Iter 22: observed MAE=0.025041 rank=4
# [SoftImpute] Iter 23: observed MAE=0.025071 rank=4
# [SoftImpute] Iter 24: observed MAE=0.025102 rank=4
# [SoftImpute] Iter 25: observed MAE=0.025134 rank=4
# [SoftImpute] Iter 26: observed MAE=0.025165 rank=4
# [SoftImpute] Iter 27: observed MAE=0.025194 rank=4
# [SoftImpute] Iter 28: observed MAE=0.025222 rank=4
# [SoftImpute] Iter 29: observed MAE=0.025249 rank=4
# [SoftImpute] Iter 30: observed MAE=0.025274 rank=4
# [SoftImpute] Iter 31: observed MAE=0.025298 rank=4
# [SoftImpute] Iter 32: observed MAE=0.025320 rank=4
# [SoftImpute] Iter 33: observed MAE=0.025341 rank=4
# [SoftImpute] Iter 34: observed MAE=0.025360 rank=4
# [SoftImpute] Iter 35: observed MAE=0.025379 rank=4
# [SoftImpute] Iter 36: observed MAE=0.025396 rank=4
# [SoftImpute] Iter 37: observed MAE=0.025413 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025430 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025448 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025465 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025482 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025498 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025514 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025529 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025544 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025558 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025572 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025585 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025598 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025611 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025623 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025634 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025645 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025655 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025664 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025672 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025679 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025687 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025693 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025699 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025705 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025710 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025715 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025720 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025725 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025729 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025733 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025736 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025739 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025742 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025745 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025748 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025750 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025752 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025755 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025757 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025758 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025760 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025762 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025764 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025765 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025767 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025768 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025769 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025770 rank=4
# [SoftImpute] Iter 86: observed MAE=0.025771 rank=4
# [SoftImpute] Iter 87: observed MAE=0.025772 rank=4
# [SoftImpute] Iter 88: observed MAE=0.025773 rank=4
# [SoftImpute] Iter 89: observed MAE=0.025774 rank=4
# [SoftImpute] Stopped after iteration 89 for lambda=0.351632
# [SoftImpute] Max Singular Value of X_init = 18.032393
# [SoftImpute] Iter 1: observed MAE=0.024087 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024124 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024158 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024192 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024225 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024258 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024290 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024321 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024352 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024383 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024412 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024441 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024474 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024507 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024541 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024574 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024606 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024637 rank=4
# [SoftImpute] Iter 19: observed MAE=0.024667 rank=4
# [SoftImpute] Iter 20: observed MAE=0.024697 rank=4
# [SoftImpute] Iter 21: observed MAE=0.024727 rank=4
# [SoftImpute] Iter 22: observed MAE=0.024754 rank=4
# [SoftImpute] Iter 23: observed MAE=0.024780 rank=4
# [SoftImpute] Iter 24: observed MAE=0.024803 rank=4
# [SoftImpute] Iter 25: observed MAE=0.024826 rank=4
# [SoftImpute] Iter 26: observed MAE=0.024847 rank=4
# [SoftImpute] Iter 27: observed MAE=0.024869 rank=4
# [SoftImpute] Iter 28: observed MAE=0.024892 rank=4
# [SoftImpute] Iter 29: observed MAE=0.024912 rank=4
# [SoftImpute] Iter 30: observed MAE=0.024933 rank=4
# [SoftImpute] Iter 31: observed MAE=0.024954 rank=4
# [SoftImpute] Iter 32: observed MAE=0.024974 rank=4
# [SoftImpute] Iter 33: observed MAE=0.024993 rank=4
# [SoftImpute] Iter 34: observed MAE=0.025009 rank=4
# [SoftImpute] Iter 35: observed MAE=0.025024 rank=4
# [SoftImpute] Iter 36: observed MAE=0.025039 rank=4
# [SoftImpute] Iter 37: observed MAE=0.025053 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025067 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025080 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025093 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025104 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025115 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025124 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025133 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025142 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025149 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025157 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025164 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025170 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025175 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025180 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025185 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025189 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025193 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025196 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025199 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025202 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025205 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025208 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025210 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025212 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025214 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025216 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025218 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025220 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025222 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025224 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025225 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025227 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025228 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025230 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025231 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025232 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025234 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025235 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025236 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025237 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025238 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025239 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025240 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025241 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025242 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025243 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025244 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025244 rank=4
# [SoftImpute] Iter 86: observed MAE=0.025245 rank=4
# [SoftImpute] Iter 87: observed MAE=0.025246 rank=4
# [SoftImpute] Iter 88: observed MAE=0.025246 rank=4
# [SoftImpute] Iter 89: observed MAE=0.025247 rank=4
# [SoftImpute] Iter 90: observed MAE=0.025248 rank=4
# [SoftImpute] Iter 91: observed MAE=0.025248 rank=4
# [SoftImpute] Iter 92: observed MAE=0.025249 rank=4
# [SoftImpute] Iter 93: observed MAE=0.025250 rank=4
# [SoftImpute] Iter 94: observed MAE=0.025250 rank=4
# [SoftImpute] Iter 95: observed MAE=0.025251 rank=4
# [SoftImpute] Stopped after iteration 95 for lambda=0.360648
# [SoftImpute] Max Singular Value of X_init = 17.805530
# [SoftImpute] Iter 1: observed MAE=0.024326 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024361 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024394 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024427 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024458 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024489 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024520 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024550 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024580 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024611 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024642 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024671 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024701 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024733 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024763 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024792 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024820 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024848 rank=4
# [SoftImpute] Iter 19: observed MAE=0.024880 rank=4
# [SoftImpute] Iter 20: observed MAE=0.024917 rank=4
# [SoftImpute] Iter 21: observed MAE=0.024954 rank=4
# [SoftImpute] Iter 22: observed MAE=0.024997 rank=4
# [SoftImpute] Iter 23: observed MAE=0.025041 rank=4
# [SoftImpute] Iter 24: observed MAE=0.025083 rank=4
# [SoftImpute] Iter 25: observed MAE=0.025126 rank=4
# [SoftImpute] Iter 26: observed MAE=0.025173 rank=4
# [SoftImpute] Iter 27: observed MAE=0.025222 rank=4
# [SoftImpute] Iter 28: observed MAE=0.025270 rank=4
# [SoftImpute] Iter 29: observed MAE=0.025316 rank=4
# [SoftImpute] Iter 30: observed MAE=0.025362 rank=4
# [SoftImpute] Iter 31: observed MAE=0.025404 rank=4
# [SoftImpute] Iter 32: observed MAE=0.025445 rank=4
# [SoftImpute] Iter 33: observed MAE=0.025483 rank=4
# [SoftImpute] Iter 34: observed MAE=0.025518 rank=4
# [SoftImpute] Iter 35: observed MAE=0.025550 rank=4
# [SoftImpute] Iter 36: observed MAE=0.025578 rank=4
# [SoftImpute] Iter 37: observed MAE=0.025604 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025627 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025648 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025667 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025684 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025702 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025718 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025732 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025744 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025755 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025766 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025775 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025783 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025791 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025798 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025804 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025809 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025814 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025819 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025823 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025826 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025830 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025833 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025835 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025838 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025841 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025843 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025846 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025848 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025850 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025852 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025853 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025855 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025857 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025858 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025859 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025861 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025862 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025863 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025864 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025865 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025866 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025867 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025868 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025868 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025869 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025870 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025871 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025871 rank=4
# [SoftImpute] Stopped after iteration 85 for lambda=0.356111
# [SoftImpute] Max Singular Value of X_init = 18.052080
# [SoftImpute] Iter 1: observed MAE=0.024461 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024490 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024518 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024544 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024572 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024600 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024627 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024653 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024679 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024707 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024736 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024767 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024802 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024838 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024876 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024913 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024948 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024980 rank=4
# [SoftImpute] Iter 19: observed MAE=0.025010 rank=4
# [SoftImpute] Iter 20: observed MAE=0.025037 rank=4
# [SoftImpute] Iter 21: observed MAE=0.025062 rank=4
# [SoftImpute] Iter 22: observed MAE=0.025089 rank=4
# [SoftImpute] Iter 23: observed MAE=0.025115 rank=4
# [SoftImpute] Iter 24: observed MAE=0.025141 rank=4
# [SoftImpute] Iter 25: observed MAE=0.025165 rank=4
# [SoftImpute] Iter 26: observed MAE=0.025190 rank=4
# [SoftImpute] Iter 27: observed MAE=0.025216 rank=4
# [SoftImpute] Iter 28: observed MAE=0.025242 rank=4
# [SoftImpute] Iter 29: observed MAE=0.025266 rank=4
# [SoftImpute] Iter 30: observed MAE=0.025289 rank=4
# [SoftImpute] Iter 31: observed MAE=0.025314 rank=4
# [SoftImpute] Iter 32: observed MAE=0.025337 rank=4
# [SoftImpute] Iter 33: observed MAE=0.025359 rank=4
# [SoftImpute] Iter 34: observed MAE=0.025380 rank=4
# [SoftImpute] Iter 35: observed MAE=0.025399 rank=4
# [SoftImpute] Iter 36: observed MAE=0.025416 rank=4
# [SoftImpute] Iter 37: observed MAE=0.025431 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025446 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025461 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025473 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025485 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025495 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025505 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025513 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025521 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025528 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025534 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025540 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025546 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025551 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025555 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025560 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025564 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025568 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025571 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025574 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025578 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025580 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025583 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025586 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025588 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025590 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025592 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025594 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025596 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025597 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025599 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025600 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025601 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025602 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025604 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025605 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025606 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025606 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025607 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025608 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025609 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025610 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025610 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025611 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025611 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025612 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025612 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025613 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025613 rank=4
# [SoftImpute] Iter 86: observed MAE=0.025614 rank=4
# [SoftImpute] Iter 87: observed MAE=0.025614 rank=4
# [SoftImpute] Iter 88: observed MAE=0.025614 rank=4
# [SoftImpute] Iter 89: observed MAE=0.025615 rank=4
# [SoftImpute] Iter 90: observed MAE=0.025615 rank=4
# [SoftImpute] Stopped after iteration 90 for lambda=0.361042
# [SoftImpute] Max Singular Value of X_init = 17.829150
# [SoftImpute] Iter 1: observed MAE=0.024269 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024303 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024335 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024368 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024400 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024431 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024460 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024488 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024513 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024537 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024559 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024581 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024603 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024623 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024642 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024661 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024678 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024693 rank=4
# [SoftImpute] Iter 19: observed MAE=0.024706 rank=4
# [SoftImpute] Iter 20: observed MAE=0.024719 rank=4
# [SoftImpute] Iter 21: observed MAE=0.024732 rank=4
# [SoftImpute] Iter 22: observed MAE=0.024742 rank=4
# [SoftImpute] Iter 23: observed MAE=0.024751 rank=4
# [SoftImpute] Iter 24: observed MAE=0.024763 rank=4
# [SoftImpute] Iter 25: observed MAE=0.024780 rank=4
# [SoftImpute] Iter 26: observed MAE=0.024799 rank=4
# [SoftImpute] Iter 27: observed MAE=0.024819 rank=4
# [SoftImpute] Iter 28: observed MAE=0.024837 rank=4
# [SoftImpute] Iter 29: observed MAE=0.024853 rank=4
# [SoftImpute] Iter 30: observed MAE=0.024873 rank=4
# [SoftImpute] Iter 31: observed MAE=0.024893 rank=4
# [SoftImpute] Iter 32: observed MAE=0.024911 rank=4
# [SoftImpute] Iter 33: observed MAE=0.024931 rank=4
# [SoftImpute] Iter 34: observed MAE=0.024949 rank=4
# [SoftImpute] Iter 35: observed MAE=0.024966 rank=4
# [SoftImpute] Iter 36: observed MAE=0.024982 rank=4
# [SoftImpute] Iter 37: observed MAE=0.024996 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025011 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025025 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025037 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025048 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025058 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025066 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025074 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025082 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025088 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025093 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025098 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025103 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025106 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025109 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025112 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025114 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025116 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025117 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025118 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025119 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025120 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025120 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025121 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025121 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025121 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025122 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025122 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025122 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025123 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025124 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025124 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025125 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025125 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025126 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025126 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025126 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025126 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025126 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025127 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025128 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025128 rank=4
# [SoftImpute] Iter 86: observed MAE=0.025128 rank=4
# [SoftImpute] Iter 87: observed MAE=0.025128 rank=4
# [SoftImpute] Stopped after iteration 87 for lambda=0.356583
# [SoftImpute] Max Singular Value of X_init = 17.797134
# [SoftImpute] Iter 1: observed MAE=0.024395 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024428 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024459 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024491 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024522 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024552 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024580 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024609 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024640 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024672 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024706 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024743 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024780 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024815 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024847 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024878 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024909 rank=4
# [SoftImpute] Iter 18: observed MAE=0.024936 rank=4
# [SoftImpute] Iter 19: observed MAE=0.024963 rank=4
# [SoftImpute] Iter 20: observed MAE=0.024991 rank=4
# [SoftImpute] Iter 21: observed MAE=0.025017 rank=4
# [SoftImpute] Iter 22: observed MAE=0.025041 rank=4
# [SoftImpute] Iter 23: observed MAE=0.025064 rank=4
# [SoftImpute] Iter 24: observed MAE=0.025084 rank=4
# [SoftImpute] Iter 25: observed MAE=0.025102 rank=4
# [SoftImpute] Iter 26: observed MAE=0.025117 rank=4
# [SoftImpute] Iter 27: observed MAE=0.025132 rank=4
# [SoftImpute] Iter 28: observed MAE=0.025144 rank=4
# [SoftImpute] Iter 29: observed MAE=0.025155 rank=4
# [SoftImpute] Iter 30: observed MAE=0.025163 rank=4
# [SoftImpute] Iter 31: observed MAE=0.025171 rank=4
# [SoftImpute] Iter 32: observed MAE=0.025176 rank=4
# [SoftImpute] Iter 33: observed MAE=0.025181 rank=4
# [SoftImpute] Iter 34: observed MAE=0.025185 rank=4
# [SoftImpute] Iter 35: observed MAE=0.025188 rank=4
# [SoftImpute] Iter 36: observed MAE=0.025190 rank=4
# [SoftImpute] Iter 37: observed MAE=0.025192 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025195 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025198 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025202 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025205 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025207 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025209 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025210 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025211 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025212 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025212 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025212 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025212 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025212 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025211 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025211 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025211 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025210 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025209 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025209 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025208 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025208 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025207 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025206 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025206 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025205 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025205 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025204 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025204 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025203 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025203 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025202 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025202 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025202 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025201 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025201 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025201 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025201 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025201 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 86: observed MAE=0.025200 rank=4
# [SoftImpute] Iter 87: observed MAE=0.025200 rank=4
# [SoftImpute] Stopped after iteration 87 for lambda=0.355943
# [SoftImpute] Max Singular Value of X_init = 17.622324
# [SoftImpute] Iter 1: observed MAE=0.024546 rank=4
# [SoftImpute] Iter 2: observed MAE=0.024583 rank=4
# [SoftImpute] Iter 3: observed MAE=0.024619 rank=4
# [SoftImpute] Iter 4: observed MAE=0.024654 rank=4
# [SoftImpute] Iter 5: observed MAE=0.024689 rank=4
# [SoftImpute] Iter 6: observed MAE=0.024722 rank=4
# [SoftImpute] Iter 7: observed MAE=0.024754 rank=4
# [SoftImpute] Iter 8: observed MAE=0.024784 rank=4
# [SoftImpute] Iter 9: observed MAE=0.024812 rank=4
# [SoftImpute] Iter 10: observed MAE=0.024839 rank=4
# [SoftImpute] Iter 11: observed MAE=0.024864 rank=4
# [SoftImpute] Iter 12: observed MAE=0.024888 rank=4
# [SoftImpute] Iter 13: observed MAE=0.024911 rank=4
# [SoftImpute] Iter 14: observed MAE=0.024931 rank=4
# [SoftImpute] Iter 15: observed MAE=0.024951 rank=4
# [SoftImpute] Iter 16: observed MAE=0.024968 rank=4
# [SoftImpute] Iter 17: observed MAE=0.024985 rank=4
# [SoftImpute] Iter 18: observed MAE=0.025007 rank=4
# [SoftImpute] Iter 19: observed MAE=0.025028 rank=4
# [SoftImpute] Iter 20: observed MAE=0.025052 rank=4
# [SoftImpute] Iter 21: observed MAE=0.025079 rank=4
# [SoftImpute] Iter 22: observed MAE=0.025103 rank=4
# [SoftImpute] Iter 23: observed MAE=0.025126 rank=4
# [SoftImpute] Iter 24: observed MAE=0.025147 rank=4
# [SoftImpute] Iter 25: observed MAE=0.025169 rank=4
# [SoftImpute] Iter 26: observed MAE=0.025190 rank=4
# [SoftImpute] Iter 27: observed MAE=0.025212 rank=4
# [SoftImpute] Iter 28: observed MAE=0.025233 rank=4
# [SoftImpute] Iter 29: observed MAE=0.025254 rank=4
# [SoftImpute] Iter 30: observed MAE=0.025273 rank=4
# [SoftImpute] Iter 31: observed MAE=0.025291 rank=4
# [SoftImpute] Iter 32: observed MAE=0.025308 rank=4
# [SoftImpute] Iter 33: observed MAE=0.025325 rank=4
# [SoftImpute] Iter 34: observed MAE=0.025342 rank=4
# [SoftImpute] Iter 35: observed MAE=0.025358 rank=4
# [SoftImpute] Iter 36: observed MAE=0.025375 rank=4
# [SoftImpute] Iter 37: observed MAE=0.025391 rank=4
# [SoftImpute] Iter 38: observed MAE=0.025406 rank=4
# [SoftImpute] Iter 39: observed MAE=0.025419 rank=4
# [SoftImpute] Iter 40: observed MAE=0.025432 rank=4
# [SoftImpute] Iter 41: observed MAE=0.025443 rank=4
# [SoftImpute] Iter 42: observed MAE=0.025454 rank=4
# [SoftImpute] Iter 43: observed MAE=0.025464 rank=4
# [SoftImpute] Iter 44: observed MAE=0.025473 rank=4
# [SoftImpute] Iter 45: observed MAE=0.025481 rank=4
# [SoftImpute] Iter 46: observed MAE=0.025490 rank=4
# [SoftImpute] Iter 47: observed MAE=0.025498 rank=4
# [SoftImpute] Iter 48: observed MAE=0.025505 rank=4
# [SoftImpute] Iter 49: observed MAE=0.025512 rank=4
# [SoftImpute] Iter 50: observed MAE=0.025519 rank=4
# [SoftImpute] Iter 51: observed MAE=0.025525 rank=4
# [SoftImpute] Iter 52: observed MAE=0.025531 rank=4
# [SoftImpute] Iter 53: observed MAE=0.025538 rank=4
# [SoftImpute] Iter 54: observed MAE=0.025543 rank=4
# [SoftImpute] Iter 55: observed MAE=0.025548 rank=4
# [SoftImpute] Iter 56: observed MAE=0.025553 rank=4
# [SoftImpute] Iter 57: observed MAE=0.025558 rank=4
# [SoftImpute] Iter 58: observed MAE=0.025562 rank=4
# [SoftImpute] Iter 59: observed MAE=0.025566 rank=4
# [SoftImpute] Iter 60: observed MAE=0.025569 rank=4
# [SoftImpute] Iter 61: observed MAE=0.025572 rank=4
# [SoftImpute] Iter 62: observed MAE=0.025576 rank=4
# [SoftImpute] Iter 63: observed MAE=0.025579 rank=4
# [SoftImpute] Iter 64: observed MAE=0.025582 rank=4
# [SoftImpute] Iter 65: observed MAE=0.025585 rank=4
# [SoftImpute] Iter 66: observed MAE=0.025587 rank=4
# [SoftImpute] Iter 67: observed MAE=0.025589 rank=4
# [SoftImpute] Iter 68: observed MAE=0.025592 rank=4
# [SoftImpute] Iter 69: observed MAE=0.025594 rank=4
# [SoftImpute] Iter 70: observed MAE=0.025596 rank=4
# [SoftImpute] Iter 71: observed MAE=0.025597 rank=4
# [SoftImpute] Iter 72: observed MAE=0.025599 rank=4
# [SoftImpute] Iter 73: observed MAE=0.025601 rank=4
# [SoftImpute] Iter 74: observed MAE=0.025602 rank=4
# [SoftImpute] Iter 75: observed MAE=0.025604 rank=4
# [SoftImpute] Iter 76: observed MAE=0.025605 rank=4
# [SoftImpute] Iter 77: observed MAE=0.025606 rank=4
# [SoftImpute] Iter 78: observed MAE=0.025607 rank=4
# [SoftImpute] Iter 79: observed MAE=0.025608 rank=4
# [SoftImpute] Iter 80: observed MAE=0.025610 rank=4
# [SoftImpute] Iter 81: observed MAE=0.025611 rank=4
# [SoftImpute] Iter 82: observed MAE=0.025611 rank=4
# [SoftImpute] Iter 83: observed MAE=0.025612 rank=4
# [SoftImpute] Iter 84: observed MAE=0.025613 rank=4
# [SoftImpute] Iter 85: observed MAE=0.025614 rank=4
# [SoftImpute] Iter 86: observed MAE=0.025615 rank=4
# [SoftImpute] Iter 87: observed MAE=0.025615 rank=4
# [SoftImpute] Iter 88: observed MAE=0.025616 rank=4
# [SoftImpute] Iter 89: observed MAE=0.025617 rank=4
# [SoftImpute] Iter 90: observed MAE=0.025617 rank=4
# [SoftImpute] Iter 91: observed MAE=0.025618 rank=4
# [SoftImpute] Iter 92: observed MAE=0.025619 rank=4
# [SoftImpute] Iter 93: observed MAE=0.025619 rank=4
# [SoftImpute] Iter 94: observed MAE=0.025620 rank=4
# [SoftImpute] Iter 95: observed MAE=0.025620 rank=4
# [SoftImpute] Stopped after iteration 95 for lambda=0.352446
# [SoftImpute] Max Singular Value of X_init = 15.485828
# [SoftImpute] Iter 1: observed MAE=0.023766 rank=4
# [SoftImpute] Iter 2: observed MAE=0.023769 rank=4
# [SoftImpute] Iter 3: observed MAE=0.023773 rank=4
# [SoftImpute] Iter 4: observed MAE=0.023776 rank=4
# [SoftImpute] Iter 5: observed MAE=0.023780 rank=4
# [SoftImpute] Iter 6: observed MAE=0.023783 rank=4
# [SoftImpute] Iter 7: observed MAE=0.023786 rank=4
# [SoftImpute] Iter 8: observed MAE=0.023788 rank=4
# [SoftImpute] Iter 9: observed MAE=0.023790 rank=4
# [SoftImpute] Iter 10: observed MAE=0.023792 rank=4
# [SoftImpute] Iter 11: observed MAE=0.023792 rank=4
# [SoftImpute] Iter 12: observed MAE=0.023792 rank=4
# [SoftImpute] Iter 13: observed MAE=0.023791 rank=4
# [SoftImpute] Iter 14: observed MAE=0.023791 rank=4
# [SoftImpute] Iter 15: observed MAE=0.023792 rank=4
# [SoftImpute] Iter 16: observed MAE=0.023792 rank=4
# [SoftImpute] Iter 17: observed MAE=0.023792 rank=4
# [SoftImpute] Iter 18: observed MAE=0.023793 rank=4
# ...
# [SoftImpute] Iter 98: observed MAE=0.022298 rank=4
# [SoftImpute] Iter 99: observed MAE=0.022296 rank=4
# [SoftImpute] Iter 100: observed MAE=0.022295 rank=4
# [SoftImpute] Stopped after iteration 100 for lambda=0.218700
# [SoftImpute] Max Singular Value of X_init = 11.238177
# [SoftImpute] Iter 1: observed MAE=0.022654 rank=4
# [SoftImpute] Iter 2: observed MAE=0.022651 rank=4
# [SoftImpute] Iter 3: observed MAE=0.022647 rank=4
# [SoftImpute] Iter 4: observed MAE=0.022643 rank=4
# [SoftImpute] Iter 5: observed MAE=0.022639 rank=4
# [SoftImpute] Iter 6: observed MAE=0.022634 rank=4
# [SoftImpute] Iter 7: observed MAE=0.022630 rank=4
# [SoftImpute] Iter 8: observed MAE=0.022625 rank=4
# [SoftImpute] Iter 9: observed MAE=0.022622 rank=4
# [SoftImpute] Iter 10: observed MAE=0.022618 rank=4
# [SoftImpute] Iter 11: observed MAE=0.022614 rank=4
# [SoftImpute] Iter 12: observed MAE=0.022610 rank=4
# [SoftImpute] Iter 13: observed MAE=0.022606 rank=4
# [SoftImpute] Iter 14: observed MAE=0.022601 rank=4
# [SoftImpute] Iter 15: observed MAE=0.022597 rank=4
# [SoftImpute] Iter 16: observed MAE=0.022592 rank=4
# [SoftImpute] Iter 17: observed MAE=0.022587 rank=4
# [SoftImpute] Iter 18: observed MAE=0.022581 rank=4
# [SoftImpute] Iter 19: observed MAE=0.022576 rank=4
# [SoftImpute] Iter 20: observed MAE=0.022570 rank=4
# [SoftImpute] Iter 21: observed MAE=0.022565 rank=4
# [SoftImpute] Iter 22: observed MAE=0.022559 rank=4
# [SoftImpute] Iter 23: observed MAE=0.022553 rank=4
# [SoftImpute] Iter 24: observed MAE=0.022546 rank=4
# [SoftImpute] Iter 25: observed MAE=0.022540 rank=4
# [SoftImpute] Iter 26: observed MAE=0.022533 rank=4
# [SoftImpute] Iter 27: observed MAE=0.022526 rank=4
# [SoftImpute] Iter 28: observed MAE=0.022520 rank=4
# [SoftImpute] Iter 29: observed MAE=0.022512 rank=4
# [SoftImpute] Iter 30: observed MAE=0.022505 rank=4
# [SoftImpute] Iter 31: observed MAE=0.022498 rank=4
# [SoftImpute] Iter 32: observed MAE=0.022491 rank=4
# [SoftImpute] Iter 33: observed MAE=0.022485 rank=4
# [SoftImpute] Iter 34: observed MAE=0.022480 rank=4
# [SoftImpute] Iter 35: observed MAE=0.022474 rank=4
# [SoftImpute] Iter 36: observed MAE=0.022468 rank=4
# [SoftImpute] Iter 37: observed MAE=0.022462 rank=4
# [SoftImpute] Iter 38: observed MAE=0.022455 rank=4
# [SoftImpute] Iter 39: observed MAE=0.022450 rank=4
# [SoftImpute] Iter 40: observed MAE=0.022446 rank=4
# [SoftImpute] Iter 41: observed MAE=0.022441 rank=4
# [SoftImpute] Iter 42: observed MAE=0.022436 rank=4
# [SoftImpute] Iter 43: observed MAE=0.022431 rank=4
# [SoftImpute] Iter 44: observed MAE=0.022426 rank=4
# [SoftImpute] Iter 45: observed MAE=0.022421 rank=4
# [SoftImpute] Iter 46: observed MAE=0.022416 rank=4
# [SoftImpute] Iter 47: observed MAE=0.022412 rank=4
# [SoftImpute] Iter 48: observed MAE=0.022407 rank=4
# [SoftImpute] Iter 49: observed MAE=0.022403 rank=4
# [SoftImpute] Iter 50: observed MAE=0.022399 rank=4
# [SoftImpute] Iter 51: observed MAE=0.022395 rank=4
# [SoftImpute] Iter 52: observed MAE=0.022391 rank=4
# [SoftImpute] Iter 53: observed MAE=0.022387 rank=4
# [SoftImpute] Iter 54: observed MAE=0.022382 rank=4
# [SoftImpute] Iter 55: observed MAE=0.022378 rank=4
# [SoftImpute] Iter 56: observed MAE=0.022374 rank=4
# [SoftImpute] Iter 57: observed MAE=0.022370 rank=4
# [SoftImpute] Iter 58: observed MAE=0.022366 rank=4
# [SoftImpute] Iter 59: observed MAE=0.022362 rank=4
# [SoftImpute] Iter 60: observed MAE=0.022358 rank=4
# [SoftImpute] Iter 61: observed MAE=0.022354 rank=4
# [SoftImpute] Iter 62: observed MAE=0.022349 rank=4
# [SoftImpute] Iter 63: observed MAE=0.022345 rank=4
# [SoftImpute] Iter 64: observed MAE=0.022341 rank=4
# [SoftImpute] Iter 65: observed MAE=0.022337 rank=4
# [SoftImpute] Iter 66: observed MAE=0.022333 rank=4
# [SoftImpute] Iter 67: observed MAE=0.022328 rank=4
# [SoftImpute] Iter 68: observed MAE=0.022324 rank=4
# [SoftImpute] Iter 69: observed MAE=0.022320 rank=4
# [SoftImpute] Iter 70: observed MAE=0.022315 rank=4
# [SoftImpute] Iter 71: observed MAE=0.022311 rank=4
# [SoftImpute] Iter 72: observed MAE=0.022306 rank=4
# [SoftImpute] Iter 73: observed MAE=0.022301 rank=4
# [SoftImpute] Iter 74: observed MAE=0.022296 rank=4
# [SoftImpute] Iter 75: observed MAE=0.022292 rank=4
# [SoftImpute] Iter 76: observed MAE=0.022287 rank=4
# [SoftImpute] Iter 77: observed MAE=0.022282 rank=4
# [SoftImpute] Iter 78: observed MAE=0.022277 rank=4
# [SoftImpute] Iter 79: observed MAE=0.022272 rank=4
# [SoftImpute] Iter 80: observed MAE=0.022267 rank=4
# [SoftImpute] Iter 81: observed MAE=0.022262 rank=4
# [SoftImpute] Iter 82: observed MAE=0.022257 rank=4
# [SoftImpute] Iter 83: observed MAE=0.022252 rank=4
# [SoftImpute] Iter 84: observed MAE=0.022247 rank=4
# [SoftImpute] Iter 85: observed MAE=0.022243 rank=4
# [SoftImpute] Iter 86: observed MAE=0.022239 rank=4
# [SoftImpute] Iter 87: observed MAE=0.022235 rank=4
# [SoftImpute] Iter 88: observed MAE=0.022230 rank=4
# [SoftImpute] Iter 89: observed MAE=0.022226 rank=4
# [SoftImpute] Iter 90: observed MAE=0.022221 rank=4
# [SoftImpute] Iter 91: observed MAE=0.022217 rank=4
# [SoftImpute] Iter 92: observed MAE=0.022212 rank=4
# [SoftImpute] Iter 93: observed MAE=0.022208 rank=4
# [SoftImpute] Iter 94: observed MAE=0.022203 rank=4
# [SoftImpute] Iter 95: observed MAE=0.022199 rank=4
# [SoftImpute] Iter 96: observed MAE=0.022194 rank=4
# [SoftImpute] Iter 97: observed MAE=0.022190 rank=4
# [SoftImpute] Iter 98: observed MAE=0.022186 rank=4
# [SoftImpute] Iter 99: observed MAE=0.022181 rank=4
# [SoftImpute] Iter 100: observed MAE=0.022177 rank=4
# [SoftImpute] Stopped after iteration 100 for lambda=0.224764
# [SoftImpute] Max Singular Value of X_init = 10.905918
# [SoftImpute] Iter 1: observed MAE=0.022672 rank=4
# [SoftImpute] Iter 2: observed MAE=0.022670 rank=4
# [SoftImpute] Iter 3: observed MAE=0.022668 rank=4
# [SoftImpute] Iter 4: observed MAE=0.022667 rank=4
# [SoftImpute] Iter 5: observed MAE=0.022664 rank=4
# [SoftImpute] Iter 6: observed MAE=0.022662 rank=4
# [SoftImpute] Iter 7: observed MAE=0.022659 rank=4
# [SoftImpute] Iter 8: observed MAE=0.022656 rank=4
# [SoftImpute] Iter 9: observed MAE=0.022653 rank=4
# [SoftImpute] Iter 10: observed MAE=0.022650 rank=4
# [SoftImpute] Iter 11: observed MAE=0.022646 rank=4
# [SoftImpute] Iter 12: observed MAE=0.022643 rank=4
# [SoftImpute] Iter 13: observed MAE=0.022639 rank=4
# [SoftImpute] Iter 14: observed MAE=0.022635 rank=4
# [SoftImpute] Iter 15: observed MAE=0.022630 rank=4
# [SoftImpute] Iter 16: observed MAE=0.022626 rank=4
# [SoftImpute] Iter 17: observed MAE=0.022621 rank=4
# [SoftImpute] Iter 18: observed MAE=0.022616 rank=4
# [SoftImpute] Iter 19: observed MAE=0.022610 rank=4
# [SoftImpute] Iter 20: observed MAE=0.022605 rank=4
# [SoftImpute] Iter 21: observed MAE=0.022600 rank=4
# [SoftImpute] Iter 22: observed MAE=0.022595 rank=4
# [SoftImpute] Iter 23: observed MAE=0.022589 rank=4
# [SoftImpute] Iter 24: observed MAE=0.022584 rank=4
# [SoftImpute] Iter 25: observed MAE=0.022578 rank=4
# [SoftImpute] Iter 26: observed MAE=0.022572 rank=4
# [SoftImpute] Iter 27: observed MAE=0.022567 rank=4
# [SoftImpute] Iter 28: observed MAE=0.022560 rank=4
# [SoftImpute] Iter 29: observed MAE=0.022554 rank=4
# [SoftImpute] Iter 30: observed MAE=0.022548 rank=4
# [SoftImpute] Iter 31: observed MAE=0.022541 rank=4
# [SoftImpute] Iter 32: observed MAE=0.022534 rank=4
# [SoftImpute] Iter 33: observed MAE=0.022528 rank=4
# [SoftImpute] Iter 34: observed MAE=0.022522 rank=4
# [SoftImpute] Iter 35: observed MAE=0.022515 rank=4
# [SoftImpute] Iter 36: observed MAE=0.022509 rank=4
# [SoftImpute] Iter 37: observed MAE=0.022503 rank=4
# [SoftImpute] Iter 38: observed MAE=0.022497 rank=4
# [SoftImpute] Iter 39: observed MAE=0.022491 rank=4
# [SoftImpute] Iter 40: observed MAE=0.022484 rank=4
# [SoftImpute] Iter 41: observed MAE=0.022478 rank=4
# [SoftImpute] Iter 42: observed MAE=0.022473 rank=4
# [SoftImpute] Iter 43: observed MAE=0.022468 rank=4
# [SoftImpute] Iter 44: observed MAE=0.022463 rank=4
# [SoftImpute] Iter 45: observed MAE=0.022458 rank=4
# [SoftImpute] Iter 46: observed MAE=0.022453 rank=4
# [SoftImpute] Iter 47: observed MAE=0.022448 rank=4
# [SoftImpute] Iter 48: observed MAE=0.022444 rank=4
# [SoftImpute] Iter 49: observed MAE=0.022439 rank=4
# [SoftImpute] Iter 50: observed MAE=0.022434 rank=4
# [SoftImpute] Iter 51: observed MAE=0.022428 rank=4
# [SoftImpute] Iter 52: observed MAE=0.022423 rank=4
# [SoftImpute] Iter 53: observed MAE=0.022418 rank=4
# [SoftImpute] Iter 54: observed MAE=0.022412 rank=4
# [SoftImpute] Iter 55: observed MAE=0.022408 rank=4
# [SoftImpute] Iter 56: observed MAE=0.022404 rank=4
# [SoftImpute] Iter 57: observed MAE=0.022400 rank=4
# [SoftImpute] Iter 58: observed MAE=0.022396 rank=4
# [SoftImpute] Iter 59: observed MAE=0.022392 rank=4
# [SoftImpute] Iter 60: observed MAE=0.022388 rank=4
# [SoftImpute] Iter 61: observed MAE=0.022384 rank=4
# [SoftImpute] Iter 62: observed MAE=0.022381 rank=4
# [SoftImpute] Iter 63: observed MAE=0.022377 rank=4
# [SoftImpute] Iter 64: observed MAE=0.022374 rank=4
# [SoftImpute] Iter 65: observed MAE=0.022370 rank=4
# [SoftImpute] Iter 66: observed MAE=0.022366 rank=4
# [SoftImpute] Iter 67: observed MAE=0.022362 rank=4
# [SoftImpute] Iter 68: observed MAE=0.022358 rank=4
# [SoftImpute] Iter 69: observed MAE=0.022354 rank=4
# [SoftImpute] Iter 70: observed MAE=0.022350 rank=4
# [SoftImpute] Iter 71: observed MAE=0.022345 rank=4
# [SoftImpute] Iter 72: observed MAE=0.022341 rank=4
# [SoftImpute] Iter 73: observed MAE=0.022336 rank=4
# [SoftImpute] Iter 74: observed MAE=0.022332 rank=4
# [SoftImpute] Iter 75: observed MAE=0.022327 rank=4
# [SoftImpute] Iter 76: observed MAE=0.022323 rank=4
# [SoftImpute] Iter 77: observed MAE=0.022319 rank=4
# [SoftImpute] Iter 78: observed MAE=0.022315 rank=4
# [SoftImpute] Iter 79: observed MAE=0.022310 rank=4
# [SoftImpute] Iter 80: observed MAE=0.022306 rank=4
# [SoftImpute] Iter 81: observed MAE=0.022302 rank=4
# [SoftImpute] Iter 82: observed MAE=0.022297 rank=4
# [SoftImpute] Iter 83: observed MAE=0.022293 rank=4
# [SoftImpute] Iter 84: observed MAE=0.022289 rank=4
# [SoftImpute] Iter 85: observed MAE=0.022284 rank=4
# [SoftImpute] Iter 86: observed MAE=0.022280 rank=4
# [SoftImpute] Iter 87: observed MAE=0.022275 rank=4
# [SoftImpute] Iter 88: observed MAE=0.022270 rank=4
# [SoftImpute] Iter 89: observed MAE=0.022266 rank=4
# [SoftImpute] Iter 90: observed MAE=0.022261 rank=4
# [SoftImpute] Iter 91: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 92: observed MAE=0.022251 rank=4
# [SoftImpute] Iter 93: observed MAE=0.022246 rank=4
# [SoftImpute] Iter 94: observed MAE=0.022242 rank=4
# [SoftImpute] Iter 95: observed MAE=0.022237 rank=4
# [SoftImpute] Iter 96: observed MAE=0.022233 rank=4
# [SoftImpute] Iter 97: observed MAE=0.022229 rank=4
# [SoftImpute] Iter 98: observed MAE=0.022224 rank=4
# [SoftImpute] Iter 99: observed MAE=0.022220 rank=4
# [SoftImpute] Iter 100: observed MAE=0.022216 rank=4
# [SoftImpute] Stopped after iteration 100 for lambda=0.218118
# [SoftImpute] Max Singular Value of X_init = 11.035003
# [SoftImpute] Iter 1: observed MAE=0.022496 rank=4
# [SoftImpute] Iter 2: observed MAE=0.022493 rank=4
# [SoftImpute] Iter 3: observed MAE=0.022491 rank=4
# [SoftImpute] Iter 4: observed MAE=0.022488 rank=4
# [SoftImpute] Iter 5: observed MAE=0.022485 rank=4
# [SoftImpute] Iter 6: observed MAE=0.022482 rank=4
# [SoftImpute] Iter 7: observed MAE=0.022480 rank=4
# [SoftImpute] Iter 8: observed MAE=0.022477 rank=4
# [SoftImpute] Iter 9: observed MAE=0.022475 rank=4
# [SoftImpute] Iter 10: observed MAE=0.022472 rank=4
# [SoftImpute] Iter 11: observed MAE=0.022469 rank=4
# [SoftImpute] Iter 12: observed MAE=0.022467 rank=4
# [SoftImpute] Iter 13: observed MAE=0.022464 rank=4
# [SoftImpute] Iter 14: observed MAE=0.022462 rank=4
# [SoftImpute] Iter 15: observed MAE=0.022459 rank=4
# [SoftImpute] Iter 16: observed MAE=0.022457 rank=4
# [SoftImpute] Iter 17: observed MAE=0.022454 rank=4
# [SoftImpute] Iter 18: observed MAE=0.022452 rank=4
# [SoftImpute] Iter 19: observed MAE=0.022450 rank=4
# [SoftImpute] Iter 20: observed MAE=0.022447 rank=4
# [SoftImpute] Iter 21: observed MAE=0.022444 rank=4
# [SoftImpute] Iter 22: observed MAE=0.022442 rank=4
# [SoftImpute] Iter 23: observed MAE=0.022439 rank=4
# [SoftImpute] Iter 24: observed MAE=0.022437 rank=4
# [SoftImpute] Iter 25: observed MAE=0.022434 rank=4
# [SoftImpute] Iter 26: observed MAE=0.022431 rank=4
# [SoftImpute] Iter 27: observed MAE=0.022428 rank=4
# [SoftImpute] Iter 28: observed MAE=0.022425 rank=4
# [SoftImpute] Iter 29: observed MAE=0.022422 rank=4
# [SoftImpute] Iter 30: observed MAE=0.022419 rank=4
# [SoftImpute] Iter 31: observed MAE=0.022415 rank=4
# [SoftImpute] Iter 32: observed MAE=0.022412 rank=4
# [SoftImpute] Iter 33: observed MAE=0.022408 rank=4
# [SoftImpute] Iter 34: observed MAE=0.022404 rank=4
# [SoftImpute] Iter 35: observed MAE=0.022400 rank=4
# [SoftImpute] Iter 36: observed MAE=0.022396 rank=4
# [SoftImpute] Iter 37: observed MAE=0.022392 rank=4
# [SoftImpute] Iter 38: observed MAE=0.022388 rank=4
# [SoftImpute] Iter 39: observed MAE=0.022383 rank=4
# [SoftImpute] Iter 40: observed MAE=0.022379 rank=4
# [SoftImpute] Iter 41: observed MAE=0.022375 rank=4
# [SoftImpute] Iter 42: observed MAE=0.022370 rank=4
# [SoftImpute] Iter 43: observed MAE=0.022366 rank=4
# [SoftImpute] Iter 44: observed MAE=0.022361 rank=4
# [SoftImpute] Iter 45: observed MAE=0.022356 rank=4
# [SoftImpute] Iter 46: observed MAE=0.022351 rank=4
# [SoftImpute] Iter 47: observed MAE=0.022346 rank=4
# [SoftImpute] Iter 48: observed MAE=0.022341 rank=4
# [SoftImpute] Iter 49: observed MAE=0.022335 rank=4
# [SoftImpute] Iter 50: observed MAE=0.022330 rank=4
# [SoftImpute] Iter 51: observed MAE=0.022325 rank=4
# [SoftImpute] Iter 52: observed MAE=0.022321 rank=4
# [SoftImpute] Iter 53: observed MAE=0.022317 rank=4
# [SoftImpute] Iter 54: observed MAE=0.022313 rank=4
# [SoftImpute] Iter 55: observed MAE=0.022309 rank=4
# [SoftImpute] Iter 56: observed MAE=0.022305 rank=4
# [SoftImpute] Iter 57: observed MAE=0.022302 rank=4
# [SoftImpute] Iter 58: observed MAE=0.022299 rank=4
# [SoftImpute] Iter 59: observed MAE=0.022296 rank=4
# [SoftImpute] Iter 60: observed MAE=0.022292 rank=4
# [SoftImpute] Iter 61: observed MAE=0.022289 rank=4
# [SoftImpute] Iter 62: observed MAE=0.022287 rank=4
# [SoftImpute] Iter 63: observed MAE=0.022285 rank=4
# [SoftImpute] Iter 64: observed MAE=0.022283 rank=4
# [SoftImpute] Iter 65: observed MAE=0.022281 rank=4
# [SoftImpute] Iter 66: observed MAE=0.022279 rank=4
# [SoftImpute] Iter 67: observed MAE=0.022277 rank=4
# [SoftImpute] Iter 68: observed MAE=0.022275 rank=4
# [SoftImpute] Iter 69: observed MAE=0.022272 rank=4
# [SoftImpute] Iter 70: observed MAE=0.022270 rank=4
# [SoftImpute] Iter 71: observed MAE=0.022267 rank=4
# [SoftImpute] Iter 72: observed MAE=0.022266 rank=4
# [SoftImpute] Iter 73: observed MAE=0.022265 rank=4
# [SoftImpute] Iter 74: observed MAE=0.022264 rank=4
# [SoftImpute] Iter 75: observed MAE=0.022263 rank=4
# [SoftImpute] Iter 76: observed MAE=0.022261 rank=4
# [SoftImpute] Iter 77: observed MAE=0.022260 rank=4
# [SoftImpute] Iter 78: observed MAE=0.022259 rank=4
# [SoftImpute] Iter 79: observed MAE=0.022258 rank=4
# [SoftImpute] Iter 80: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 81: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 82: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 83: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 84: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 85: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 86: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 87: observed MAE=0.022256 rank=4
# [SoftImpute] Iter 88: observed MAE=0.022255 rank=4
# [SoftImpute] Iter 89: observed MAE=0.022255 rank=4
# [SoftImpute] Iter 90: observed MAE=0.022255 rank=4
# [SoftImpute] Iter 91: observed MAE=0.022254 rank=4
# [SoftImpute] Iter 92: observed MAE=0.022254 rank=4
# [SoftImpute] Iter 93: observed MAE=0.022253 rank=4
# [SoftImpute] Iter 94: observed MAE=0.022252 rank=4
# [SoftImpute] Iter 95: observed MAE=0.022252 rank=4
# [SoftImpute] Iter 96: observed MAE=0.022251 rank=4
# [SoftImpute] Iter 97: observed MAE=0.022250 rank=4
# [SoftImpute] Iter 98: observed MAE=0.022249 rank=4
# [SoftImpute] Iter 99: observed MAE=0.022249 rank=4
# [SoftImpute] Iter 100: observed MAE=0.022248 rank=4
# [SoftImpute] Stopped after iteration 100 for lambda=0.220700
# array([[0.013, 0.002],
#        [0.026, 0.005],
#        [0.04 , 0.004],
#        [0.054, 0.007],
#        [0.066, 0.005]])
